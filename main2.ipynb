# %% [markdown]
# # Michelin Restaurants in Italy: Data Exploration and Search Engine

# %% [markdown]
# # RQ1. Data Collection

# %% [markdown]
# I started by collecting the restaurants' URLs from the Michelin Guide's website for Italy. To do this, I used a web scraper built with requests and BeautifulSoup. The scraper iteratively constructs paginated URLs (/page/1, /page/2, ecc). I considered only links that contains /restaurant/ in their url, and I stored them in a Python set (in order to avoid duplicates).

# %% [markdown]
# ## 1.1. Get the List of Michelin Restaurants

# %%
# Importing necessary libraries

import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import os
import shutil
import re
import pandas as pd

# Set the base URL, the Michelin guide site for restaurants in Italy
base_url = "https://guide.michelin.com/en/it/restaurants"
all_urls = set()  # Inizialize the set to store unique URLs
page_number = 1   # Initialize the page number

while True:
  # Construct the URL for the current page
  paginated_url = f"{base_url}/page/{page_number}"
  response = requests.get(paginated_url)

  # Check if the request was successful (status code 200) or not
  if response.status_code != 200:
    print(f"Stopping at page {page_number}, status code: {response.status_code}")
    break  # If the request fails, stop (no more pages to fetch)

  # Parse the HTML content using BeautifulSoup
  soup = BeautifulSoup(response.text, "html.parser")

  # Find all <a> tags with a href attribute (hyperlinks)
  links = soup.find_all("a", href=True)

  # Filter links to include only the ones containing "restaurant" in theirs URLs
  filtered_links = list(filter(lambda link: "/restaurant/" in link["href"], links))

  # Convert relative URLs to absolute URLs and add them to the set
  for link in filtered_links:
    all_urls.add(urljoin(base_url, link["href"]))

  # Check for the end of the page
  if not filtered_links:
    print("No more restaurants on this page, stopping pagination")
    break

  # Increment the page number
  page_number += 1

# Output the results
print(f"Collected {len(all_urls)} unique restaurant links")
for url in all_urls:
    print(url)
# Out:
# Stopping at page 101, status code: 404
# Collected 1981 unique restaurant links
# https://guide.michelin.com/en/emilia-romagna/milano-marittima/restaurant/terrazza-bartolini
# https://guide.michelin.com/en/friuli-venezia-giulia/tavagnacco/restaurant/al-grop
# https://guide.michelin.com/en/veneto/rubano/restaurant/le-calandre
# https://guide.michelin.com/en/emilia-romagna/campogalliano/restaurant/magnagallo
# https://guide.michelin.com/en/veneto/asolo/restaurant/locanda-baggio
# https://guide.michelin.com/en/lazio/latina/restaurant/il-funghetto
# https://guide.michelin.com/en/trentino-alto-adige/corvara-in-badia/restaurant/ladinia
# https://guide.michelin.com/en/veneto/mestre/restaurant/all-ombra-del-gabbiano
# https://guide.michelin.com/en/lombardia/legnano/restaurant/koine
# https://guide.michelin.com/en/emilia-romagna/modena/restaurant/trattoria-pomposa-al-re-gras
# https://guide.michelin.com/en/toscana/firenze/restaurant/degusteria-italiana
# https://guide.michelin.com/en/emilia-romagna/castelnovo-di-sotto/restaurant/poli-alla-stazione
# https://guide.michelin.com/en/sicilia/noto/restaurant/viva-il-bistrot
# https://guide.michelin.com/en/puglia/ostuni/restaurant/700
# https://guide.michelin.com/en/lombardia/milano/restaurant/bele
# https://guide.michelin.com/en/toscana/cutigliano/restaurant/trattoria-da-fagiolino
# https://guide.michelin.com/en/toscana/castelnuovo-berardenga/restaurant/poggio-rosso
# https://guide.michelin.com/en/lombardia/origgio/restaurant/el-primero
# https://guide.michelin.com/en/lombardia/albavilla/restaurant/il-cantuccio
# https://guide.michelin.com/en/campania/sant--agata-sui-due-golfi/restaurant/don-alfonso-1890-151521
# https://guide.michelin.com/en/lombardia/milano/restaurant/il-liberty
# https://guide.michelin.com/en/sicilia/pantelleria/restaurant/osteria-il-principe-e-il-pirata
# https://guide.michelin.com/en/veneto/scorz/restaurant/i-savi
# https://guide.michelin.com/en/lombardia/milano/restaurant/il-ristorante-niko-romito
# https://guide.michelin.com/en/lazio/ariccia/restaurant/sintesi
# https://guide.michelin.com/en/sicilia/zafferana-etnea/restaurant/sabir
# https://guide.michelin.com/en/lombardia/delebio/restaurant/osteria-del-benedet
# https://guide.michelin.com/en/veneto/scorz/restaurant/san-martino
# https://guide.michelin.com/en/lombardia/varzi/restaurant/buscone
# https://guide.michelin.com/en/veneto/bardolino/restaurant/il-giardino-delle-esperidi
# https://guide.michelin.com/en/veneto/venezia/restaurant/alle-corone
# https://guide.michelin.com/en/valle-d-aosta/it-breuil-cervinia/restaurant/la-chandelle1154957
# https://guide.michelin.com/en/lombardia/ambivere/restaurant/antica-osteria-dei-cameli
# https://guide.michelin.com/en/veneto/noventa-padovana_1818158/restaurant/opificio
# https://guide.michelin.com/en/campania/vico-equense/restaurant/mima
# https://guide.michelin.com/en/sardegna/arborea/restaurant/trattoria-margherita
# https://guide.michelin.com/en/lombardia/recorfano/restaurant/antica-trattoria-gianna
# https://guide.michelin.com/en/marche/civitanova-marche/restaurant/galileo
# https://guide.michelin.com/en/calabria/tropea/restaurant/de-minimi
# https://guide.michelin.com/en/emilia-romagna/castel-san-pietro-terme_1824717/restaurant/il-grifone
# https://guide.michelin.com/en/friuli-venezia-giulia/dolegna-del-collio/restaurant/ronchi-ro
# https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/corbezzoli
# https://guide.michelin.com/en/piemonte/borghetto-di-borbera/restaurant/il-fiorile
# https://guide.michelin.com/en/toscana/castiglione-della-pescaia/restaurant/la-trattoria-enrico-bartolini
# https://guide.michelin.com/en/trentino-alto-adige/san-martino-di-castrozza/restaurant/chalet-pra-delle-nasse-da-anita
# https://guide.michelin.com/en/piemonte/alba/restaurant/osteria-dell-arco
# https://guide.michelin.com/en/puglia/trani/restaurant/osteria-frangipane
# https://guide.michelin.com/en/toscana/cetona/restaurant/il-tiglio-di-piazza-da-nilo
# https://guide.michelin.com/en/campania/san-giorgio-del-sannio/restaurant/locanda-della-luna
# https://guide.michelin.com/en/calabria/catanzaro/restaurant/abbruzzino
# https://guide.michelin.com/en/veneto/lughetto/restaurant/antica-osteria-cera
# https://guide.michelin.com/en/veneto/treviso/restaurant/feria
# https://guide.michelin.com/en/veneto/mirano/restaurant/da-flavio-e-fabrizio-al-teatro
# https://guide.michelin.com/en/marche/fano/restaurant/cile-s
# https://guide.michelin.com/en/lombardia/milano/restaurant/pellico-3
# https://guide.michelin.com/en/emilia-romagna/milano-marittima/restaurant/sale-grosso
# https://guide.michelin.com/en/veneto/verona/restaurant/iris-ristorante
# https://guide.michelin.com/en/toscana/prato/restaurant/moi-omakase
# https://guide.michelin.com/en/liguria/framura_1795556/restaurant/l-agave
# https://guide.michelin.com/en/lombardia/milano/restaurant/seta-by-antonio-guida
# https://guide.michelin.com/en/piemonte/torino/restaurant/andrea-larossa
# https://guide.michelin.com/en/toscana/bibbiena/restaurant/il-tirabuscio262517
# https://guide.michelin.com/en/toscana/arezzo/restaurant/le-chiavi-d-oro
# https://guide.michelin.com/en/emilia-romagna/savigno/restaurant/trattoria-da-amerigo
# https://guide.michelin.com/en/lazio/terracina/restaurant/locanda-altobelli
# https://guide.michelin.com/en/trentino-alto-adige/fondo/restaurant/alle-ciaspole
# https://guide.michelin.com/en/emilia-romagna/monticelli-d-ongina/restaurant/antica-trattoria-cattivelli
# https://guide.michelin.com/en/lombardia/milano/restaurant/sadler
# https://guide.michelin.com/en/lombardia/milano/restaurant/quadri-bistrot
# https://guide.michelin.com/en/veneto/cortina-d-ampezzo/restaurant/baita-pie-tofana
# https://guide.michelin.com/en/veneto/venezia/restaurant/terrazza-danieli
# https://guide.michelin.com/en/toscana/volterra/restaurant/enoteca-del-duca
# https://guide.michelin.com/en/toscana/empoli/restaurant/20-posti
# https://guide.michelin.com/en/sicilia/licata/restaurant/l-oste-e-il-sacrestano
# https://guide.michelin.com/en/puglia/trani/restaurant/il-melograno155156
# https://guide.michelin.com/en/toscana/loro-ciuffenna/restaurant/il-cipresso-da-cioni
# https://guide.michelin.com/en/piemonte/treiso/restaurant/la-ciau-del-tornavento
# https://guide.michelin.com/en/veneto/treviso/restaurant/il-basilisco
# https://guide.michelin.com/en/liguria/genova/restaurant/santamonica
# https://guide.michelin.com/en/piemonte/torino/restaurant/condividere
# https://guide.michelin.com/en/piemonte/stresa/restaurant/verbano
# https://guide.michelin.com/en/lombardia/barcuzzi/restaurant/da-oscar
# https://guide.michelin.com/en/trentino-alto-adige/canazei/restaurant/alla-locanda
# https://guide.michelin.com/en/liguria/ne/restaurant/la-brinca
# https://guide.michelin.com/en/toscana/bientina/restaurant/osteria-taviani
# https://guide.michelin.com/en/lombardia/varenna/restaurant/hosteria-del-platano
# https://guide.michelin.com/en/lombardia/cernobbio/restaurant/casa-perrotta-restaurant
# https://guide.michelin.com/en/emilia-romagna/levizzano-rangone/restaurant/opera-02
# https://guide.michelin.com/en/veneto/puos-d-alpago/restaurant/locanda-san-lorenzo
# https://guide.michelin.com/en/trentino-alto-adige/brez/restaurant/locanda-alpina
# https://guide.michelin.com/en/lombardia/mese/restaurant/crotasc
# https://guide.michelin.com/en/lombardia/toscolano-maderno/restaurant/il-cortiletto
# https://guide.michelin.com/en/sicilia/ragusa/restaurant/locanda-don-serafino
# https://guide.michelin.com/en/emilia-romagna/milano-marittima/restaurant/osteria-del-gran-fritto334900
# https://guide.michelin.com/en/veneto/san-zeno-di-montagna/restaurant/taverna-kus
# https://guide.michelin.com/en/lombardia/carona/restaurant/locanda-dei-cantu
# https://guide.michelin.com/en/campania/sorrento/restaurant/zest-1212030
# https://guide.michelin.com/en/trentino-alto-adige/nova-levante/restaurant/johannes-stube
# https://guide.michelin.com/en/toscana/chiusdino/restaurant/saporium
# https://guide.michelin.com/en/lombardia/ponte-san-pietro/restaurant/cucina-cereda
# https://guide.michelin.com/en/liguria/cavi/restaurant/raieu
# https://guide.michelin.com/en/emilia-romagna/modena/restaurant/osteria-francescana
# https://guide.michelin.com/en/toscana/montalcino/restaurant/taverna-il-grappolo-blu
# https://guide.michelin.com/en/piemonte/castagnole-piemonte_1793747/restaurant/granoturco-bistrot
# https://guide.michelin.com/en/piemonte/pollone/restaurant/il-faggio
# https://guide.michelin.com/en/veneto/verona/restaurant/l-oste-scuro
# https://guide.michelin.com/en/lombardia/rovato_1809080/restaurant/al-malo-cucina-e-miscelazione
# https://guide.michelin.com/en/trentino-alto-adige/dobbiaco/restaurant/gratschwirt
# https://guide.michelin.com/en/toscana/montemarciano/restaurant/la-cantinella154248
# https://guide.michelin.com/en/lazio/formello/restaurant/mogano
# https://guide.michelin.com/en/lombardia/robbiate_1808919/restaurant/osteria-dello-strecciolo
# https://guide.michelin.com/en/campania/vallo-della-lucania/restaurant/la-chioccia-d-oro
# https://guide.michelin.com/en/veneto/san-polo-di-piave/restaurant/osteria-enoteca-gambrinus
# https://guide.michelin.com/en/campania/salerno/restaurant/casamare
# https://guide.michelin.com/en/lombardia/palazzolo-sull-oglio/restaurant/osteria-della-villetta
# https://guide.michelin.com/en/lombardia/santa-maria-della-versa/restaurant/ad-astra
# https://guide.michelin.com/en/veneto/mazzorbo/restaurant/venissa
# https://guide.michelin.com/en/trentino-alto-adige/san-cassiano/restaurant/cocun-cellar-restaurant
# https://guide.michelin.com/en/toscana/forte-dei-marmi/restaurant/lorenzo
# https://guide.michelin.com/en/toscana/firenze/restaurant/il-santo-bevitore
# https://guide.michelin.com/en/emilia-romagna/selva-malvezzi_1828749/restaurant/locanda-pincelli
# https://guide.michelin.com/en/campania/sorrento/restaurant/da-bob-cook-fish
# https://guide.michelin.com/en/liguria/monterosso-al-mare/restaurant/l-ancora-della-tortuga
# https://guide.michelin.com/en/piemonte/cerretto-langhe/restaurant/faula
# https://guide.michelin.com/en/trentino-alto-adige/merano/restaurant/sissi
# https://guide.michelin.com/en/puglia/andria/restaurant/il-turacciolo
# https://guide.michelin.com/en/sicilia/taormina/restaurant/kiste
# https://guide.michelin.com/en/veneto/venezia/restaurant/oro-restaurant
# https://guide.michelin.com/en/calabria/rende/restaurant/agora
# https://guide.michelin.com/en/trentino-alto-adige/brennero_1812096/restaurant/artifex
# https://guide.michelin.com/en/puglia/conversano/restaurant/pasha
# https://guide.michelin.com/en/veneto/venezia/restaurant/ai-gondolieri
# https://guide.michelin.com/en/trentino-alto-adige/trento/restaurant/osteria-a-le-due-spade-1198464
# https://guide.michelin.com/en/campania/eboli/restaurant/il-papavero
# https://guide.michelin.com/en/campania/lacco-ameno/restaurant/indaco
# https://guide.michelin.com/en/toscana/carrara/restaurant/extra
# https://guide.michelin.com/en/toscana/pitigliano/restaurant/il-tufo-allegro
# https://guide.michelin.com/en/valle-d-aosta/aosta/restaurant/stefenelli-desk
# https://guide.michelin.com/en/campania/paestum/restaurant/da-nonna-sceppa
# https://guide.michelin.com/en/lazio/tivoli/restaurant/sibilla
# https://guide.michelin.com/en/trentino-alto-adige/merano/restaurant/in-viaggio-claudio-melis1154911
# https://guide.michelin.com/en/sardegna/san-teodoro/restaurant/gusto-by-sadler
# https://guide.michelin.com/en/sardegna/cagliari/restaurant/da-marino-al-st-remy
# https://guide.michelin.com/en/veneto/verona/restaurant/casa-perbellini
# https://guide.michelin.com/en/trentino-alto-adige/trentino-alto-adige-san-michele/restaurant/osteria-platzegg
# https://guide.michelin.com/en/friuli-venezia-giulia/san-quirino/restaurant/la-primula
# https://guide.michelin.com/en/liguria/la-spezia/restaurant/andree
# https://guide.michelin.com/en/emilia-romagna/calestano/restaurant/locanda-mariella
# https://guide.michelin.com/en/veneto/verona/restaurant/la-canonica-1186584
# https://guide.michelin.com/en/trentino-alto-adige/arco/restaurant/locanda-53-supper-club
# https://guide.michelin.com/en/lombardia/revere/restaurant/il-tartufo
# https://guide.michelin.com/en/campania/napoli/restaurant/palazzo-petrucci
# https://guide.michelin.com/en/piemonte/torino/restaurant/madama-piola
# https://guide.michelin.com/en/lombardia/bergamo/restaurant/osteria-al-gigianca
# https://guide.michelin.com/en/lombardia/spirano/restaurant/3-noci-da-camillo
# https://guide.michelin.com/en/emilia-romagna/bobbio/restaurant/piacentino
# https://guide.michelin.com/en/piemonte/torino/restaurant/la-limonaia
# https://guide.michelin.com/en/sicilia/piazza-armerina/restaurant/al-fogher
# https://guide.michelin.com/en/piemonte/pettenasco/restaurant/cannavacciuolo-by-the-lake
# https://guide.michelin.com/en/umbria/passignano-sul-trasimeno/restaurant/il-molo
# https://guide.michelin.com/en/toscana/viareggio/restaurant/henri-restaurant
# https://guide.michelin.com/en/liguria/sestri-levante/restaurant/baia-del-silenzio
# https://guide.michelin.com/en/lombardia/milano/restaurant/horto-1204821
# https://guide.michelin.com/en/sicilia/siracusa/restaurant/don-camillo
# https://guide.michelin.com/en/lombardia/milano/restaurant/ratana
# https://guide.michelin.com/en/campania/squille/restaurant/marotta
# https://guide.michelin.com/en/toscana/massa/restaurant/il-trillo139594
# https://guide.michelin.com/en/toscana/firenze/restaurant/il-gusto-di-xinge
# https://guide.michelin.com/en/lazio/valmontone_1847397/restaurant/specus
# https://guide.michelin.com/en/toscana/lucca/restaurant/l-imbuto
# https://guide.michelin.com/en/lazio/roma/restaurant/enoteca-al-parlamento-achilli
# https://guide.michelin.com/en/lombardia/tavernerio_1809991/restaurant/gnocchetto
# https://guide.michelin.com/en/puglia/savelletri/restaurant/due-camini
# https://guide.michelin.com/en/piemonte/cavagli/restaurant/osteria-dell-oca-bianca
# https://guide.michelin.com/en/lombardia/lallio/restaurant/bolle
# https://guide.michelin.com/en/lazio/frascati/restaurant/cacciani
# https://guide.michelin.com/en/lazio/fiumicino/restaurant/l-osteria-dell-orologio
# https://guide.michelin.com/en/liguria/levanto/restaurant/antica-trattoria-centro
# https://guide.michelin.com/en/piemonte/pallanza/restaurant/milano
# https://guide.michelin.com/en/lombardia/brescia/restaurant/trattoria-porteri
# https://guide.michelin.com/en/piemonte/canelli/restaurant/san-marco
# https://guide.michelin.com/en/liguria/montemarcello/restaurant/pescarino-sapori-di-terra-e-di-mare
# https://guide.michelin.com/en/trentino-alto-adige/madonna-di-senales/restaurant/josef-stube
# https://guide.michelin.com/en/trentino-alto-adige/chienes/restaurant/gassenwirt
# https://guide.michelin.com/en/campania/vico-equense/restaurant/il-bikini
# https://guide.michelin.com/en/basilicata/castelmezzano/restaurant/al-becco-della-civetta
# https://guide.michelin.com/en/sicilia/siracusa/restaurant/cortile-spirito-santo
# https://guide.michelin.com/en/lombardia/ranco/restaurant/il-sole-di-ranco
# https://guide.michelin.com/en/campania/conca-dei-marini/restaurant/il-refettorio
# https://guide.michelin.com/en/toscana/chiusi/restaurant/i-salotti
# https://guide.michelin.com/en/piemonte/gavi/restaurant/locanda-la-raia
# https://guide.michelin.com/en/lombardia/sal/restaurant/felter-alle-rose
# https://guide.michelin.com/en/toscana/orbetello/restaurant/l-oste-dispensa
# https://guide.michelin.com/en/liguria/noli/restaurant/il-vescovado
# https://guide.michelin.com/en/piemonte/magliano-alfieri/restaurant/stefano-paganini-alla-corte-degli-alfieri
# https://guide.michelin.com/en/liguria/lavagna/restaurant/aria-1206715
# https://guide.michelin.com/en/piemonte/novara/restaurant/tantris
# https://guide.michelin.com/en/lombardia/seregno/restaurant/pomiroeu
# https://guide.michelin.com/en/calabria/roccella-ionica/restaurant/la-cascina-1899
# https://guide.michelin.com/en/lombardia/bergamo/restaurant/al-carroponte
# https://guide.michelin.com/en/veneto/venezia/restaurant/al-covo
# https://guide.michelin.com/en/lombardia/villa-d-alm/restaurant/osteria-della-brughiera
# https://guide.michelin.com/en/lombardia/lomazzo/restaurant/trattoria-contemporanea
# https://guide.michelin.com/en/lombardia/villa-d-alm/restaurant/tenuta-casa-virginia
# https://guide.michelin.com/en/lombardia/milano/restaurant/bentoteca
# https://guide.michelin.com/en/umbria/montefalco/restaurant/camiano-piccolo
# https://guide.michelin.com/en/veneto/bassano-del-grappa/restaurant/impronta
# https://guide.michelin.com/en/valle-d-aosta/cogne/restaurant/bar-a-fromage
# https://guide.michelin.com/en/puglia/trani/restaurant/quintessenza-1195965
# https://guide.michelin.com/en/piemonte/traversella/restaurant/le-miniere
# https://guide.michelin.com/en/emilia-romagna/casalgrande/restaurant/badessa
# https://guide.michelin.com/en/lombardia/milano/restaurant/la-veranda-162636
# https://guide.michelin.com/en/lazio/castel-gandolfo/restaurant/antico-ristorante-pagnanelli
# https://guide.michelin.com/en/veneto/treviso/restaurant/pierre-trattoria-sartoriale
# https://guide.michelin.com/en/lombardia/chiesa-in-valmalenco/restaurant/malenco
# https://guide.michelin.com/en/veneto/monselice/restaurant/la-torre141903
# https://guide.michelin.com/en/campania/cava-de-tirreni/restaurant/crub
# https://guide.michelin.com/en/veneto/peschiera-del-garda_1818693/restaurant/osteria-bakare
# https://guide.michelin.com/en/liguria/la-spezia/restaurant/l-osteria-della-corte
# https://guide.michelin.com/en/emilia-romagna/san-polo-d-enza/restaurant/mamma-rosa
# https://guide.michelin.com/en/toscana/san-gimignano/restaurant/linfa
# https://guide.michelin.com/en/lombardia/trezzano-sul-naviglio/restaurant/bacco-e-arianna
# https://guide.michelin.com/en/piemonte/pibesi-d-alba/restaurant/21-9
# https://guide.michelin.com/en/lombardia/suzzara/restaurant/mangiare-bere-uomo-donna
# https://guide.michelin.com/en/trentino-alto-adige/tirolo/restaurant/castel-fine-dining
# https://guide.michelin.com/en/liguria/alassio/restaurant/lamberti
# https://guide.michelin.com/en/trentino-alto-adige/sarentino/restaurant/terra151934
# https://guide.michelin.com/en/liguria/arma-di-taggia/restaurant/la-conchiglia
# https://guide.michelin.com/en/veneto/venezia/restaurant/il-ridotto
# https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/trattoria-battibecco
# https://guide.michelin.com/en/piemonte/torino/restaurant/la-pista
# https://guide.michelin.com/en/lombardia/appiano-gentile/restaurant/ll-portico
# https://guide.michelin.com/en/lombardia/milano/restaurant/pacifico
# https://guide.michelin.com/en/trentino-alto-adige/selva-di-val-gardena/restaurant/suinsom
# https://guide.michelin.com/en/toscana/cerreto-guidi/restaurant/ps-ristorante-1192505
# https://guide.michelin.com/en/veneto/lusia/restaurant/trattoria-al-ponte138786
# https://guide.michelin.com/en/piemonte/mont/restaurant/marcelin
# https://guide.michelin.com/en/lombardia/milano/restaurant/28-posti
# https://guide.michelin.com/en/lombardia/pralboino/restaurant/leon-d-oro146788
# https://guide.michelin.com/en/emilia-romagna/castelnovo-di-baganzola/restaurant/le-viole
# https://guide.michelin.com/en/veneto/venezia/restaurant/local
# https://guide.michelin.com/en/lombardia/monza/restaurant/il-circolino
# https://guide.michelin.com/en/emilia-romagna/montegridolfo_1826929/restaurant/osteria-dell-accademia
# https://guide.michelin.com/en/campania/forio/restaurant/il-saturnino
# https://guide.michelin.com/en/trentino-alto-adige/ravina/restaurant/locanda-margon
# https://guide.michelin.com/en/lombardia/fasano-del-garda/restaurant/il-fagiano
# https://guide.michelin.com/en/liguria/albenga/restaurant/babette394187
# https://guide.michelin.com/en/veneto/vicenza/restaurant/matteo-grandi
# https://guide.michelin.com/en/campania/vico-equense/restaurant/antica-osteria-nonna-rosa
# https://guide.michelin.com/en/lombardia/mariano-comense/restaurant/la-piemontese
# https://guide.michelin.com/en/friuli-venezia-giulia/sauris_1820948/restaurant/alla-pace
# https://guide.michelin.com/en/toscana/firenze/restaurant/locale
# https://guide.michelin.com/en/campania/scala/restaurant/da-lorenzo
# https://guide.michelin.com/en/valle-d-aosta/it-breuil-cervinia/restaurant/wood460913
# https://guide.michelin.com/en/sicilia/isola-vulcano/restaurant/i-tenerumi
# https://guide.michelin.com/en/sardegna/oliena/restaurant/sa-corte
# https://guide.michelin.com/en/lombardia/milano/restaurant/joia
# https://guide.michelin.com/en/lombardia/barzago_1803054/restaurant/osteria-manzoni
# https://guide.michelin.com/en/emilia-romagna/lido-di-savio/restaurant/salsedine367
# https://guide.michelin.com/en/lazio/roma/restaurant/menabo-vino-e-cucina
# https://guide.michelin.com/en/trentino-alto-adige/corvara-in-badia/restaurant/rifugio-col-alt
# https://guide.michelin.com/en/toscana/forte-dei-marmi/restaurant/lux-lucis
# https://guide.michelin.com/en/umbria/perugia/restaurant/ada
# https://guide.michelin.com/en/emilia-romagna/pennabilli/restaurant/il-piastrino
# https://guide.michelin.com/en/lazio/roma/restaurant/antica-pesa
# https://guide.michelin.com/en/toscana/viareggio/restaurant/lunasia500267
# https://guide.michelin.com/en/liguria/finalborgo/restaurant/ai-torchi
# https://guide.michelin.com/en/liguria/dolcedo/restaurant/casa-della-rocca
# https://guide.michelin.com/en/emilia-romagna/piacenza/restaurant/osteria-del-trentino-da-marco
# https://guide.michelin.com/en/lombardia/calvisano/restaurant/al-gambero
# https://guide.michelin.com/en/umbria/todi/restaurant/fiorfiore
# https://guide.michelin.com/en/toscana/marina-di-pietrasanta/restaurant/franco-mare
# https://guide.michelin.com/en/piemonte/la-morra/restaurant/osteria-dell-arborina
# https://guide.michelin.com/en/friuli-venezia-giulia/savogna-d-isonzo/restaurant/lokanda-devetak
# https://guide.michelin.com/en/emilia-romagna/piacenza/restaurant/io-luigi-taglienti
# https://guide.michelin.com/en/veneto/san-bonifacio/restaurant/i-tigli
# https://guide.michelin.com/en/liguria/genova/restaurant/le-rune
# https://guide.michelin.com/en/liguria/montoggio/restaurant/roma
# https://guide.michelin.com/en/sicilia/lipari/restaurant/trattoria-del-vicolo
# https://guide.michelin.com/en/puglia/barletta/restaurant/antica-cucina-1983
# https://guide.michelin.com/en/piemonte/monforte-d-alba/restaurant/giardino-da-felicin
# https://guide.michelin.com/en/toscana/lucca/restaurant/giglio
# https://guide.michelin.com/en/veneto/sandrigo/restaurant/trattoria-da-palmerino
# https://guide.michelin.com/en/friuli-venezia-giulia/cividale-del-friuli/restaurant/al-monastero
# https://guide.michelin.com/en/piemonte/nizza-monferrato/restaurant/le-due-lanterne
# https://guide.michelin.com/en/lombardia/milano/restaurant/andrea-aprea
# https://guide.michelin.com/en/veneto/cortina-d-ampezzo/restaurant/baita-fraina
# https://guide.michelin.com/en/lombardia/milano/restaurant/abba
# https://guide.michelin.com/en/marche/acqualagna/restaurant/anticofurlo
# https://guide.michelin.com/en/liguria/bordighera/restaurant/romolo-mare
# https://guide.michelin.com/en/lombardia/gardone-riviera/restaurant/villa-fiordaliso
# https://guide.michelin.com/en/campania/napoli/restaurant/50-kalo
# https://guide.michelin.com/en/emilia-romagna/cesenatico/restaurant/mare
# https://guide.michelin.com/en/lazio/roma/restaurant/pipero
# https://guide.michelin.com/en/campania/napoli/restaurant/la-notizia
# https://guide.michelin.com/en/veneto/venezia/restaurant/arva
# https://guide.michelin.com/en/veneto/venezia/restaurant/amo
# https://guide.michelin.com/en/trentino-alto-adige/soprabolzano/restaurant/1908
# https://guide.michelin.com/en/lombardia/san-felice-del-benaco/restaurant/sogno
# https://guide.michelin.com/en/lombardia/sesto-san-giovanni/restaurant/85-bistrot
# https://guide.michelin.com/en/veneto/bardolino/restaurant/la-veranda160871
# https://guide.michelin.com/en/piemonte/castelletto-sopra-ticino/restaurant/rosso-di-sera
# https://guide.michelin.com/en/basilicata/melfi/restaurant/la-villa139895
# https://guide.michelin.com/en/campania/napoli/restaurant/joca
# https://guide.michelin.com/en/veneto/caprino-veronese_1812975/restaurant/vert-osteria-contemporanea
# https://guide.michelin.com/en/lombardia/sorisole/restaurant/osteria-degli-assonica
# https://guide.michelin.com/en/lombardia/sorico/restaurant/beccaccino
# https://guide.michelin.com/en/veneto/revine/restaurant/ai-cadelach
# https://guide.michelin.com/en/piemonte/capriata-d-orba/restaurant/il-moro
# https://guide.michelin.com/en/campania/bacoli/restaurant/riccio-restaurant
# https://guide.michelin.com/en/trentino-alto-adige/castel-toblino/restaurant/castel-toblino
# https://guide.michelin.com/en/lombardia/milano/restaurant/morelli
# https://guide.michelin.com/en/emilia-romagna/cesenatico/restaurant/osteria-del-gran-fritto
# https://guide.michelin.com/en/puglia/polignano-a-mare/restaurant/meraviglioso-osteria-moderna
# https://guide.michelin.com/en/campania/pisciotta/restaurant/angiolina
# https://guide.michelin.com/en/friuli-venezia-giulia/monfalcone/restaurant/ai-campi-di-marcello
# https://guide.michelin.com/en/veneto/canale-d-agordo/restaurant/alle-codole
# https://guide.michelin.com/en/sardegna/valledoria_1841206/restaurant/mesadoria
# https://guide.michelin.com/en/veneto/verona/restaurant/osteria-mondo-d-oro
# https://guide.michelin.com/en/veneto/cortina-d-ampezzo/restaurant/alajmo-cortina
# https://guide.michelin.com/en/trentino-alto-adige/san-vigilio-di-marebbe/restaurant/fana-ladina
# https://guide.michelin.com/en/piemonte/torino/restaurant/razzo
# https://guide.michelin.com/en/friuli-venezia-giulia/pordenone/restaurant/la-ferrata
# https://guide.michelin.com/en/veneto/verona/restaurant/il-desco
# https://guide.michelin.com/en/toscana/marciana-marina/restaurant/salegrosso
# https://guide.michelin.com/en/lazio/roma/restaurant/dogma
# https://guide.michelin.com/en/campania/napoli/restaurant/il-ristorante-alain-ducasse-napoli
# https://guide.michelin.com/en/lombardia/gargnano/restaurant/la-tortuga
# https://guide.michelin.com/en/toscana/nibbiaia/restaurant/locanda-martinelli
# https://guide.michelin.com/en/trentino-alto-adige/riva-del-garda/restaurant/al-volt
# https://guide.michelin.com/en/lombardia/stradella/restaurant/gioele
# https://guide.michelin.com/en/lombardia/teglio/restaurant/fracia
# https://guide.michelin.com/en/sicilia/malfa/restaurant/signum
# https://guide.michelin.com/en/lombardia/laveno/restaurant/la-tavola
# https://guide.michelin.com/en/marche/senigallia/restaurant/al-cuoco-di-bordo
# https://guide.michelin.com/en/abruzzo/roccaraso/restaurant/chichibio
# https://guide.michelin.com/en/liguria/san-desiderio/restaurant/bruxaboschi
# https://guide.michelin.com/en/sardegna/olbia/restaurant/dulchemente
# https://guide.michelin.com/en/toscana/torrita-di-siena/restaurant/lupaia
# https://guide.michelin.com/en/campania/marina-di-casal-velino/restaurant/alessandro-feo
# https://guide.michelin.com/en/lazio/roma/restaurant/trattoria-del-pesce
# https://guide.michelin.com/en/trentino-alto-adige/pergine-valsugana/restaurant/osteria-storica-morelli
# https://guide.michelin.com/en/piemonte/alba/restaurant/lalibera
# https://guide.michelin.com/en/sicilia/agrigento/restaurant/carusu
# https://guide.michelin.com/en/marche/cagli/restaurant/la-gioconda
# https://guide.michelin.com/en/emilia-romagna/rimini/restaurant/abocar-due-cucine
# https://guide.michelin.com/en/toscana/san-gimignano/restaurant/san-martino-26
# https://guide.michelin.com/en/emilia-romagna/ferrara/restaurant/cucina-bacilieri
# https://guide.michelin.com/en/piemonte/alba/restaurant/locanda-del-pilone
# https://guide.michelin.com/en/liguria/badalucco/restaurant/umami-1211596
# https://guide.michelin.com/en/friuli-venezia-giulia/cavazzo-carnico/restaurant/borgo-poscolle
# https://guide.michelin.com/en/toscana/moggiona/restaurant/il-cedro
# https://guide.michelin.com/en/lombardia/milano/restaurant/finger-s-garden
# https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/la-porta-restaurant
# https://guide.michelin.com/en/sardegna/santa-reparata/restaurant/s-andira
# https://guide.michelin.com/en/emilia-romagna/castel-maggiore/restaurant/iacobucci
# https://guide.michelin.com/en/toscana/montopoli-in-val-d-arno/restaurant/quattro-gigli
# https://guide.michelin.com/en/trentino-alto-adige/moena/restaurant/malga-panna
# https://guide.michelin.com/en/veneto/annone-veneto/restaurant/il-credenziere
# https://guide.michelin.com/en/piemonte/canale/restaurant/all-enoteca
# https://guide.michelin.com/en/sardegna/cagliari/restaurant/sarti-del-gusto
# https://guide.michelin.com/en/campania/positano/restaurant/la-taverna-del-leone
# https://guide.michelin.com/en/liguria/borgio-verezzi/restaurant/doc
# https://guide.michelin.com/en/trentino-alto-adige/anterivo/restaurant/kurbishof
# https://guide.michelin.com/en/basilicata/terranova-di-pollino/restaurant/luna-rossa
# https://guide.michelin.com/en/campania/nola/restaurant/rear-restaurant
# https://guide.michelin.com/en/lazio/roma/restaurant/all-oro
# https://guide.michelin.com/en/campania/telese/restaurant/la-locanda-del-borgo
# https://guide.michelin.com/en/marche/gabicce-monte/restaurant/dalla-gioconda
# https://guide.michelin.com/en/abruzzo/giulianova-lido/restaurant/osteria-dal-moro
# https://guide.michelin.com/en/lombardia/milano/restaurant/la-cantina-di-manuela69273
# https://guide.michelin.com/en/piemonte/torino/restaurant/tuorlo-1198461
# https://guide.michelin.com/en/puglia/ruvo-di-puglia/restaurant/u-p-e-p-i-d-d-e
# https://guide.michelin.com/en/sicilia/caltanissetta/restaurant/zaghara-restaurant
# https://guide.michelin.com/en/campania/caserta/restaurant/le-colonne
# https://guide.michelin.com/en/friuli-venezia-giulia/sappada/restaurant/laite
# https://guide.michelin.com/en/piemonte/gattinara/restaurant/cucine-nervi
# https://guide.michelin.com/en/lombardia/crema/restaurant/botero
# https://guide.michelin.com/en/piemonte/revigliasco/restaurant/la-taverna-di-fra-fiusch
# https://guide.michelin.com/en/piemonte/badia-di-dulzago/restaurant/osteria-san-giulio
# https://guide.michelin.com/en/emilia-romagna/novafeltria/restaurant/del-turista-da-marchesi
# https://guide.michelin.com/en/toscana/firenze/restaurant/ora-d-aria
# https://guide.michelin.com/en/emilia-romagna/longiano/restaurant/terre-alte
# https://guide.michelin.com/en/lombardia/milano/restaurant/la-cucina-dei-frigoriferi-milanesi
# https://guide.michelin.com/en/lazio/roma/restaurant/pulejo
# https://guide.michelin.com/en/emilia-romagna/gaione/restaurant/trattoria-antichi-sapori
# https://guide.michelin.com/en/toscana/vicopisano/restaurant/osteria-vecchia-noce
# https://guide.michelin.com/en/liguria/genova/restaurant/spin-ristorante-enoteca-sola
# https://guide.michelin.com/en/sardegna/carloforte/restaurant/al-tonno-di-corsa
# https://guide.michelin.com/en/trentino-alto-adige/rabla/restaurant/hanswirt
# https://guide.michelin.com/en/toscana/firenze/restaurant/l-ortone
# https://guide.michelin.com/en/lazio/caprarola/restaurant/trattoria-del-cimino-dal-1895
# https://guide.michelin.com/en/piemonte/torino/restaurant/magazzino-52
# https://guide.michelin.com/en/puglia/carovigno/restaurant/gia-sotto-l-arco
# https://guide.michelin.com/en/lazio/pontinia/restaurant/mater1apr1ma
# https://guide.michelin.com/en/lombardia/peschiera-borromeo/restaurant/asina-luna
# https://guide.michelin.com/en/sicilia/taormina/restaurant/blum-1208129
# https://guide.michelin.com/en/trentino-alto-adige/romeno/restaurant/nerina
# https://guide.michelin.com/en/valle-d-aosta/aosta/restaurant/vecchio-ristoro
# https://guide.michelin.com/en/emilia-romagna/montefiorino/restaurant/lucenti
# https://guide.michelin.com/en/piemonte/borgomanero/restaurant/pinocchio
# https://guide.michelin.com/en/puglia/troia_1853841/restaurant/gallery-bistrot-contemporaneo
# https://guide.michelin.com/en/toscana/cortona/restaurant/la-bucaccia
# https://guide.michelin.com/en/toscana/serravalle-pistoiese/restaurant/trattoria-da-marino
# https://guide.michelin.com/en/calabria/crotone/restaurant/da-ercole
# https://guide.michelin.com/en/toscana/san-miniato/restaurant/papaveri-e-papere
# https://guide.michelin.com/en/lazio/roma/restaurant/da-armando-al-pantheon
# https://guide.michelin.com/en/veneto/venezia/restaurant/chat-qui-rit
# https://guide.michelin.com/en/puglia/bari/restaurant/la-bul
# https://guide.michelin.com/en/lazio/roma/restaurant/l-arcangelo
# https://guide.michelin.com/en/veneto/vetrego/restaurant/il-sogno
# https://guide.michelin.com/en/sicilia/isola-vulcano/restaurant/il-cappero
# https://guide.michelin.com/en/veneto/brenzone-sul-garda_1812115/restaurant/nin
# https://guide.michelin.com/en/lombardia/casteggio_1804962/restaurant/hosteria-la-cave-cantu
# https://guide.michelin.com/en/lombardia/milano/restaurant/ba-asian-mood
# https://guide.michelin.com/en/emilia-romagna/longiano/restaurant/magnolia
# https://guide.michelin.com/en/sardegna/porto-cervo/restaurant/frades-la-terrazza
# https://guide.michelin.com/en/piemonte/sizzano/restaurant/impero
# https://guide.michelin.com/en/piemonte/gattinara/restaurant/osteria-contemporanea
# https://guide.michelin.com/en/lazio/ponza/restaurant/acqua-pazza-1192022
# https://guide.michelin.com/en/toscana/castelnuovo-berardenga/restaurant/contrada
# https://guide.michelin.com/en/lombardia/brescia/restaurant/vivace
# https://guide.michelin.com/en/sicilia/terrasini/restaurant/salotto-sul-mare
# https://guide.michelin.com/en/veneto/roncade/restaurant/le-cementine
# https://guide.michelin.com/en/emilia-romagna/carpi/restaurant/il-25
# https://guide.michelin.com/en/sicilia/marina-di-ragusa/restaurant/votavota
# https://guide.michelin.com/en/campania/vallesaccarda/restaurant/oasis-sapori-antichi
# https://guide.michelin.com/en/marche/pesaro/restaurant/gibas
# https://guide.michelin.com/en/veneto/marano-di-valpolicella_1817125/restaurant/locanda-di-nonna-ida
# https://guide.michelin.com/en/emilia-romagna/rimini/restaurant/dallo-zio
# https://guide.michelin.com/en/emilia-romagna/gaibana/restaurant/trattoria-lanzagallo
# https://guide.michelin.com/en/piemonte/roletto/restaurant/il-ciabot
# https://guide.michelin.com/en/veneto/venezia/restaurant/lineadombra
# https://guide.michelin.com/en/trentino-alto-adige/fornace/restaurant/le-tre-colombe
# https://guide.michelin.com/en/trentino-alto-adige/sorni/restaurant/trattoria-vecchia-sorni
# https://guide.michelin.com/en/abruzzo/rivisondoli/restaurant/da-giocondo
# https://guide.michelin.com/en/toscana/cecina/restaurant/il-doretto
# https://guide.michelin.com/en/trentino-alto-adige/corvara-in-badia/restaurant/bistrot-la-perla
# https://guide.michelin.com/en/emilia-romagna/salsomaggiore-terme/restaurant/l-osteria-del-castellazzo
# https://guide.michelin.com/en/toscana/vinci_1839587/restaurant/atman
# https://guide.michelin.com/en/veneto/arzignano/restaurant/damini-macelleria-affini
# https://guide.michelin.com/en/veneto/fagnano/restaurant/trattoria-alla-pergola
# https://guide.michelin.com/en/campania/praiano/restaurant/un-piano-nel-cielo
# https://guide.michelin.com/en/sardegna/alghero/restaurant/sa-mandra
# https://guide.michelin.com/en/toscana/suvereto/restaurant/i-ciocio-osteria-di-suvereto
# https://guide.michelin.com/en/campania/napoli/restaurant/george-restaurant
# https://guide.michelin.com/en/lombardia/milano/restaurant/altrimenti
# https://guide.michelin.com/en/marche/torre-di-palme/restaurant/villa-lattanzi
# https://guide.michelin.com/en/marche/san-benedetto-del-tronto/restaurant/degusteria-del-gigante
# https://guide.michelin.com/en/toscana/viareggio/restaurant/da-miro-alla-lanterna
# https://guide.michelin.com/en/toscana/greve-in-chianti/restaurant/vitique
# https://guide.michelin.com/en/lazio/grottaferrata/restaurant/taverna-dello-spuntino
# https://guide.michelin.com/en/piemonte/biella/restaurant/matteo-caffe-e-cucina
# https://guide.michelin.com/en/emilia-romagna/salsomaggiore-terme/restaurant/trattoria-ceriati
# https://guide.michelin.com/en/veneto/padova/restaurant/stefano-mocellin-al-padovanino
# https://guide.michelin.com/en/piemonte/toceno_1801599/restaurant/le-vie-del-borgo
# https://guide.michelin.com/en/sicilia/cefal/restaurant/cortile-pepe
# https://guide.michelin.com/en/sicilia/san-vito-lo-capo/restaurant/profumi-del-cous-cous
# https://guide.michelin.com/en/lombardia/cassinetta-di-lugagnano_1804947/restaurant/antica-osteria-del-ponte
# https://guide.michelin.com/en/lombardia/corte-de-cortesi/restaurant/il-gabbiano
# https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/vicolo-colombina
# https://guide.michelin.com/en/veneto/asiago/restaurant/stube-gourmet
# https://guide.michelin.com/en/sicilia/pantelleria/restaurant/i-giardini-dei-rodo
# https://guide.michelin.com/en/lombardia/cornaredo/restaurant/olmo
# https://guide.michelin.com/en/piemonte/quarona/restaurant/italia
# https://guide.michelin.com/en/lazio/roma/restaurant/gainn
# https://guide.michelin.com/en/calabria/lamezia-terme/restaurant/abbruzzino-oltre
# https://guide.michelin.com/en/lombardia/senago/restaurant/la-brughiera
# https://guide.michelin.com/en/sicilia/cefal/restaurant/locanda-del-marinaio
# https://guide.michelin.com/en/puglia/minervino-di-lecce_1852995/restaurant/osteria-origano
# https://guide.michelin.com/en/sardegna/portoscuso/restaurant/sa-musciara
# https://guide.michelin.com/en/umbria/orvieto/restaurant/i-sette-consoli
# https://guide.michelin.com/en/calabria/san-giovanni-in-fiore/restaurant/hyle
# https://guide.michelin.com/en/umbria/bevagna/restaurant/serpillo
# https://guide.michelin.com/en/abruzzo/manoppello-scalo/restaurant/trita-pepe
# https://guide.michelin.com/en/veneto/montecchio-precalcino/restaurant/la-locanda-di-piero
# https://guide.michelin.com/en/veneto/dossobuono/restaurant/cavour
# https://guide.michelin.com/en/lombardia/livigno/restaurant/camana-veglia
# https://guide.michelin.com/en/lombardia/milano/restaurant/borgia-milano
# https://guide.michelin.com/en/toscana/lido-di-camaiore/restaurant/il-merlo
# https://guide.michelin.com/en/toscana/lucca/restaurant/peperosa
# https://guide.michelin.com/en/lombardia/milano/restaurant/enrico-bartolini-al-mudec
# https://guide.michelin.com/en/veneto/san-dona-di-piave/restaurant/forte-del-48
# https://guide.michelin.com/en/lazio/roma/restaurant/osteria-fernanda
# https://guide.michelin.com/en/lombardia/san-fermo-della-battaglia/restaurant/abitat
# https://guide.michelin.com/en/piemonte/biella/restaurant/regallo
# https://guide.michelin.com/en/piemonte/canelli/restaurant/enoteca-di-canelli
# https://guide.michelin.com/en/veneto/venezia/restaurant/dama-restaurant
# https://guide.michelin.com/en/lombardia/milano/restaurant/bon-wei
# https://guide.michelin.com/en/veneto/sernaglia-della-battaglia/restaurant/dalla-libera
# https://guide.michelin.com/en/emilia-romagna/galeata/restaurant/la-campanara
# https://guide.michelin.com/en/toscana/colle-di-val-d-elsa/restaurant/arnolfo
# https://guide.michelin.com/en/umbria/terni/restaurant/nascostoposto
# https://guide.michelin.com/en/friuli-venezia-giulia/trieste/restaurant/al-bagatto
# https://guide.michelin.com/en/trentino-alto-adige/riva-del-garda/restaurant/antiche-mura
# https://guide.michelin.com/en/lombardia/montu-beccaria/restaurant/la-locanda-dei-beccaria
# https://guide.michelin.com/en/puglia/carovigno/restaurant/osteria-casale-ferrovia
# https://guide.michelin.com/en/veneto/san-giorgio-di-valpolicella/restaurant/dalla-rosa-alda
# https://guide.michelin.com/en/lazio/rivodutri/restaurant/la-trota
# https://guide.michelin.com/en/lombardia/gallarate/restaurant/radici-osteria-contemporanea-1196408
# https://guide.michelin.com/en/abruzzo/pescocostanzo/restaurant/la-corniola
# https://guide.michelin.com/en/piemonte/santa-maria-maggiore/restaurant/le-colonne151641
# https://guide.michelin.com/en/liguria/alassio/restaurant/nove
# https://guide.michelin.com/en/piemonte/torino/restaurant/san-tommaso-10
# https://guide.michelin.com/en/trentino-alto-adige/bolzano/restaurant/laurin
# https://guide.michelin.com/en/abruzzo/giulianova-lido/restaurant/lucia-136215
# https://guide.michelin.com/en/piemonte/mondovi/restaurant/caffe-bertaina-osteria
# https://guide.michelin.com/en/lombardia/origgio/restaurant/olio
# https://guide.michelin.com/en/lombardia/como/restaurant/kitchen-325766
# https://guide.michelin.com/en/marche/sirolo/restaurant/lofficina
# https://guide.michelin.com/en/emilia-romagna/parma/restaurant/inkiostro
# https://guide.michelin.com/en/lombardia/lenna_1806857/restaurant/agriturismo-ferdy
# https://guide.michelin.com/en/veneto/verona/restaurant/vescovo-moro
# https://guide.michelin.com/en/liguria/paraggi/restaurant/langosteria-paraggi
# https://guide.michelin.com/en/piemonte/carru/restaurant/vascello-d-oro
# https://guide.michelin.com/en/valle-d-aosta/cogne/restaurant/lou-ressignon
# https://guide.michelin.com/en/piemonte/cherasco/restaurant/osteria-la-torre
# https://guide.michelin.com/en/toscana/prato/restaurant/il-pirana
# https://guide.michelin.com/en/campania/napoli/restaurant/palazzo-petrucci-pizzeria
# https://guide.michelin.com/en/emilia-romagna/sant-agostino/restaurant/trattoria-la-rosa
# https://guide.michelin.com/en/liguria/recco/restaurant/manuelina
# https://guide.michelin.com/en/lombardia/milano/restaurant/un-posto-a-milano-cascina-cuccagna
# https://guide.michelin.com/en/emilia-romagna/rivalta-trebbia/restaurant/locanda-del-falco
# https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/ahime
# https://guide.michelin.com/en/marche/fano/restaurant/il-galeone
# https://guide.michelin.com/en/piemonte/castagnito-d-alba_7770391/restaurant/marc-lanteri
# https://guide.michelin.com/en/piemonte/grinzane-cavour/restaurant/alessandro-mecca-al-castello-di-grinzane-cavour
# https://guide.michelin.com/en/toscana/pietrasanta/restaurant/filippo
# https://guide.michelin.com/en/emilia-romagna/ravalle/restaurant/l-antico-giardino
# https://guide.michelin.com/en/umbria/corciano_1835233/restaurant/osteria-del-posto
# https://guide.michelin.com/en/trentino-alto-adige/pozza-di-fassa/restaurant/el-filo
# https://guide.michelin.com/en/piemonte/torino/restaurant/tre-galline
# https://guide.michelin.com/en/lombardia/milano/restaurant/motelombroso
# https://guide.michelin.com/en/marche/ascoli-piceno/restaurant/caffe-meletti
# https://guide.michelin.com/en/campania/forio/restaurant/umberto-a-mare
# https://guide.michelin.com/en/sardegna/santa-teresa-gallura/restaurant/millo-ristorante
# https://guide.michelin.com/en/piemonte/san-marzano-oliveto/restaurant/del-belbo-da-bardon
# https://guide.michelin.com/en/marche/porto-san-giorgio/restaurant/l-arcade-1196110
# https://guide.michelin.com/en/calabria/vibo-valentia-marina/restaurant/lapprodo
# https://guide.michelin.com/en/toscana/grosseto/restaurant/grantosco
# https://guide.michelin.com/en/sicilia/noto/restaurant/w-villadorata-country-restaurant
# https://guide.michelin.com/en/veneto/chies-d-alpago_1814192/restaurant/locanda-san-martino
# https://guide.michelin.com/en/veneto/cortina-d-ampezzo/restaurant/al-camin
# https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/seta-sushi-restaurant
# https://guide.michelin.com/en/lombardia/borgonato/restaurant/due-colombe
# https://guide.michelin.com/en/lombardia/erbusco/restaurant/leonefelice
# https://guide.michelin.com/en/piemonte/santo-stefano-belbo/restaurant/il-ristorante-di-guido-da-costigliole
# https://guide.michelin.com/en/lombardia/alzano-lombardo/restaurant/ristofante
# https://guide.michelin.com/en/marche/marotta/restaurant/burro-alici
# https://guide.michelin.com/en/lombardia/milano/restaurant/da-giannino-l-angolo-d-abruzzo
# https://guide.michelin.com/en/trentino-alto-adige/moena/restaurant/inalto-alfio-ghezzi-dolomites
# https://guide.michelin.com/en/piemonte/asti/restaurant/cannavacciuolo-le-cattedrali-asti
# https://guide.michelin.com/en/lazio/gaeta/restaurant/dolia-gaeta
# https://guide.michelin.com/en/liguria/pietra-ligure/restaurant/buca-di-bacco
# https://guide.michelin.com/en/lazio/roma/restaurant/trattoria-pennestri
# https://guide.michelin.com/en/toscana/san-vincenzo/restaurant/la-perla-del-mare
# https://guide.michelin.com/en/abruzzo/teramo/restaurant/oishi-teramo
# https://guide.michelin.com/en/sicilia/castellammare-del-golfo/restaurant/mirko-s
# https://guide.michelin.com/en/lombardia/cicognolo/restaurant/osteria-de-l-umbreleer
# https://guide.michelin.com/en/trentino-alto-adige/moena/restaurant/malga-roncac
# https://guide.michelin.com/en/trentino-alto-adige/madonna-di-campiglio/restaurant/stube-hermitage
# https://guide.michelin.com/en/lazio/roma/restaurant/shiroya
# https://guide.michelin.com/en/basilicata/matera/restaurant/dimora-ulmo
# https://guide.michelin.com/en/veneto/quero/restaurant/locanda-solagna
# https://guide.michelin.com/en/veneto/pieve-d-alpago/restaurant/dolada
# https://guide.michelin.com/en/veneto/verona/restaurant/ponte-pietra
# https://guide.michelin.com/en/emilia-romagna/morciano-di-romagna/restaurant/controcorrente
# https://guide.michelin.com/en/piemonte/torino/restaurant/l-acino
# https://guide.michelin.com/en/piemonte/isola-sant-antonio/restaurant/da-manuela
# https://guide.michelin.com/en/lombardia/morimondo/restaurant/trattoria-di-coronate
# https://guide.michelin.com/en/trentino-alto-adige/sarche/restaurant/hosteria-toblino
# https://guide.michelin.com/en/campania/paestum/restaurant/le-trabe
# https://guide.michelin.com/en/lombardia/pagazzano/restaurant/locanda-viola
# https://guide.michelin.com/en/toscana/forte-dei-marmi/restaurant/la-magnolia
# https://guide.michelin.com/en/umbria/assisi/restaurant/la-locanda-del-cardinale
# https://guide.michelin.com/en/sicilia/taormina/restaurant/st-george-by-heinz-beck
# https://guide.michelin.com/en/emilia-romagna/sarturano/restaurant/antica-trattoria-giovanelli
# https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/sale-grosso384785
# https://guide.michelin.com/en/toscana/lucca/restaurant/all-olivo
# https://guide.michelin.com/en/piemonte/cerretto-langhe/restaurant/trattoria-del-bivio
# https://guide.michelin.com/en/lombardia/clusone/restaurant/commercio-e-mas-ci
# https://guide.michelin.com/en/lombardia/desenzano-del-garda/restaurant/esplanade
# https://guide.michelin.com/en/piemonte/novara/restaurant/tre-scalini
# https://guide.michelin.com/en/campania/pompei/restaurant/il-principe
# https://guide.michelin.com/en/lombardia/milano/restaurant/le-nove-scodelle
# https://guide.michelin.com/en/emilia-romagna/rivergaro/restaurant/locanda-sensi
# https://guide.michelin.com/en/umbria/corciano_1835233/restaurant/aldivino
# https://guide.michelin.com/en/friuli-venezia-giulia/san-giorgio-della-richinvelda/restaurant/il-favri
# https://guide.michelin.com/en/trentino-alto-adige/torbole/restaurant/la-terrazza
# https://guide.michelin.com/en/campania/ariano-irpino/restaurant/maeba-restaurant
# https://guide.michelin.com/en/sicilia/giarre_1854983/restaurant/casu-osteria-contemporanea
# https://guide.michelin.com/en/lombardia/milano/restaurant/aalto
# https://guide.michelin.com/en/trentino-alto-adige/pinzolo/restaurant/grual
# https://guide.michelin.com/en/lombardia/como/restaurant/comi-107
# https://guide.michelin.com/en/toscana/marina-di-pisa/restaurant/foresta
# https://guide.michelin.com/en/calabria/palmi/restaurant/de-gustibus-maurizio
# https://guide.michelin.com/en/veneto/pianiga/restaurant/trattoria-da-paeto
# https://guide.michelin.com/en/toscana/marina-di-massa/restaurant/la-peniche
# https://guide.michelin.com/en/liguria/genova/restaurant/etra
# https://guide.michelin.com/en/piemonte/pollone/restaurant/il-patio
# https://guide.michelin.com/en/veneto/belluno/restaurant/al-borgo126456
# https://guide.michelin.com/en/puglia/minervino-murge/restaurant/la-tradizione-cucina-casalinga
# https://guide.michelin.com/en/lombardia/milano/restaurant/berton
# https://guide.michelin.com/en/calabria/lamezia-terme/restaurant/luigi-lepore
# https://guide.michelin.com/en/lombardia/montichiari/restaurant/maragoncello
# https://guide.michelin.com/en/friuli-venezia-giulia/mariano-del-friuli/restaurant/al-piave
# https://guide.michelin.com/en/liguria/loano/restaurant/bagatto
# https://guide.michelin.com/en/veneto/venezia/restaurant/corte-sconta
# https://guide.michelin.com/en/veneto/fosso/restaurant/bacaro-il-gusto
# https://guide.michelin.com/en/emilia-romagna/maranello/restaurant/il-cavallino
# https://guide.michelin.com/en/abruzzo/marina-di-san-vito/restaurant/l-angolino-da-filippo
# https://guide.michelin.com/en/piemonte/baldichieri-d-asti/restaurant/madama-vigna
# https://guide.michelin.com/en/puglia/lesina/restaurant/le-antiche-sere
# https://guide.michelin.com/en/lombardia/lecco/restaurant/nicolin
# https://guide.michelin.com/en/sardegna/porto-rotondo/restaurant/deste
# https://guide.michelin.com/en/campania/capri/restaurant/da-tonino
# https://guide.michelin.com/en/sicilia/taormina/restaurant/vineria-modi
# https://guide.michelin.com/en/lombardia/brescia/restaurant/la-sosta
# https://guide.michelin.com/en/sicilia/milazzo/restaurant/doppio-gusto
# https://guide.michelin.com/en/sicilia/torregrotta/restaurant/modi
# https://guide.michelin.com/en/veneto/venezia/restaurant/osteria-da-fiore
# https://guide.michelin.com/en/veneto/pastrengo/restaurant/stella-d-italia
# ...
# https://guide.michelin.com/en/sicilia/cefal/restaurant/qualia
# https://guide.michelin.com/en/lombardia/albiate/restaurant/grow-restaurant
# https://guide.michelin.com/en/lombardia/san-vigilio/restaurant/1500
# https://guide.michelin.com/en/liguria/genova/restaurant/voltalacarta
# https://guide.michelin.com/en/trentino-alto-adige/lagundo/restaurant/zur-blauen-traube
# https://guide.michelin.com/en/piemonte/chieri/restaurant/de-gustibus
# https://guide.michelin.com/en/lombardia/milano/restaurant/cracco
# https://guide.michelin.com/en/veneto/rubano/restaurant/il-calandrino
# https://guide.michelin.com/en/toscana/lucca/restaurant/osteria-verciani-il-mecenate-a-lucca
# https://guide.michelin.com/en/veneto/venezia/restaurant/glam-enrico-bartolini
# https://guide.michelin.com/en/liguria/ventimiglia/restaurant/casa-buono
# https://guide.michelin.com/en/toscana/colle-di-val-d-elsa/restaurant/bis-osteria-italiana-contemporanea
# https://guide.michelin.com/en/calabria/pizzo/restaurant/me-restaurant
# https://guide.michelin.com/en/toscana/firenze/restaurant/la-leggenda-dei-frati
# https://guide.michelin.com/en/toscana/castel-del-piano/restaurant/antica-fattoria-del-grottaione
# https://guide.michelin.com/en/campania/napoli/restaurant/januarius
# https://guide.michelin.com/en/lombardia/treviglio/restaurant/san-martino155366
# https://guide.michelin.com/en/trentino-alto-adige/san-genesio-atesino/restaurant/antica-locanda-al-cervo-landgasthof-zum-hirschen
# https://guide.michelin.com/en/lombardia/san-paolo-d-argon/restaurant/florian-maison
# https://guide.michelin.com/en/piemonte/galliate/restaurant/osteria-del-borgo352717
# https://guide.michelin.com/en/trentino-alto-adige/aldein/restaurant/krone
# https://guide.michelin.com/en/piemonte/alba/restaurant/hostaria-dai-musi
# https://guide.michelin.com/en/lazio/roma/restaurant/mater-terrae
# https://guide.michelin.com/en/toscana/panzano/restaurant/antica-macelleria-cecchini-solociccia
# https://guide.michelin.com/en/toscana/marina-di-bibbona/restaurant/la-pineta
# https://guide.michelin.com/en/lazio/nettuno/restaurant/terramadre
# https://guide.michelin.com/en/toscana/firenze/restaurant/konnubio
# https://guide.michelin.com/en/toscana/cortona/restaurant/enoteca-meucci
# https://guide.michelin.com/en/toscana/firenze/restaurant/io-osteria-personale
# https://guide.michelin.com/en/piemonte/cuneo/restaurant/osteria-della-chiocciola
# https://guide.michelin.com/en/lombardia/milano/restaurant/gong
# https://guide.michelin.com/en/sardegna/cagliari/restaurant/amano-1211513
# https://guide.michelin.com/en/toscana/viareggio/restaurant/il-piccolo-principe
# https://guide.michelin.com/en/piemonte/alba/restaurant/piazza-duomo
# https://guide.michelin.com/en/puglia/lecce/restaurant/gimmi-restaurant
# https://guide.michelin.com/en/liguria/rapallo/restaurant/le-cupole
# https://guide.michelin.com/en/lombardia/saronno_1809624/restaurant/sui-generis
# https://guide.michelin.com/en/lazio/roma/restaurant/zia
# https://guide.michelin.com/en/campania/napoli/restaurant/3-0-ciro-cascella
# https://guide.michelin.com/en/valle-d-aosta/aosta/restaurant/gina
# https://guide.michelin.com/en/piemonte/candia-canavese/restaurant/residenza-del-lago
# https://guide.michelin.com/en/toscana/ardenza/restaurant/oscar
# https://guide.michelin.com/en/emilia-romagna/rubbianino/restaurant/ca-matilde
# https://guide.michelin.com/en/lombardia/treviglio/restaurant/marelet
# https://guide.michelin.com/en/piemonte/torino/restaurant/cannavacciuolo-bistrot
# https://guide.michelin.com/en/lombardia/busto-arsizio/restaurant/i-5-campanili
# https://guide.michelin.com/en/emilia-romagna/coloreto/restaurant/la-maison-du-gourmet
# https://guide.michelin.com/en/veneto/venezia/restaurant/bistrot-de-venise
# https://guide.michelin.com/en/toscana/cortona/restaurant/osteria-del-teatro
# https://guide.michelin.com/en/sardegna/porto-san-paolo/restaurant/il-portolano
# https://guide.michelin.com/en/toscana/firenze/restaurant/podere-39
# https://guide.michelin.com/en/calabria/reggio-di-calabria/restaurant/l-a-gourmet-l-accademia
# https://guide.michelin.com/en/trentino-alto-adige/pedraces/restaurant/maso-runch-hof
# https://guide.michelin.com/en/lazio/roma/restaurant/moma
# https://guide.michelin.com/en/campania/atrani/restaurant/a-paranza
# https://guide.michelin.com/en/lazio/rieti/restaurant/bistrot147741
# https://guide.michelin.com/en/toscana/san-casciano-dei-bagni/restaurant/daniela
# https://guide.michelin.com/en/lombardia/barco/restaurant/saur
# https://guide.michelin.com/en/campania/nola/restaurant/re-santi-e-leoni
# https://guide.michelin.com/en/campania/sant--agata-sui-due-golfi/restaurant/lo-stuzzichino
# https://guide.michelin.com/en/toscana/bolgheri/restaurant/osteria-del-tasso
# https://guide.michelin.com/en/toscana/galluzzo/restaurant/trattoria-bibe
# https://guide.michelin.com/en/trentino-alto-adige/vandoies/restaurant/la-passion
# https://guide.michelin.com/en/veneto/lapio/restaurant/trattoria-da-zamboni
# https://guide.michelin.com/en/friuli-venezia-giulia/ruda/restaurant/osteria-altran
# https://guide.michelin.com/en/lombardia/varese/restaurant/al-vecchio-convento
# https://guide.michelin.com/en/sicilia/messina/restaurant/marina-del-nettuno
# https://guide.michelin.com/en/lombardia/milano/restaurant/wicky-s-wicuisine
# https://guide.michelin.com/en/piemonte/torino/restaurant/piazza-dei-mestieri
# https://guide.michelin.com/en/toscana/firenze/restaurant/winter-garden-florence
# https://guide.michelin.com/en/trentino-alto-adige/merano/restaurant/prezioso
# https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/acqua-pazza
# https://guide.michelin.com/en/sardegna/cagliari/restaurant/chiaroscuro
# https://guide.michelin.com/en/lombardia/fagnano-olona/restaurant/acquerello197794
# https://guide.michelin.com/en/lombardia/riva-di-solto/restaurant/miranda148125
# https://guide.michelin.com/en/emilia-romagna/rimini/restaurant/guido
# https://guide.michelin.com/en/sicilia/termini-imerese/restaurant/secondo-tempo
# https://guide.michelin.com/en/molise/termoli/restaurant/federico-ii
# https://guide.michelin.com/en/lombardia/milano/restaurant/ceresio-7
# https://guide.michelin.com/en/veneto/galliera-veneta/restaurant/al-palazzon
# https://guide.michelin.com/en/lombardia/lodi_1806947/restaurant/la-coldana
# https://guide.michelin.com/en/lombardia/quistello/restaurant/l-ambasciata
# https://guide.michelin.com/en/lombardia/runate/restaurant/dal-pescatore
# https://guide.michelin.com/en/trentino-alto-adige/corvara-in-badia/restaurant/l-osti
# https://guide.michelin.com/en/friuli-venezia-giulia/buttrio/restaurant/trattoria-al-parco
# https://guide.michelin.com/en/liguria/genova/restaurant/20tre
# https://guide.michelin.com/en/trentino-alto-adige/corvara-in-badia/restaurant/la-stua-de-michil
# https://guide.michelin.com/en/puglia/monopoli/restaurant/orto
# https://guide.michelin.com/en/emilia-romagna/faenza/restaurant/il-fenicottero-rosa-gourmet
# https://guide.michelin.com/en/umbria/gualdo-cattaneo_1836295/restaurant/il-grottino-1204740
# https://guide.michelin.com/en/toscana/capolona/restaurant/terramira
# https://guide.michelin.com/en/trentino-alto-adige/moena/restaurant/agritur-el-mas
# https://guide.michelin.com/en/campania/torre-del-greco/restaurant/jose-restaurant-tenuta-villa-guerra
# https://guide.michelin.com/en/campania/bacoli/restaurant/caracol
# https://guide.michelin.com/en/lombardia/calvisano/restaurant/fiamma-cremisi
# https://guide.michelin.com/en/trentino-alto-adige/mauls/restaurant/gasthofstube-stafler
# https://guide.michelin.com/en/liguria/portofino/restaurant/cracco-portofino
# https://guide.michelin.com/en/abruzzo/spoltore/restaurant/tamo
# https://guide.michelin.com/en/sicilia/palermo/restaurant/bebop
# https://guide.michelin.com/en/emilia-romagna/vicomero/restaurant/romani
# https://guide.michelin.com/en/sicilia/noto/restaurant/crocifisso
# https://guide.michelin.com/en/piemonte/chieri/restaurant/cascina-lautier
# https://guide.michelin.com/en/lombardia/livigno/restaurant/al-persef
# https://guide.michelin.com/en/veneto/val-liona/restaurant/trequarti
# https://guide.michelin.com/en/campania/ischia/restaurant/dani-maison
# https://guide.michelin.com/en/lombardia/ponte-di-legno/restaurant/kro
# https://guide.michelin.com/en/abruzzo/pacentro/restaurant/taverna-dei-caldora
# https://guide.michelin.com/en/campania/vico-equense/restaurant/maxi
# https://guide.michelin.com/en/marche/senigallia/restaurant/uliassi
# https://guide.michelin.com/en/veneto/oderzo/restaurant/gellius
# https://guide.michelin.com/en/lombardia/como/restaurant/feel
# https://guide.michelin.com/en/toscana/firenze/restaurant/l-insolita-trattoria-tre-soldi
# https://guide.michelin.com/en/campania/vairano-patenora/restaurant/vairo-del-volturno
# https://guide.michelin.com/en/campania/it-montoro/restaurant/casa-federici
# https://guide.michelin.com/en/veneto/bassano-del-grappa/restaurant/ca-7
# https://guide.michelin.com/en/sicilia/san-leone/restaurant/il-molo-430027
# https://guide.michelin.com/en/sicilia/sclafani-bagni/restaurant/terrazza-costantino
# https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/ling-s-ravioleria-migrante
# https://guide.michelin.com/en/piemonte/torino/restaurant/taverna-dell-oca
# https://guide.michelin.com/en/marche/fano/restaurant/osteria-dalla-peppa
# https://guide.michelin.com/en/liguria/finale-ligure/restaurant/rosita
# https://guide.michelin.com/en/campania/capri/restaurant/terrazza-tiberio
# https://guide.michelin.com/en/emilia-romagna/bagno-di-romagna/restaurant/del-lago
# https://guide.michelin.com/en/emilia-romagna/finale-emilia/restaurant/entra
# https://guide.michelin.com/en/sicilia/linguaglossa/restaurant/dodici-fontane
# https://guide.michelin.com/en/lombardia/mantova/restaurant/sucar-brusc
# https://guide.michelin.com/en/campania/napoli/restaurant/veritas
# https://guide.michelin.com/en/emilia-romagna/modena/restaurant/antica-moka
# https://guide.michelin.com/en/liguria/genova/restaurant/le-cicale-in-citta
# https://guide.michelin.com/en/campania/sorrento/restaurant/il-buco
# https://guide.michelin.com/en/veneto/bigolino/restaurant/tre-noghere
# https://guide.michelin.com/en/lazio/roma/restaurant/luciano-cucina-italiana
# https://guide.michelin.com/en/marche/san-severino-marche/restaurant/cavallini
# https://guide.michelin.com/en/lombardia/milano/restaurant/altatto-bistrot
# https://guide.michelin.com/en/lombardia/lainate_1806778/restaurant/la-corte-gourmet
# https://guide.michelin.com/en/veneto/asiago/restaurant/osteria-europa
# https://guide.michelin.com/en/lombardia/castiglione-delle-stiviere/restaurant/hostaria-viola
# https://guide.michelin.com/en/lazio/roma/restaurant/kohaku-1206448
# https://guide.michelin.com/en/toscana/marina-di-pietrasanta/restaurant/alex
# https://guide.michelin.com/en/campania/napoli/restaurant/essencia-restaurant
# https://guide.michelin.com/en/piemonte/torino/restaurant/carignano
# https://guide.michelin.com/en/piemonte/ovada/restaurant/l-archivolto-osteria-nostrale
# https://guide.michelin.com/en/marche/offida/restaurant/osteria-ophis
# https://guide.michelin.com/en/lombardia/cavernago/restaurant/il-saraceno
# https://guide.michelin.com/en/lombardia/cornaredo/restaurant/d-o
# https://guide.michelin.com/en/sicilia/modica/restaurant/radici-1190542
# https://guide.michelin.com/en/toscana/porto-azzurro/restaurant/sapereta
# https://guide.michelin.com/en/liguria/genova/restaurant/soho-restaurant-fish-work
# https://guide.michelin.com/en/lombardia/castel-mella/restaurant/chicco-di-grano
# https://guide.michelin.com/en/campania/napoli/restaurant/luminist-cafe-bistrot
# https://guide.michelin.com/en/veneto/burano/restaurant/al-gatto-nero-da-ruggero
# https://guide.michelin.com/en/friuli-venezia-giulia/lavariano/restaurant/ab-osteria-contemporanea
# https://guide.michelin.com/en/piemonte/borgo-vercelli/restaurant/osteria-cascina-dei-fiori
# https://guide.michelin.com/en/trentino-alto-adige/trentino-alto-adige-san-michele/restaurant/osteria-acquarol
# https://guide.michelin.com/en/piemonte/venaria-reale/restaurant/dolce-stil-novo-alla-reggia
# https://guide.michelin.com/en/toscana/firenze/restaurant/gucci-osteria-da-massimo-bottura
# https://guide.michelin.com/en/veneto/paderno-del-grappa/restaurant/osteria-bellavista
# https://guide.michelin.com/en/abruzzo/civitella-casanova/restaurant/il-ritrovo-d-abruzzo
# https://guide.michelin.com/en/campania/massa-lubrense/restaurant/terrazza-fiorella
# https://guide.michelin.com/en/lazio/roma/restaurant/diana-s-place
# https://guide.michelin.com/en/toscana/casole-d-elsa/restaurant/tosca435462
# https://guide.michelin.com/en/emilia-romagna/modena/restaurant/l-erba-del-re
# https://guide.michelin.com/en/trentino-alto-adige/gudon/restaurant/unterwirt
# https://guide.michelin.com/en/lombardia/cervesina/restaurant/dama-1213583
# https://guide.michelin.com/en/trentino-alto-adige/bolzano/restaurant/zur-kaiserkron
# https://guide.michelin.com/en/trentino-alto-adige/trentino-alto-adige-san-michele/restaurant/zur-rose
# https://guide.michelin.com/en/liguria/savona/restaurant/quintogusto
# https://guide.michelin.com/en/piemonte/tortona/restaurant/osteria-billis
# https://guide.michelin.com/en/lombardia/livigno/restaurant/kosmo-taste-the-mountain
# https://guide.michelin.com/en/trentino-alto-adige/arco/restaurant/peter-brunel-ristorante-gourmet
# https://guide.michelin.com/en/abruzzo/fara-filiorum-petri/restaurant/casa-d-angelo
# https://guide.michelin.com/en/toscana/volterra/restaurant/villa-pignano
# https://guide.michelin.com/en/basilicata/matera/restaurant/ego
# https://guide.michelin.com/en/trentino-alto-adige/badia_3684715/restaurant/porcino
# https://guide.michelin.com/en/sicilia/palermo/restaurant/osteria-dei-vespri
# https://guide.michelin.com/en/lombardia/milano/restaurant/il-marchese-osteria-mercato-liquori-1204539
# https://guide.michelin.com/en/trentino-alto-adige/torbole/restaurant/aqua-560894
# https://guide.michelin.com/en/puglia/racale/restaurant/l-acchiatura
# https://guide.michelin.com/en/piemonte/spinetta-marengo/restaurant/la-fermata
# https://guide.michelin.com/en/lombardia/milano/restaurant/rovello-18
# https://guide.michelin.com/en/trentino-alto-adige/brentonico/restaurant/maso-palu
# https://guide.michelin.com/en/campania/positano/restaurant/la-sponda
# https://guide.michelin.com/en/liguria/portofino/restaurant/dav-mare
# https://guide.michelin.com/en/veneto/venezia/restaurant/osteria-alle-testiere
# https://guide.michelin.com/en/abruzzo/pescara/restaurant/nole
# https://guide.michelin.com/en/campania/amalfi/restaurant/sensi536205
# https://guide.michelin.com/en/toscana/firenze/restaurant/zeb
# https://guide.michelin.com/en/toscana/firenze/restaurant/atto-di-vito-mollica
# https://guide.michelin.com/en/trentino-alto-adige/nalles/restaurant/apollonia
# https://guide.michelin.com/en/trentino-alto-adige/marlengo/restaurant/oberwirt
# https://guide.michelin.com/en/piemonte/ponte/restaurant/walser-schtuba
# https://guide.michelin.com/en/lazio/roma/restaurant/enoteca-la-torre
# https://guide.michelin.com/en/lombardia/puegnago-sul-garda/restaurant/casa-leali
# https://guide.michelin.com/en/veneto/miane/restaurant/da-gigetto
# https://guide.michelin.com/en/emilia-romagna/rimini/restaurant/trattoria-da-lucio
# https://guide.michelin.com/en/campania/napoli/restaurant/sustanza
# https://guide.michelin.com/en/lombardia/milano/restaurant/daniel417950
# https://guide.michelin.com/en/veneto/verona/restaurant/trattoria-i-masenini
# https://guide.michelin.com/en/toscana/carrara/restaurant/il-narciso
# https://guide.michelin.com/en/emilia-romagna/diolo/restaurant/osteria-ardenga
# https://guide.michelin.com/en/lombardia/palazzolo-sull-oglio/restaurant/la-corte144371
# https://guide.michelin.com/en/lombardia/sondrio/restaurant/trippi
# https://guide.michelin.com/en/sardegna/palau/restaurant/la-gritta
# https://guide.michelin.com/en/puglia/trani/restaurant/casa-sgarra
# https://guide.michelin.com/en/lombardia/rodengo-saiano/restaurant/il-colmetto
# https://guide.michelin.com/en/lombardia/induno-olona/restaurant/olona-da-venanzio-dal-1922
# https://guide.michelin.com/en/emilia-romagna/ravenna/restaurant/osteria-del-tempo-perso
# https://guide.michelin.com/en/abruzzo/castel-di-sangro/restaurant/materia-prima
# https://guide.michelin.com/en/lombardia/castiglione-delle-stiviere/restaurant/hostaria-del-teatro

# %% [markdown]
# Once we have a list of restaurant URLs, the next step is to fetch and save the HTML content of each page. The URLs are loaded from **all_links.txt** for processing. The script sends the requests to retrieve the HTML content of each URL, and the fetched HTML content is saved immediately to a local directory (**michelin_restaurant_html**).
#
# The saved HTML files are organized into subfolders based on pages. Files are moved from the main output directory to organized_michelin_html, and they are grouped into subfolders (Page_1, Page_2, ecc). Each subfolder contains up to 20 HTML files, as the official website's pagination.

# %% [markdown]
# ## 1.2. Crawl Michelin restaurant pages

# %%
# Save the collected links to a file
with open("all_links.txt", "w") as f:

    # Write each URL to a new line in the file
    f.writelines(f"{url}\n" for url in all_urls)

# Read URLs from the file
with open("all_links.txt", "r") as file:

    # Split lines into a list of URLs
    urls_list = file.read().splitlines()

print(f"Loaded {len(urls_list)} URLs.")
print(urls_list)

# Directory to save the HTML files
output_folder = "michelin_restaurant_html"
os.makedirs(output_folder, exist_ok=True)  # Create folder if it doesn't exist

# Fetch and save HTML files
for i, url in enumerate(urls_list):
    try:
        # Send a request to fetch the HTML content
        response = requests.get(url)
        response.raise_for_status()  # Raise an error if the request fails

        # Save HTML content immediately to a file
        filename = f"{output_folder}/restaurant_{i+1}.html"
        with open(filename, "w", encoding="utf-8") as file:
            file.write(response.text)

        print(f"Successfully saved: {filename}")

    except requests.RequestException as e:
        print(f"Failed to fetch {url}: {e}")

# Organize HTML files into subfolders
output_folder = "michelin_restaurant_html"    # Folder with the saved HTML files
organized_folder = "organized_michelin_html"  # Target folder for organized structure

# Create the main folder for organized HTML files if it doesn't exist
os.makedirs(organized_folder, exist_ok=True)

# Get a sorted list of all HTML files in the output folder
html_files = sorted(os.listdir(output_folder))
files_per_page = 20  # As the official website

# Loop to move files into page-based folders
for start_index in range(0, len(html_files), files_per_page):
    page_number = (start_index // files_per_page) + 1  # Calculate page number

    # Create a subfolder for each page
    page_folder = os.path.join(organized_folder, f"Page_{page_number}")
    os.makedirs(page_folder, exist_ok=True)  # Create a subfolder if it doesn't exist

    # Move files for the current page into the appropriate folder
    for file_name in html_files[start_index:start_index + files_per_page]:
        file_to_move = os.path.join(output_folder, file_name)
        destination_path = os.path.join(page_folder, file_name)
        if os.path.exists(file_to_move):
            shutil.move(file_to_move, destination_path)
        else:
            print(f"File {file_to_move} not found, skipping move.")

print("Files have been organized into folders based on pages.")

# Get list of subfolders and sort them numerically based on the page number
subfolders = [f.path for f in os.scandir(organized_folder) if f.is_dir()]
subfolders = sorted(subfolders, key=lambda x: int(re.search(r'\d+', x).group()))

# Print out the contents of each subfolder in ascending numerical order
for subfolder in subfolders:

    # Get a sorted list of files in the current subfolder
    file_list = sorted(os.listdir(subfolder))  # Sort files in each subfolder for order consistency
    print(f"{subfolder} contains {len(file_list)} files.")
# Out:
# Loaded 1981 URLs.
# ['https://guide.michelin.com/en/emilia-romagna/milano-marittima/restaurant/terrazza-bartolini', 'https://guide.michelin.com/en/friuli-venezia-giulia/tavagnacco/restaurant/al-grop', 'https://guide.michelin.com/en/veneto/rubano/restaurant/le-calandre', 'https://guide.michelin.com/en/emilia-romagna/campogalliano/restaurant/magnagallo', 'https://guide.michelin.com/en/veneto/asolo/restaurant/locanda-baggio', 'https://guide.michelin.com/en/lazio/latina/restaurant/il-funghetto', 'https://guide.michelin.com/en/trentino-alto-adige/corvara-in-badia/restaurant/ladinia', 'https://guide.michelin.com/en/veneto/mestre/restaurant/all-ombra-del-gabbiano', 'https://guide.michelin.com/en/lombardia/legnano/restaurant/koine', 'https://guide.michelin.com/en/emilia-romagna/modena/restaurant/trattoria-pomposa-al-re-gras', 'https://guide.michelin.com/en/toscana/firenze/restaurant/degusteria-italiana', 'https://guide.michelin.com/en/emilia-romagna/castelnovo-di-sotto/restaurant/poli-alla-stazione', 'https://guide.michelin.com/en/sicilia/noto/restaurant/viva-il-bistrot', 'https://guide.michelin.com/en/puglia/ostuni/restaurant/700', 'https://guide.michelin.com/en/lombardia/milano/restaurant/bele', 'https://guide.michelin.com/en/toscana/cutigliano/restaurant/trattoria-da-fagiolino', 'https://guide.michelin.com/en/toscana/castelnuovo-berardenga/restaurant/poggio-rosso', 'https://guide.michelin.com/en/lombardia/origgio/restaurant/el-primero', 'https://guide.michelin.com/en/lombardia/albavilla/restaurant/il-cantuccio', 'https://guide.michelin.com/en/campania/sant--agata-sui-due-golfi/restaurant/don-alfonso-1890-151521', 'https://guide.michelin.com/en/lombardia/milano/restaurant/il-liberty', 'https://guide.michelin.com/en/sicilia/pantelleria/restaurant/osteria-il-principe-e-il-pirata', 'https://guide.michelin.com/en/veneto/scorz/restaurant/i-savi', 'https://guide.michelin.com/en/lombardia/milano/restaurant/il-ristorante-niko-romito', 'https://guide.michelin.com/en/lazio/ariccia/restaurant/sintesi', 'https://guide.michelin.com/en/sicilia/zafferana-etnea/restaurant/sabir', 'https://guide.michelin.com/en/lombardia/delebio/restaurant/osteria-del-benedet', 'https://guide.michelin.com/en/veneto/scorz/restaurant/san-martino', 'https://guide.michelin.com/en/lombardia/varzi/restaurant/buscone', 'https://guide.michelin.com/en/veneto/bardolino/restaurant/il-giardino-delle-esperidi', 'https://guide.michelin.com/en/veneto/venezia/restaurant/alle-corone', 'https://guide.michelin.com/en/valle-d-aosta/it-breuil-cervinia/restaurant/la-chandelle1154957', 'https://guide.michelin.com/en/lombardia/ambivere/restaurant/antica-osteria-dei-cameli', 'https://guide.michelin.com/en/veneto/noventa-padovana_1818158/restaurant/opificio', 'https://guide.michelin.com/en/campania/vico-equense/restaurant/mima', 'https://guide.michelin.com/en/sardegna/arborea/restaurant/trattoria-margherita', 'https://guide.michelin.com/en/lombardia/recorfano/restaurant/antica-trattoria-gianna', 'https://guide.michelin.com/en/marche/civitanova-marche/restaurant/galileo', 'https://guide.michelin.com/en/calabria/tropea/restaurant/de-minimi', 'https://guide.michelin.com/en/emilia-romagna/castel-san-pietro-terme_1824717/restaurant/il-grifone', 'https://guide.michelin.com/en/friuli-venezia-giulia/dolegna-del-collio/restaurant/ronchi-ro', 'https://guide.michelin.com/en/emilia-romagna/bologna/restaurant/corbezzoli', 'https://guide.michelin.com/en/piemonte/borghetto-di-borbera/restaurant/il-fiorile', 'https://guide.michelin.com/en/toscana/castiglione-della-pescaia/restaurant/la-trattoria-enrico-bartolini', 'https://guide.michelin.com/en/trentino-alto-adige/san-martino-di-castrozza/restaurant/chalet-pra-delle-nasse-da-anita', 'https://guide.michelin.com/en/piemonte/alba/restaurant/osteria-dell-arco', 'https://guide.michelin.com/en/puglia/trani/restaurant/osteria-frangipane', 'https://guide.michelin.com/en/toscana/cetona/restaurant/il-tiglio-di-piazza-da-nilo', 'https://guide.michelin.com/en/campania/san-giorgio-del-sann ...
# Successfully saved: michelin_restaurant_html/restaurant_1.html
# Successfully saved: michelin_restaurant_html/restaurant_2.html
# Successfully saved: michelin_restaurant_html/restaurant_3.html
# Successfully saved: michelin_restaurant_html/restaurant_4.html
# Successfully saved: michelin_restaurant_html/restaurant_5.html
# Successfully saved: michelin_restaurant_html/restaurant_6.html
# Successfully saved: michelin_restaurant_html/restaurant_7.html
# Successfully saved: michelin_restaurant_html/restaurant_8.html
# Successfully saved: michelin_restaurant_html/restaurant_9.html
# Successfully saved: michelin_restaurant_html/restaurant_10.html
# Successfully saved: michelin_restaurant_html/restaurant_11.html
# Successfully saved: michelin_restaurant_html/restaurant_12.html
# Successfully saved: michelin_restaurant_html/restaurant_13.html
# Successfully saved: michelin_restaurant_html/restaurant_14.html
# Successfully saved: michelin_restaurant_html/restaurant_15.html
# Successfully saved: michelin_restaurant_html/restaurant_16.html
# Successfully saved: michelin_restaurant_html/restaurant_17.html
# Successfully saved: michelin_restaurant_html/restaurant_18.html
# Successfully saved: michelin_restaurant_html/restaurant_19.html
# Successfully saved: michelin_restaurant_html/restaurant_20.html
# Successfully saved: michelin_restaurant_html/restaurant_21.html
# Successfully saved: michelin_restaurant_html/restaurant_22.html
# Successfully saved: michelin_restaurant_html/restaurant_23.html
# Successfully saved: michelin_restaurant_html/restaurant_24.html
# Successfully saved: michelin_restaurant_html/restaurant_25.html
# Successfully saved: michelin_restaurant_html/restaurant_26.html
# Successfully saved: michelin_restaurant_html/restaurant_27.html
# Successfully saved: michelin_restaurant_html/restaurant_28.html
# Successfully saved: michelin_restaurant_html/restaurant_29.html
# Successfully saved: michelin_restaurant_html/restaurant_30.html
# Successfully saved: michelin_restaurant_html/restaurant_31.html
# Successfully saved: michelin_restaurant_html/restaurant_32.html
# Successfully saved: michelin_restaurant_html/restaurant_33.html
# Successfully saved: michelin_restaurant_html/restaurant_34.html
# Successfully saved: michelin_restaurant_html/restaurant_35.html
# Successfully saved: michelin_restaurant_html/restaurant_36.html
# Successfully saved: michelin_restaurant_html/restaurant_37.html
# Successfully saved: michelin_restaurant_html/restaurant_38.html
# Successfully saved: michelin_restaurant_html/restaurant_39.html
# Successfully saved: michelin_restaurant_html/restaurant_40.html
# Successfully saved: michelin_restaurant_html/restaurant_41.html
# Successfully saved: michelin_restaurant_html/restaurant_42.html
# Successfully saved: michelin_restaurant_html/restaurant_43.html
# Successfully saved: michelin_restaurant_html/restaurant_44.html
# Successfully saved: michelin_restaurant_html/restaurant_45.html
# Successfully saved: michelin_restaurant_html/restaurant_46.html
# Successfully saved: michelin_restaurant_html/restaurant_47.html
# Successfully saved: michelin_restaurant_html/restaurant_48.html
# Successfully saved: michelin_restaurant_html/restaurant_49.html
# Successfully saved: michelin_restaurant_html/restaurant_50.html
# Successfully saved: michelin_restaurant_html/restaurant_51.html
# Successfully saved: michelin_restaurant_html/restaurant_52.html
# Successfully saved: michelin_restaurant_html/restaurant_53.html
# Successfully saved: michelin_restaurant_html/restaurant_54.html
# Successfully saved: michelin_restaurant_html/restaurant_55.html
# Successfully saved: michelin_restaurant_html/restaurant_56.html
# Successfully saved: michelin_restaurant_html/restaurant_57.html
# Successfully saved: michelin_restaurant_html/restaurant_58.html
# Successfully saved: michelin_restaurant_html/restaurant_59.html
# Successfully saved: michelin_restaurant_html/restaurant_60.html
# Successfully saved: michelin_restaurant_html/restaurant_61.html
# Successfully saved: michelin_restaurant_html/restaurant_62.html
# Successfully saved: michelin_restaurant_html/restaurant_63.html
# Successfully saved: michelin_restaurant_html/restaurant_64.html
# Successfully saved: michelin_restaurant_html/restaurant_65.html
# Successfully saved: michelin_restaurant_html/restaurant_66.html
# Successfully saved: michelin_restaurant_html/restaurant_67.html
# Successfully saved: michelin_restaurant_html/restaurant_68.html
# Successfully saved: michelin_restaurant_html/restaurant_69.html
# Successfully saved: michelin_restaurant_html/restaurant_70.html
# Successfully saved: michelin_restaurant_html/restaurant_71.html
# Successfully saved: michelin_restaurant_html/restaurant_72.html
# Successfully saved: michelin_restaurant_html/restaurant_73.html
# Successfully saved: michelin_restaurant_html/restaurant_74.html
# Successfully saved: michelin_restaurant_html/restaurant_75.html
# Successfully saved: michelin_restaurant_html/restaurant_76.html
# Successfully saved: michelin_restaurant_html/restaurant_77.html
# Successfully saved: michelin_restaurant_html/restaurant_78.html
# Successfully saved: michelin_restaurant_html/restaurant_79.html
# Successfully saved: michelin_restaurant_html/restaurant_80.html
# Successfully saved: michelin_restaurant_html/restaurant_81.html
# Successfully saved: michelin_restaurant_html/restaurant_82.html
# Successfully saved: michelin_restaurant_html/restaurant_83.html
# Successfully saved: michelin_restaurant_html/restaurant_84.html
# Successfully saved: michelin_restaurant_html/restaurant_85.html
# Successfully saved: michelin_restaurant_html/restaurant_86.html
# Successfully saved: michelin_restaurant_html/restaurant_87.html
# Successfully saved: michelin_restaurant_html/restaurant_88.html
# Successfully saved: michelin_restaurant_html/restaurant_89.html
# Successfully saved: michelin_restaurant_html/restaurant_90.html
# Successfully saved: michelin_restaurant_html/restaurant_91.html
# Successfully saved: michelin_restaurant_html/restaurant_92.html
# Successfully saved: michelin_restaurant_html/restaurant_93.html
# Successfully saved: michelin_restaurant_html/restaurant_94.html
# Successfully saved: michelin_restaurant_html/restaurant_95.html
# Successfully saved: michelin_restaurant_html/restaurant_96.html
# Successfully saved: michelin_restaurant_html/restaurant_97.html
# Successfully saved: michelin_restaurant_html/restaurant_98.html
# Successfully saved: michelin_restaurant_html/restaurant_99.html
# Successfully saved: michelin_restaurant_html/restaurant_100.html
# Successfully saved: michelin_restaurant_html/restaurant_101.html
# Successfully saved: michelin_restaurant_html/restaurant_102.html
# Successfully saved: michelin_restaurant_html/restaurant_103.html
# Successfully saved: michelin_restaurant_html/restaurant_104.html
# Successfully saved: michelin_restaurant_html/restaurant_105.html
# Successfully saved: michelin_restaurant_html/restaurant_106.html
# Successfully saved: michelin_restaurant_html/restaurant_107.html
# Successfully saved: michelin_restaurant_html/restaurant_108.html
# Successfully saved: michelin_restaurant_html/restaurant_109.html
# Successfully saved: michelin_restaurant_html/restaurant_110.html
# Successfully saved: michelin_restaurant_html/restaurant_111.html
# Successfully saved: michelin_restaurant_html/restaurant_112.html
# Successfully saved: michelin_restaurant_html/restaurant_113.html
# Successfully saved: michelin_restaurant_html/restaurant_114.html
# Successfully saved: michelin_restaurant_html/restaurant_115.html
# Successfully saved: michelin_restaurant_html/restaurant_116.html
# Successfully saved: michelin_restaurant_html/restaurant_117.html
# Successfully saved: michelin_restaurant_html/restaurant_118.html
# Successfully saved: michelin_restaurant_html/restaurant_119.html
# Successfully saved: michelin_restaurant_html/restaurant_120.html
# Successfully saved: michelin_restaurant_html/restaurant_121.html
# Successfully saved: michelin_restaurant_html/restaurant_122.html
# Successfully saved: michelin_restaurant_html/restaurant_123.html
# Successfully saved: michelin_restaurant_html/restaurant_124.html
# Successfully saved: michelin_restaurant_html/restaurant_125.html
# Successfully saved: michelin_restaurant_html/restaurant_126.html
# Successfully saved: michelin_restaurant_html/restaurant_127.html
# Successfully saved: michelin_restaurant_html/restaurant_128.html
# Successfully saved: michelin_restaurant_html/restaurant_129.html
# Successfully saved: michelin_restaurant_html/restaurant_130.html
# Successfully saved: michelin_restaurant_html/restaurant_131.html
# Successfully saved: michelin_restaurant_html/restaurant_132.html
# Successfully saved: michelin_restaurant_html/restaurant_133.html
# Successfully saved: michelin_restaurant_html/restaurant_134.html
# Successfully saved: michelin_restaurant_html/restaurant_135.html
# Successfully saved: michelin_restaurant_html/restaurant_136.html
# Successfully saved: michelin_restaurant_html/restaurant_137.html
# Successfully saved: michelin_restaurant_html/restaurant_138.html
# Successfully saved: michelin_restaurant_html/restaurant_139.html
# Successfully saved: michelin_restaurant_html/restaurant_140.html
# Successfully saved: michelin_restaurant_html/restaurant_141.html
# Successfully saved: michelin_restaurant_html/restaurant_142.html
# Successfully saved: michelin_restaurant_html/restaurant_143.html
# Successfully saved: michelin_restaurant_html/restaurant_144.html
# Successfully saved: michelin_restaurant_html/restaurant_145.html
# Successfully saved: michelin_restaurant_html/restaurant_146.html
# Successfully saved: michelin_restaurant_html/restaurant_147.html
# Successfully saved: michelin_restaurant_html/restaurant_148.html
# Successfully saved: michelin_restaurant_html/restaurant_149.html
# Successfully saved: michelin_restaurant_html/restaurant_150.html
# Successfully saved: michelin_restaurant_html/restaurant_151.html
# Successfully saved: michelin_restaurant_html/restaurant_152.html
# Successfully saved: michelin_restaurant_html/restaurant_153.html
# Successfully saved: michelin_restaurant_html/restaurant_154.html
# Successfully saved: michelin_restaurant_html/restaurant_155.html
# Successfully saved: michelin_restaurant_html/restaurant_156.html
# Successfully saved: michelin_restaurant_html/restaurant_157.html
# Successfully saved: michelin_restaurant_html/restaurant_158.html
# Successfully saved: michelin_restaurant_html/restaurant_159.html
# Successfully saved: michelin_restaurant_html/restaurant_160.html
# Successfully saved: michelin_restaurant_html/restaurant_161.html
# Successfully saved: michelin_restaurant_html/restaurant_162.html
# Successfully saved: michelin_restaurant_html/restaurant_163.html
# Successfully saved: michelin_restaurant_html/restaurant_164.html
# Successfully saved: michelin_restaurant_html/restaurant_165.html
# Successfully saved: michelin_restaurant_html/restaurant_166.html
# Successfully saved: michelin_restaurant_html/restaurant_167.html
# Successfully saved: michelin_restaurant_html/restaurant_168.html
# Successfully saved: michelin_restaurant_html/restaurant_169.html
# Successfully saved: michelin_restaurant_html/restaurant_170.html
# Successfully saved: michelin_restaurant_html/restaurant_171.html
# Successfully saved: michelin_restaurant_html/restaurant_172.html
# Successfully saved: michelin_restaurant_html/restaurant_173.html
# Successfully saved: michelin_restaurant_html/restaurant_174.html
# Successfully saved: michelin_restaurant_html/restaurant_175.html
# Successfully saved: michelin_restaurant_html/restaurant_176.html
# Successfully saved: michelin_restaurant_html/restaurant_177.html
# Successfully saved: michelin_restaurant_html/restaurant_178.html
# Successfully saved: michelin_restaurant_html/restaurant_179.html
# Successfully saved: michelin_restaurant_html/restaurant_180.html
# Successfully saved: michelin_restaurant_html/restaurant_181.html
# Successfully saved: michelin_restaurant_html/restaurant_182.html
# Successfully saved: michelin_restaurant_html/restaurant_183.html
# Successfully saved: michelin_restaurant_html/restaurant_184.html
# Successfully saved: michelin_restaurant_html/restaurant_185.html
# Successfully saved: michelin_restaurant_html/restaurant_186.html
# Successfully saved: michelin_restaurant_html/restaurant_187.html
# Successfully saved: michelin_restaurant_html/restaurant_188.html
# Successfully saved: michelin_restaurant_html/restaurant_189.html
# Successfully saved: michelin_restaurant_html/restaurant_190.html
# Successfully saved: michelin_restaurant_html/restaurant_191.html
# Successfully saved: michelin_restaurant_html/restaurant_192.html
# Successfully saved: michelin_restaurant_html/restaurant_193.html
# Successfully saved: michelin_restaurant_html/restaurant_194.html
# Successfully saved: michelin_restaurant_html/restaurant_195.html
# Successfully saved: michelin_restaurant_html/restaurant_196.html
# Successfully saved: michelin_restaurant_html/restaurant_197.html
# Successfully saved: michelin_restaurant_html/restaurant_198.html
# Successfully saved: michelin_restaurant_html/restaurant_199.html
# Successfully saved: michelin_restaurant_html/restaurant_200.html
# Successfully saved: michelin_restaurant_html/restaurant_201.html
# Successfully saved: michelin_restaurant_html/restaurant_202.html
# Successfully saved: michelin_restaurant_html/restaurant_203.html
# Successfully saved: michelin_restaurant_html/restaurant_204.html
# Successfully saved: michelin_restaurant_html/restaurant_205.html
# Successfully saved: michelin_restaurant_html/restaurant_206.html
# Successfully saved: michelin_restaurant_html/restaurant_207.html
# Successfully saved: michelin_restaurant_html/restaurant_208.html
# Successfully saved: michelin_restaurant_html/restaurant_209.html
# Successfully saved: michelin_restaurant_html/restaurant_210.html
# Successfully saved: michelin_restaurant_html/restaurant_211.html
# Successfully saved: michelin_restaurant_html/restaurant_212.html
# Successfully saved: michelin_restaurant_html/restaurant_213.html
# Successfully saved: michelin_restaurant_html/restaurant_214.html
# Successfully saved: michelin_restaurant_html/restaurant_215.html
# Successfully saved: michelin_restaurant_html/restaurant_216.html
# Successfully saved: michelin_restaurant_html/restaurant_217.html
# Successfully saved: michelin_restaurant_html/restaurant_218.html
# Successfully saved: michelin_restaurant_html/restaurant_219.html
# Successfully saved: michelin_restaurant_html/restaurant_220.html
# Successfully saved: michelin_restaurant_html/restaurant_221.html
# Successfully saved: michelin_restaurant_html/restaurant_222.html
# Successfully saved: michelin_restaurant_html/restaurant_223.html
# Successfully saved: michelin_restaurant_html/restaurant_224.html
# Successfully saved: michelin_restaurant_html/restaurant_225.html
# Successfully saved: michelin_restaurant_html/restaurant_226.html
# Successfully saved: michelin_restaurant_html/restaurant_227.html
# Successfully saved: michelin_restaurant_html/restaurant_228.html
# Successfully saved: michelin_restaurant_html/restaurant_229.html
# Successfully saved: michelin_restaurant_html/restaurant_230.html
# Successfully saved: michelin_restaurant_html/restaurant_231.html
# Successfully saved: michelin_restaurant_html/restaurant_232.html
# Successfully saved: michelin_restaurant_html/restaurant_233.html
# Successfully saved: michelin_restaurant_html/restaurant_234.html
# Successfully saved: michelin_restaurant_html/restaurant_235.html
# Successfully saved: michelin_restaurant_html/restaurant_236.html
# Successfully saved: michelin_restaurant_html/restaurant_237.html
# Successfully saved: michelin_restaurant_html/restaurant_238.html
# Successfully saved: michelin_restaurant_html/restaurant_239.html
# Successfully saved: michelin_restaurant_html/restaurant_240.html
# Successfully saved: michelin_restaurant_html/restaurant_241.html
# Successfully saved: michelin_restaurant_html/restaurant_242.html
# Successfully saved: michelin_restaurant_html/restaurant_243.html
# Successfully saved: michelin_restaurant_html/restaurant_244.html
# Successfully saved: michelin_restaurant_html/restaurant_245.html
# Successfully saved: michelin_restaurant_html/restaurant_246.html
# Successfully saved: michelin_restaurant_html/restaurant_247.html
# Successfully saved: michelin_restaurant_html/restaurant_248.html
# Successfully saved: michelin_restaurant_html/restaurant_249.html
# Successfully saved: michelin_restaurant_html/restaurant_250.html
# Successfully saved: michelin_restaurant_html/restaurant_251.html
# Successfully saved: michelin_restaurant_html/restaurant_252.html
# Successfully saved: michelin_restaurant_html/restaurant_253.html
# Successfully saved: michelin_restaurant_html/restaurant_254.html
# Successfully saved: michelin_restaurant_html/restaurant_255.html
# Successfully saved: michelin_restaurant_html/restaurant_256.html
# Successfully saved: michelin_restaurant_html/restaurant_257.html
# Successfully saved: michelin_restaurant_html/restaurant_258.html
# Successfully saved: michelin_restaurant_html/restaurant_259.html
# Successfully saved: michelin_restaurant_html/restaurant_260.html
# Successfully saved: michelin_restaurant_html/restaurant_261.html
# Successfully saved: michelin_restaurant_html/restaurant_262.html
# Successfully saved: michelin_restaurant_html/restaurant_263.html
# Successfully saved: michelin_restaurant_html/restaurant_264.html
# Successfully saved: michelin_restaurant_html/restaurant_265.html
# Successfully saved: michelin_restaurant_html/restaurant_266.html
# Successfully saved: michelin_restaurant_html/restaurant_267.html
# Successfully saved: michelin_restaurant_html/restaurant_268.html
# Successfully saved: michelin_restaurant_html/restaurant_269.html
# Successfully saved: michelin_restaurant_html/restaurant_270.html
# Successfully saved: michelin_restaurant_html/restaurant_271.html
# Successfully saved: michelin_restaurant_html/restaurant_272.html
# Successfully saved: michelin_restaurant_html/restaurant_273.html
# Successfully saved: michelin_restaurant_html/restaurant_274.html
# Successfully saved: michelin_restaurant_html/restaurant_275.html
# Successfully saved: michelin_restaurant_html/restaurant_276.html
# Successfully saved: michelin_restaurant_html/restaurant_277.html
# Successfully saved: michelin_restaurant_html/restaurant_278.html
# Successfully saved: michelin_restaurant_html/restaurant_279.html
# Successfully saved: michelin_restaurant_html/restaurant_280.html
# Successfully saved: michelin_restaurant_html/restaurant_281.html
# Successfully saved: michelin_restaurant_html/restaurant_282.html
# Successfully saved: michelin_restaurant_html/restaurant_283.html
# Successfully saved: michelin_restaurant_html/restaurant_284.html
# Successfully saved: michelin_restaurant_html/restaurant_285.html
# Successfully saved: michelin_restaurant_html/restaurant_286.html
# Successfully saved: michelin_restaurant_html/restaurant_287.html
# Successfully saved: michelin_restaurant_html/restaurant_288.html
# Successfully saved: michelin_restaurant_html/restaurant_289.html
# Successfully saved: michelin_restaurant_html/restaurant_290.html
# Successfully saved: michelin_restaurant_html/restaurant_291.html
# Successfully saved: michelin_restaurant_html/restaurant_292.html
# Successfully saved: michelin_restaurant_html/restaurant_293.html
# Successfully saved: michelin_restaurant_html/restaurant_294.html
# Successfully saved: michelin_restaurant_html/restaurant_295.html
# Successfully saved: michelin_restaurant_html/restaurant_296.html
# Successfully saved: michelin_restaurant_html/restaurant_297.html
# Successfully saved: michelin_restaurant_html/restaurant_298.html
# Successfully saved: michelin_restaurant_html/restaurant_299.html
# Successfully saved: michelin_restaurant_html/restaurant_300.html
# Successfully saved: michelin_restaurant_html/restaurant_301.html
# Successfully saved: michelin_restaurant_html/restaurant_302.html
# Successfully saved: michelin_restaurant_html/restaurant_303.html
# Successfully saved: michelin_restaurant_html/restaurant_304.html
# Successfully saved: michelin_restaurant_html/restaurant_305.html
# Successfully saved: michelin_restaurant_html/restaurant_306.html
# Successfully saved: michelin_restaurant_html/restaurant_307.html
# Successfully saved: michelin_restaurant_html/restaurant_308.html
# Successfully saved: michelin_restaurant_html/restaurant_309.html
# Successfully saved: michelin_restaurant_html/restaurant_310.html
# Successfully saved: michelin_restaurant_html/restaurant_311.html
# Successfully saved: michelin_restaurant_html/restaurant_312.html
# Successfully saved: michelin_restaurant_html/restaurant_313.html
# Successfully saved: michelin_restaurant_html/restaurant_314.html
# Successfully saved: michelin_restaurant_html/restaurant_315.html
# Successfully saved: michelin_restaurant_html/restaurant_316.html
# Successfully saved: michelin_restaurant_html/restaurant_317.html
# Successfully saved: michelin_restaurant_html/restaurant_318.html
# Successfully saved: michelin_restaurant_html/restaurant_319.html
# Successfully saved: michelin_restaurant_html/restaurant_320.html
# Successfully saved: michelin_restaurant_html/restaurant_321.html
# Successfully saved: michelin_restaurant_html/restaurant_322.html
# Successfully saved: michelin_restaurant_html/restaurant_323.html
# Successfully saved: michelin_restaurant_html/restaurant_324.html
# Successfully saved: michelin_restaurant_html/restaurant_325.html
# Successfully saved: michelin_restaurant_html/restaurant_326.html
# Successfully saved: michelin_restaurant_html/restaurant_327.html
# Successfully saved: michelin_restaurant_html/restaurant_328.html
# Successfully saved: michelin_restaurant_html/restaurant_329.html
# Successfully saved: michelin_restaurant_html/restaurant_330.html
# Successfully saved: michelin_restaurant_html/restaurant_331.html
# Successfully saved: michelin_restaurant_html/restaurant_332.html
# Successfully saved: michelin_restaurant_html/restaurant_333.html
# Successfully saved: michelin_restaurant_html/restaurant_334.html
# Successfully saved: michelin_restaurant_html/restaurant_335.html
# Successfully saved: michelin_restaurant_html/restaurant_336.html
# Successfully saved: michelin_restaurant_html/restaurant_337.html
# Successfully saved: michelin_restaurant_html/restaurant_338.html
# Successfully saved: michelin_restaurant_html/restaurant_339.html
# Successfully saved: michelin_restaurant_html/restaurant_340.html
# Successfully saved: michelin_restaurant_html/restaurant_341.html
# Successfully saved: michelin_restaurant_html/restaurant_342.html
# Successfully saved: michelin_restaurant_html/restaurant_343.html
# Successfully saved: michelin_restaurant_html/restaurant_344.html
# Successfully saved: michelin_restaurant_html/restaurant_345.html
# Successfully saved: michelin_restaurant_html/restaurant_346.html
# Successfully saved: michelin_restaurant_html/restaurant_347.html
# Successfully saved: michelin_restaurant_html/restaurant_348.html
# Successfully saved: michelin_restaurant_html/restaurant_349.html
# Successfully saved: michelin_restaurant_html/restaurant_350.html
# Successfully saved: michelin_restaurant_html/restaurant_351.html
# Successfully saved: michelin_restaurant_html/restaurant_352.html
# Successfully saved: michelin_restaurant_html/restaurant_353.html
# Successfully saved: michelin_restaurant_html/restaurant_354.html
# Successfully saved: michelin_restaurant_html/restaurant_355.html
# Successfully saved: michelin_restaurant_html/restaurant_356.html
# Successfully saved: michelin_restaurant_html/restaurant_357.html
# Successfully saved: michelin_restaurant_html/restaurant_358.html
# Successfully saved: michelin_restaurant_html/restaurant_359.html
# Successfully saved: michelin_restaurant_html/restaurant_360.html
# Successfully saved: michelin_restaurant_html/restaurant_361.html
# Successfully saved: michelin_restaurant_html/restaurant_362.html
# Successfully saved: michelin_restaurant_html/restaurant_363.html
# Successfully saved: michelin_restaurant_html/restaurant_364.html
# Successfully saved: michelin_restaurant_html/restaurant_365.html
# Successfully saved: michelin_restaurant_html/restaurant_366.html
# Successfully saved: michelin_restaurant_html/restaurant_367.html
# Successfully saved: michelin_restaurant_html/restaurant_368.html
# Successfully saved: michelin_restaurant_html/restaurant_369.html
# Successfully saved: michelin_restaurant_html/restaurant_370.html
# Successfully saved: michelin_restaurant_html/restaurant_371.html
# Successfully saved: michelin_restaurant_html/restaurant_372.html
# Successfully saved: michelin_restaurant_html/restaurant_373.html
# Successfully saved: michelin_restaurant_html/restaurant_374.html
# Successfully saved: michelin_restaurant_html/restaurant_375.html
# Successfully saved: michelin_restaurant_html/restaurant_376.html
# Successfully saved: michelin_restaurant_html/restaurant_377.html
# Successfully saved: michelin_restaurant_html/restaurant_378.html
# Successfully saved: michelin_restaurant_html/restaurant_379.html
# Successfully saved: michelin_restaurant_html/restaurant_380.html
# Successfully saved: michelin_restaurant_html/restaurant_381.html
# Successfully saved: michelin_restaurant_html/restaurant_382.html
# Successfully saved: michelin_restaurant_html/restaurant_383.html
# Successfully saved: michelin_restaurant_html/restaurant_384.html
# Successfully saved: michelin_restaurant_html/restaurant_385.html
# Successfully saved: michelin_restaurant_html/restaurant_386.html
# Successfully saved: michelin_restaurant_html/restaurant_387.html
# Successfully saved: michelin_restaurant_html/restaurant_388.html
# Successfully saved: michelin_restaurant_html/restaurant_389.html
# Successfully saved: michelin_restaurant_html/restaurant_390.html
# Successfully saved: michelin_restaurant_html/restaurant_391.html
# Successfully saved: michelin_restaurant_html/restaurant_392.html
# Successfully saved: michelin_restaurant_html/restaurant_393.html
# Successfully saved: michelin_restaurant_html/restaurant_394.html
# Successfully saved: michelin_restaurant_html/restaurant_395.html
# Successfully saved: michelin_restaurant_html/restaurant_396.html
# Successfully saved: michelin_restaurant_html/restaurant_397.html
# Successfully saved: michelin_restaurant_html/restaurant_398.html
# Successfully saved: michelin_restaurant_html/restaurant_399.html
# Successfully saved: michelin_restaurant_html/restaurant_400.html
# Successfully saved: michelin_restaurant_html/restaurant_401.html
# Successfully saved: michelin_restaurant_html/restaurant_402.html
# Successfully saved: michelin_restaurant_html/restaurant_403.html
# Successfully saved: michelin_restaurant_html/restaurant_404.html
# Successfully saved: michelin_restaurant_html/restaurant_405.html
# Successfully saved: michelin_restaurant_html/restaurant_406.html
# Successfully saved: michelin_restaurant_html/restaurant_407.html
# Successfully saved: michelin_restaurant_html/restaurant_408.html
# Successfully saved: michelin_restaurant_html/restaurant_409.html
# Successfully saved: michelin_restaurant_html/restaurant_410.html
# Successfully saved: michelin_restaurant_html/restaurant_411.html
# Successfully saved: michelin_restaurant_html/restaurant_412.html
# Successfully saved: michelin_restaurant_html/restaurant_413.html
# Successfully saved: michelin_restaurant_html/restaurant_414.html
# Successfully saved: michelin_restaurant_html/restaurant_415.html
# Successfully saved: michelin_restaurant_html/restaurant_416.html
# Successfully saved: michelin_restaurant_html/restaurant_417.html
# Successfully saved: michelin_restaurant_html/restaurant_418.html
# Successfully saved: michelin_restaurant_html/restaurant_419.html
# Successfully saved: michelin_restaurant_html/restaurant_420.html
# Successfully saved: michelin_restaurant_html/restaurant_421.html
# Successfully saved: michelin_restaurant_html/restaurant_422.html
# Successfully saved: michelin_restaurant_html/restaurant_423.html
# Successfully saved: michelin_restaurant_html/restaurant_424.html
# Successfully saved: michelin_restaurant_html/restaurant_425.html
# Successfully saved: michelin_restaurant_html/restaurant_426.html
# Successfully saved: michelin_restaurant_html/restaurant_427.html
# Successfully saved: michelin_restaurant_html/restaurant_428.html
# Successfully saved: michelin_restaurant_html/restaurant_429.html
# Successfully saved: michelin_restaurant_html/restaurant_430.html
# Successfully saved: michelin_restaurant_html/restaurant_431.html
# Successfully saved: michelin_restaurant_html/restaurant_432.html
# Successfully saved: michelin_restaurant_html/restaurant_433.html
# Successfully saved: michelin_restaurant_html/restaurant_434.html
# Successfully saved: michelin_restaurant_html/restaurant_435.html
# Successfully saved: michelin_restaurant_html/restaurant_436.html
# Successfully saved: michelin_restaurant_html/restaurant_437.html
# Successfully saved: michelin_restaurant_html/restaurant_438.html
# Successfully saved: michelin_restaurant_html/restaurant_439.html
# Successfully saved: michelin_restaurant_html/restaurant_440.html
# Successfully saved: michelin_restaurant_html/restaurant_441.html
# Successfully saved: michelin_restaurant_html/restaurant_442.html
# Successfully saved: michelin_restaurant_html/restaurant_443.html
# Successfully saved: michelin_restaurant_html/restaurant_444.html
# Successfully saved: michelin_restaurant_html/restaurant_445.html
# Successfully saved: michelin_restaurant_html/restaurant_446.html
# Successfully saved: michelin_restaurant_html/restaurant_447.html
# Successfully saved: michelin_restaurant_html/restaurant_448.html
# Successfully saved: michelin_restaurant_html/restaurant_449.html
# Successfully saved: michelin_restaurant_html/restaurant_450.html
# Successfully saved: michelin_restaurant_html/restaurant_451.html
# Successfully saved: michelin_restaurant_html/restaurant_452.html
# Successfully saved: michelin_restaurant_html/restaurant_453.html
# Successfully saved: michelin_restaurant_html/restaurant_454.html
# Successfully saved: michelin_restaurant_html/restaurant_455.html
# Successfully saved: michelin_restaurant_html/restaurant_456.html
# Successfully saved: michelin_restaurant_html/restaurant_457.html
# Successfully saved: michelin_restaurant_html/restaurant_458.html
# Successfully saved: michelin_restaurant_html/restaurant_459.html
# Successfully saved: michelin_restaurant_html/restaurant_460.html
# Successfully saved: michelin_restaurant_html/restaurant_461.html
# Successfully saved: michelin_restaurant_html/restaurant_462.html
# Successfully saved: michelin_restaurant_html/restaurant_463.html
# Successfully saved: michelin_restaurant_html/restaurant_464.html
# Successfully saved: michelin_restaurant_html/restaurant_465.html
# Successfully saved: michelin_restaurant_html/restaurant_466.html
# Successfully saved: michelin_restaurant_html/restaurant_467.html
# Successfully saved: michelin_restaurant_html/restaurant_468.html
# Successfully saved: michelin_restaurant_html/restaurant_469.html
# Successfully saved: michelin_restaurant_html/restaurant_470.html
# Successfully saved: michelin_restaurant_html/restaurant_471.html
# Successfully saved: michelin_restaurant_html/restaurant_472.html
# Successfully saved: michelin_restaurant_html/restaurant_473.html
# Successfully saved: michelin_restaurant_html/restaurant_474.html
# Successfully saved: michelin_restaurant_html/restaurant_475.html
# Successfully saved: michelin_restaurant_html/restaurant_476.html
# Successfully saved: michelin_restaurant_html/restaurant_477.html
# Successfully saved: michelin_restaurant_html/restaurant_478.html
# Successfully saved: michelin_restaurant_html/restaurant_479.html
# Successfully saved: michelin_restaurant_html/restaurant_480.html
# Successfully saved: michelin_restaurant_html/restaurant_481.html
# Successfully saved: michelin_restaurant_html/restaurant_482.html
# Successfully saved: michelin_restaurant_html/restaurant_483.html
# Successfully saved: michelin_restaurant_html/restaurant_484.html
# Successfully saved: michelin_restaurant_html/restaurant_485.html
# Successfully saved: michelin_restaurant_html/restaurant_486.html
# Successfully saved: michelin_restaurant_html/restaurant_487.html
# Successfully saved: michelin_restaurant_html/restaurant_488.html
# Successfully saved: michelin_restaurant_html/restaurant_489.html
# Successfully saved: michelin_restaurant_html/restaurant_490.html
# Successfully saved: michelin_restaurant_html/restaurant_491.html
# Successfully saved: michelin_restaurant_html/restaurant_492.html
# Successfully saved: michelin_restaurant_html/restaurant_493.html
# Successfully saved: michelin_restaurant_html/restaurant_494.html
# Successfully saved: michelin_restaurant_html/restaurant_495.html
# Successfully saved: michelin_restaurant_html/restaurant_496.html
# Successfully saved: michelin_restaurant_html/restaurant_497.html
# Successfully saved: michelin_restaurant_html/restaurant_498.html
# Successfully saved: michelin_restaurant_html/restaurant_499.html
# Successfully saved: michelin_restaurant_html/restaurant_500.html
# Successfully saved: michelin_restaurant_html/restaurant_501.html
# Successfully saved: michelin_restaurant_html/restaurant_502.html
# Successfully saved: michelin_restaurant_html/restaurant_503.html
# Successfully saved: michelin_restaurant_html/restaurant_504.html
# Successfully saved: michelin_restaurant_html/restaurant_505.html
# Successfully saved: michelin_restaurant_html/restaurant_506.html
# Successfully saved: michelin_restaurant_html/restaurant_507.html
# Successfully saved: michelin_restaurant_html/restaurant_508.html
# Successfully saved: michelin_restaurant_html/restaurant_509.html
# Successfully saved: michelin_restaurant_html/restaurant_510.html
# Successfully saved: michelin_restaurant_html/restaurant_511.html
# Successfully saved: michelin_restaurant_html/restaurant_512.html
# Successfully saved: michelin_restaurant_html/restaurant_513.html
# Successfully saved: michelin_restaurant_html/restaurant_514.html
# Successfully saved: michelin_restaurant_html/restaurant_515.html
# Successfully saved: michelin_restaurant_html/restaurant_516.html
# Successfully saved: michelin_restaurant_html/restaurant_517.html
# Successfully saved: michelin_restaurant_html/restaurant_518.html
# Successfully saved: michelin_restaurant_html/restaurant_519.html
# Successfully saved: michelin_restaurant_html/restaurant_520.html
# Successfully saved: michelin_restaurant_html/restaurant_521.html
# Successfully saved: michelin_restaurant_html/restaurant_522.html
# Successfully saved: michelin_restaurant_html/restaurant_523.html
# Successfully saved: michelin_restaurant_html/restaurant_524.html
# Successfully saved: michelin_restaurant_html/restaurant_525.html
# Successfully saved: michelin_restaurant_html/restaurant_526.html
# Successfully saved: michelin_restaurant_html/restaurant_527.html
# Successfully saved: michelin_restaurant_html/restaurant_528.html
# Successfully saved: michelin_restaurant_html/restaurant_529.html
# Successfully saved: michelin_restaurant_html/restaurant_530.html
# Successfully saved: michelin_restaurant_html/restaurant_531.html
# Successfully saved: michelin_restaurant_html/restaurant_532.html
# Successfully saved: michelin_restaurant_html/restaurant_533.html
# Successfully saved: michelin_restaurant_html/restaurant_534.html
# Successfully saved: michelin_restaurant_html/restaurant_535.html
# Successfully saved: michelin_restaurant_html/restaurant_536.html
# Successfully saved: michelin_restaurant_html/restaurant_537.html
# Successfully saved: michelin_restaurant_html/restaurant_538.html
# Successfully saved: michelin_restaurant_html/restaurant_539.html
# Successfully saved: michelin_restaurant_html/restaurant_540.html
# Successfully saved: michelin_restaurant_html/restaurant_541.html
# Successfully saved: michelin_restaurant_html/restaurant_542.html
# Successfully saved: michelin_restaurant_html/restaurant_543.html
# Successfully saved: michelin_restaurant_html/restaurant_544.html
# Successfully saved: michelin_restaurant_html/restaurant_545.html
# Successfully saved: michelin_restaurant_html/restaurant_546.html
# Successfully saved: michelin_restaurant_html/restaurant_547.html
# Successfully saved: michelin_restaurant_html/restaurant_548.html
# Successfully saved: michelin_restaurant_html/restaurant_549.html
# Successfully saved: michelin_restaurant_html/restaurant_550.html
# Successfully saved: michelin_restaurant_html/restaurant_551.html
# Successfully saved: michelin_restaurant_html/restaurant_552.html
# Successfully saved: michelin_restaurant_html/restaurant_553.html
# Successfully saved: michelin_restaurant_html/restaurant_554.html
# Successfully saved: michelin_restaurant_html/restaurant_555.html
# Successfully saved: michelin_restaurant_html/restaurant_556.html
# Successfully saved: michelin_restaurant_html/restaurant_557.html
# Successfully saved: michelin_restaurant_html/restaurant_558.html
# Successfully saved: michelin_restaurant_html/restaurant_559.html
# Successfully saved: michelin_restaurant_html/restaurant_560.html
# Successfully saved: michelin_restaurant_html/restaurant_561.html
# Successfully saved: michelin_restaurant_html/restaurant_562.html
# Successfully saved: michelin_restaurant_html/restaurant_563.html
# Successfully saved: michelin_restaurant_html/restaurant_564.html
# Successfully saved: michelin_restaurant_html/restaurant_565.html
# Successfully saved: michelin_restaurant_html/restaurant_566.html
# Successfully saved: michelin_restaurant_html/restaurant_567.html
# Successfully saved: michelin_restaurant_html/restaurant_568.html
# Successfully saved: michelin_restaurant_html/restaurant_569.html
# Successfully saved: michelin_restaurant_html/restaurant_570.html
# Successfully saved: michelin_restaurant_html/restaurant_571.html
# Successfully saved: michelin_restaurant_html/restaurant_572.html
# Successfully saved: michelin_restaurant_html/restaurant_573.html
# Successfully saved: michelin_restaurant_html/restaurant_574.html
# Successfully saved: michelin_restaurant_html/restaurant_575.html
# Successfully saved: michelin_restaurant_html/restaurant_576.html
# Successfully saved: michelin_restaurant_html/restaurant_577.html
# Successfully saved: michelin_restaurant_html/restaurant_578.html
# Successfully saved: michelin_restaurant_html/restaurant_579.html
# Successfully saved: michelin_restaurant_html/restaurant_580.html
# Successfully saved: michelin_restaurant_html/restaurant_581.html
# Successfully saved: michelin_restaurant_html/restaurant_582.html
# Successfully saved: michelin_restaurant_html/restaurant_583.html
# Successfully saved: michelin_restaurant_html/restaurant_584.html
# Successfully saved: michelin_restaurant_html/restaurant_585.html
# Successfully saved: michelin_restaurant_html/restaurant_586.html
# Successfully saved: michelin_restaurant_html/restaurant_587.html
# Successfully saved: michelin_restaurant_html/restaurant_588.html
# Successfully saved: michelin_restaurant_html/restaurant_589.html
# Successfully saved: michelin_restaurant_html/restaurant_590.html
# Successfully saved: michelin_restaurant_html/restaurant_591.html
# Successfully saved: michelin_restaurant_html/restaurant_592.html
# Successfully saved: michelin_restaurant_html/restaurant_593.html
# Successfully saved: michelin_restaurant_html/restaurant_594.html
# Successfully saved: michelin_restaurant_html/restaurant_595.html
# Successfully saved: michelin_restaurant_html/restaurant_596.html
# Successfully saved: michelin_restaurant_html/restaurant_597.html
# Successfully saved: michelin_restaurant_html/restaurant_598.html
# Successfully saved: michelin_restaurant_html/restaurant_599.html
# Successfully saved: michelin_restaurant_html/restaurant_600.html
# Successfully saved: michelin_restaurant_html/restaurant_601.html
# Successfully saved: michelin_restaurant_html/restaurant_602.html
# Successfully saved: michelin_restaurant_html/restaurant_603.html
# Successfully saved: michelin_restaurant_html/restaurant_604.html
# Successfully saved: michelin_restaurant_html/restaurant_605.html
# Successfully saved: michelin_restaurant_html/restaurant_606.html
# Successfully saved: michelin_restaurant_html/restaurant_607.html
# Successfully saved: michelin_restaurant_html/restaurant_608.html
# Successfully saved: michelin_restaurant_html/restaurant_609.html
# Successfully saved: michelin_restaurant_html/restaurant_610.html
# Successfully saved: michelin_restaurant_html/restaurant_611.html
# Successfully saved: michelin_restaurant_html/restaurant_612.html
# Successfully saved: michelin_restaurant_html/restaurant_613.html
# Successfully saved: michelin_restaurant_html/restaurant_614.html
# Successfully saved: michelin_restaurant_html/restaurant_615.html
# Successfully saved: michelin_restaurant_html/restaurant_616.html
# Successfully saved: michelin_restaurant_html/restaurant_617.html
# Successfully saved: michelin_restaurant_html/restaurant_618.html
# Successfully saved: michelin_restaurant_html/restaurant_619.html
# Successfully saved: michelin_restaurant_html/restaurant_620.html
# Successfully saved: michelin_restaurant_html/restaurant_621.html
# Successfully saved: michelin_restaurant_html/restaurant_622.html
# Successfully saved: michelin_restaurant_html/restaurant_623.html
# Successfully saved: michelin_restaurant_html/restaurant_624.html
# Successfully saved: michelin_restaurant_html/restaurant_625.html
# Successfully saved: michelin_restaurant_html/restaurant_626.html
# Successfully saved: michelin_restaurant_html/restaurant_627.html
# Successfully saved: michelin_restaurant_html/restaurant_628.html
# Successfully saved: michelin_restaurant_html/restaurant_629.html
# Successfully saved: michelin_restaurant_html/restaurant_630.html
# Successfully saved: michelin_restaurant_html/restaurant_631.html
# Successfully saved: michelin_restaurant_html/restaurant_632.html
# Successfully saved: michelin_restaurant_html/restaurant_633.html
# Successfully saved: michelin_restaurant_html/restaurant_634.html
# Successfully saved: michelin_restaurant_html/restaurant_635.html
# Successfully saved: michelin_restaurant_html/restaurant_636.html
# Successfully saved: michelin_restaurant_html/restaurant_637.html
# Successfully saved: michelin_restaurant_html/restaurant_638.html
# Successfully saved: michelin_restaurant_html/restaurant_639.html
# Successfully saved: michelin_restaurant_html/restaurant_640.html
# Successfully saved: michelin_restaurant_html/restaurant_641.html
# Successfully saved: michelin_restaurant_html/restaurant_642.html
# Successfully saved: michelin_restaurant_html/restaurant_643.html
# Successfully saved: michelin_restaurant_html/restaurant_644.html
# Successfully saved: michelin_restaurant_html/restaurant_645.html
# Successfully saved: michelin_restaurant_html/restaurant_646.html
# Successfully saved: michelin_restaurant_html/restaurant_647.html
# Successfully saved: michelin_restaurant_html/restaurant_648.html
# Successfully saved: michelin_restaurant_html/restaurant_649.html
# Successfully saved: michelin_restaurant_html/restaurant_650.html
# Successfully saved: michelin_restaurant_html/restaurant_651.html
# Successfully saved: michelin_restaurant_html/restaurant_652.html
# Successfully saved: michelin_restaurant_html/restaurant_653.html
# Successfully saved: michelin_restaurant_html/restaurant_654.html
# Successfully saved: michelin_restaurant_html/restaurant_655.html
# Successfully saved: michelin_restaurant_html/restaurant_656.html
# Successfully saved: michelin_restaurant_html/restaurant_657.html
# Successfully saved: michelin_restaurant_html/restaurant_658.html
# Successfully saved: michelin_restaurant_html/restaurant_659.html
# Successfully saved: michelin_restaurant_html/restaurant_660.html
# Successfully saved: michelin_restaurant_html/restaurant_661.html
# Successfully saved: michelin_restaurant_html/restaurant_662.html
# Successfully saved: michelin_restaurant_html/restaurant_663.html
# Successfully saved: michelin_restaurant_html/restaurant_664.html
# Successfully saved: michelin_restaurant_html/restaurant_665.html
# Successfully saved: michelin_restaurant_html/restaurant_666.html
# Successfully saved: michelin_restaurant_html/restaurant_667.html
# Successfully saved: michelin_restaurant_html/restaurant_668.html
# Successfully saved: michelin_restaurant_html/restaurant_669.html
# Successfully saved: michelin_restaurant_html/restaurant_670.html
# Successfully saved: michelin_restaurant_html/restaurant_671.html
# Successfully saved: michelin_restaurant_html/restaurant_672.html
# Successfully saved: michelin_restaurant_html/restaurant_673.html
# Successfully saved: michelin_restaurant_html/restaurant_674.html
# Successfully saved: michelin_restaurant_html/restaurant_675.html
# Successfully saved: michelin_restaurant_html/restaurant_676.html
# Successfully saved: michelin_restaurant_html/restaurant_677.html
# Successfully saved: michelin_restaurant_html/restaurant_678.html
# ...
# Successfully saved: michelin_restaurant_html/restaurant_1818.html
# Successfully saved: michelin_restaurant_html/restaurant_1819.html
# Successfully saved: michelin_restaurant_html/restaurant_1820.html
# Successfully saved: michelin_restaurant_html/restaurant_1821.html
# Successfully saved: michelin_restaurant_html/restaurant_1822.html
# Successfully saved: michelin_restaurant_html/restaurant_1823.html
# Successfully saved: michelin_restaurant_html/restaurant_1824.html
# Successfully saved: michelin_restaurant_html/restaurant_1825.html
# Successfully saved: michelin_restaurant_html/restaurant_1826.html
# Successfully saved: michelin_restaurant_html/restaurant_1827.html
# Successfully saved: michelin_restaurant_html/restaurant_1828.html
# Successfully saved: michelin_restaurant_html/restaurant_1829.html
# Successfully saved: michelin_restaurant_html/restaurant_1830.html
# Successfully saved: michelin_restaurant_html/restaurant_1831.html
# Successfully saved: michelin_restaurant_html/restaurant_1832.html
# Successfully saved: michelin_restaurant_html/restaurant_1833.html
# Successfully saved: michelin_restaurant_html/restaurant_1834.html
# Successfully saved: michelin_restaurant_html/restaurant_1835.html
# Successfully saved: michelin_restaurant_html/restaurant_1836.html
# Successfully saved: michelin_restaurant_html/restaurant_1837.html
# Successfully saved: michelin_restaurant_html/restaurant_1838.html
# Successfully saved: michelin_restaurant_html/restaurant_1839.html
# Successfully saved: michelin_restaurant_html/restaurant_1840.html
# Successfully saved: michelin_restaurant_html/restaurant_1841.html
# Successfully saved: michelin_restaurant_html/restaurant_1842.html
# Successfully saved: michelin_restaurant_html/restaurant_1843.html
# Successfully saved: michelin_restaurant_html/restaurant_1844.html
# Successfully saved: michelin_restaurant_html/restaurant_1845.html
# Successfully saved: michelin_restaurant_html/restaurant_1846.html
# Successfully saved: michelin_restaurant_html/restaurant_1847.html
# Successfully saved: michelin_restaurant_html/restaurant_1848.html
# Successfully saved: michelin_restaurant_html/restaurant_1849.html
# Successfully saved: michelin_restaurant_html/restaurant_1850.html
# Successfully saved: michelin_restaurant_html/restaurant_1851.html
# Successfully saved: michelin_restaurant_html/restaurant_1852.html
# Successfully saved: michelin_restaurant_html/restaurant_1853.html
# Successfully saved: michelin_restaurant_html/restaurant_1854.html
# Successfully saved: michelin_restaurant_html/restaurant_1855.html
# Successfully saved: michelin_restaurant_html/restaurant_1856.html
# Successfully saved: michelin_restaurant_html/restaurant_1857.html
# Successfully saved: michelin_restaurant_html/restaurant_1858.html
# Successfully saved: michelin_restaurant_html/restaurant_1859.html
# Successfully saved: michelin_restaurant_html/restaurant_1860.html
# Successfully saved: michelin_restaurant_html/restaurant_1861.html
# Successfully saved: michelin_restaurant_html/restaurant_1862.html
# Successfully saved: michelin_restaurant_html/restaurant_1863.html
# Successfully saved: michelin_restaurant_html/restaurant_1864.html
# Successfully saved: michelin_restaurant_html/restaurant_1865.html
# Successfully saved: michelin_restaurant_html/restaurant_1866.html
# Successfully saved: michelin_restaurant_html/restaurant_1867.html
# Successfully saved: michelin_restaurant_html/restaurant_1868.html
# Successfully saved: michelin_restaurant_html/restaurant_1869.html
# Successfully saved: michelin_restaurant_html/restaurant_1870.html
# Successfully saved: michelin_restaurant_html/restaurant_1871.html
# Successfully saved: michelin_restaurant_html/restaurant_1872.html
# Successfully saved: michelin_restaurant_html/restaurant_1873.html
# Successfully saved: michelin_restaurant_html/restaurant_1874.html
# Successfully saved: michelin_restaurant_html/restaurant_1875.html
# Successfully saved: michelin_restaurant_html/restaurant_1876.html
# Successfully saved: michelin_restaurant_html/restaurant_1877.html
# Successfully saved: michelin_restaurant_html/restaurant_1878.html
# Successfully saved: michelin_restaurant_html/restaurant_1879.html
# Successfully saved: michelin_restaurant_html/restaurant_1880.html
# Successfully saved: michelin_restaurant_html/restaurant_1881.html
# Successfully saved: michelin_restaurant_html/restaurant_1882.html
# Successfully saved: michelin_restaurant_html/restaurant_1883.html
# Successfully saved: michelin_restaurant_html/restaurant_1884.html
# Successfully saved: michelin_restaurant_html/restaurant_1885.html
# Successfully saved: michelin_restaurant_html/restaurant_1886.html
# Successfully saved: michelin_restaurant_html/restaurant_1887.html
# Successfully saved: michelin_restaurant_html/restaurant_1888.html
# Successfully saved: michelin_restaurant_html/restaurant_1889.html
# Successfully saved: michelin_restaurant_html/restaurant_1890.html
# Successfully saved: michelin_restaurant_html/restaurant_1891.html
# Successfully saved: michelin_restaurant_html/restaurant_1892.html
# Successfully saved: michelin_restaurant_html/restaurant_1893.html
# Successfully saved: michelin_restaurant_html/restaurant_1894.html
# Successfully saved: michelin_restaurant_html/restaurant_1895.html
# Successfully saved: michelin_restaurant_html/restaurant_1896.html
# Successfully saved: michelin_restaurant_html/restaurant_1897.html
# Successfully saved: michelin_restaurant_html/restaurant_1898.html
# Successfully saved: michelin_restaurant_html/restaurant_1899.html
# Successfully saved: michelin_restaurant_html/restaurant_1900.html
# Successfully saved: michelin_restaurant_html/restaurant_1901.html
# Successfully saved: michelin_restaurant_html/restaurant_1902.html
# Successfully saved: michelin_restaurant_html/restaurant_1903.html
# Successfully saved: michelin_restaurant_html/restaurant_1904.html
# Successfully saved: michelin_restaurant_html/restaurant_1905.html
# Successfully saved: michelin_restaurant_html/restaurant_1906.html
# Successfully saved: michelin_restaurant_html/restaurant_1907.html
# Successfully saved: michelin_restaurant_html/restaurant_1908.html
# Successfully saved: michelin_restaurant_html/restaurant_1909.html
# Successfully saved: michelin_restaurant_html/restaurant_1910.html
# Successfully saved: michelin_restaurant_html/restaurant_1911.html
# Successfully saved: michelin_restaurant_html/restaurant_1912.html
# Successfully saved: michelin_restaurant_html/restaurant_1913.html
# Successfully saved: michelin_restaurant_html/restaurant_1914.html
# Successfully saved: michelin_restaurant_html/restaurant_1915.html
# Successfully saved: michelin_restaurant_html/restaurant_1916.html
# Successfully saved: michelin_restaurant_html/restaurant_1917.html
# Successfully saved: michelin_restaurant_html/restaurant_1918.html
# Successfully saved: michelin_restaurant_html/restaurant_1919.html
# Successfully saved: michelin_restaurant_html/restaurant_1920.html
# Successfully saved: michelin_restaurant_html/restaurant_1921.html
# Successfully saved: michelin_restaurant_html/restaurant_1922.html
# Successfully saved: michelin_restaurant_html/restaurant_1923.html
# Successfully saved: michelin_restaurant_html/restaurant_1924.html
# Successfully saved: michelin_restaurant_html/restaurant_1925.html
# Successfully saved: michelin_restaurant_html/restaurant_1926.html
# Successfully saved: michelin_restaurant_html/restaurant_1927.html
# Successfully saved: michelin_restaurant_html/restaurant_1928.html
# Successfully saved: michelin_restaurant_html/restaurant_1929.html
# Successfully saved: michelin_restaurant_html/restaurant_1930.html
# Successfully saved: michelin_restaurant_html/restaurant_1931.html
# Successfully saved: michelin_restaurant_html/restaurant_1932.html
# Successfully saved: michelin_restaurant_html/restaurant_1933.html
# Successfully saved: michelin_restaurant_html/restaurant_1934.html
# Successfully saved: michelin_restaurant_html/restaurant_1935.html
# Successfully saved: michelin_restaurant_html/restaurant_1936.html
# Successfully saved: michelin_restaurant_html/restaurant_1937.html
# Successfully saved: michelin_restaurant_html/restaurant_1938.html
# Successfully saved: michelin_restaurant_html/restaurant_1939.html
# Successfully saved: michelin_restaurant_html/restaurant_1940.html
# Successfully saved: michelin_restaurant_html/restaurant_1941.html
# Successfully saved: michelin_restaurant_html/restaurant_1942.html
# Successfully saved: michelin_restaurant_html/restaurant_1943.html
# Successfully saved: michelin_restaurant_html/restaurant_1944.html
# Successfully saved: michelin_restaurant_html/restaurant_1945.html
# Successfully saved: michelin_restaurant_html/restaurant_1946.html
# Successfully saved: michelin_restaurant_html/restaurant_1947.html
# Successfully saved: michelin_restaurant_html/restaurant_1948.html
# Successfully saved: michelin_restaurant_html/restaurant_1949.html
# Successfully saved: michelin_restaurant_html/restaurant_1950.html
# Successfully saved: michelin_restaurant_html/restaurant_1951.html
# Successfully saved: michelin_restaurant_html/restaurant_1952.html
# Successfully saved: michelin_restaurant_html/restaurant_1953.html
# Successfully saved: michelin_restaurant_html/restaurant_1954.html
# Successfully saved: michelin_restaurant_html/restaurant_1955.html
# Successfully saved: michelin_restaurant_html/restaurant_1956.html
# Successfully saved: michelin_restaurant_html/restaurant_1957.html
# Successfully saved: michelin_restaurant_html/restaurant_1958.html
# Successfully saved: michelin_restaurant_html/restaurant_1959.html
# Successfully saved: michelin_restaurant_html/restaurant_1960.html
# Successfully saved: michelin_restaurant_html/restaurant_1961.html
# Successfully saved: michelin_restaurant_html/restaurant_1962.html
# Successfully saved: michelin_restaurant_html/restaurant_1963.html
# Successfully saved: michelin_restaurant_html/restaurant_1964.html
# Successfully saved: michelin_restaurant_html/restaurant_1965.html
# Successfully saved: michelin_restaurant_html/restaurant_1966.html
# Successfully saved: michelin_restaurant_html/restaurant_1967.html
# Successfully saved: michelin_restaurant_html/restaurant_1968.html
# Successfully saved: michelin_restaurant_html/restaurant_1969.html
# Successfully saved: michelin_restaurant_html/restaurant_1970.html
# Successfully saved: michelin_restaurant_html/restaurant_1971.html
# Successfully saved: michelin_restaurant_html/restaurant_1972.html
# Successfully saved: michelin_restaurant_html/restaurant_1973.html
# Successfully saved: michelin_restaurant_html/restaurant_1974.html
# Successfully saved: michelin_restaurant_html/restaurant_1975.html
# Successfully saved: michelin_restaurant_html/restaurant_1976.html
# Successfully saved: michelin_restaurant_html/restaurant_1977.html
# Successfully saved: michelin_restaurant_html/restaurant_1978.html
# Successfully saved: michelin_restaurant_html/restaurant_1979.html
# Successfully saved: michelin_restaurant_html/restaurant_1980.html
# Successfully saved: michelin_restaurant_html/restaurant_1981.html
# Files have been organized into folders based on pages.
# organized_michelin_html/Page_1 contains 20 files.
# organized_michelin_html/Page_2 contains 20 files.
# organized_michelin_html/Page_3 contains 20 files.
# organized_michelin_html/Page_4 contains 20 files.
# organized_michelin_html/Page_5 contains 20 files.
# organized_michelin_html/Page_6 contains 20 files.
# organized_michelin_html/Page_7 contains 20 files.
# organized_michelin_html/Page_8 contains 20 files.
# organized_michelin_html/Page_9 contains 20 files.
# organized_michelin_html/Page_10 contains 20 files.
# organized_michelin_html/Page_11 contains 20 files.
# organized_michelin_html/Page_12 contains 20 files.
# organized_michelin_html/Page_13 contains 20 files.
# organized_michelin_html/Page_14 contains 20 files.
# organized_michelin_html/Page_15 contains 20 files.
# organized_michelin_html/Page_16 contains 20 files.
# organized_michelin_html/Page_17 contains 20 files.
# organized_michelin_html/Page_18 contains 20 files.
# organized_michelin_html/Page_19 contains 20 files.
# organized_michelin_html/Page_20 contains 20 files.
# organized_michelin_html/Page_21 contains 20 files.
# organized_michelin_html/Page_22 contains 20 files.
# organized_michelin_html/Page_23 contains 20 files.
# organized_michelin_html/Page_24 contains 20 files.
# organized_michelin_html/Page_25 contains 20 files.
# organized_michelin_html/Page_26 contains 20 files.
# organized_michelin_html/Page_27 contains 20 files.
# organized_michelin_html/Page_28 contains 20 files.
# organized_michelin_html/Page_29 contains 20 files.
# organized_michelin_html/Page_30 contains 20 files.
# organized_michelin_html/Page_31 contains 20 files.
# organized_michelin_html/Page_32 contains 20 files.
# organized_michelin_html/Page_33 contains 20 files.
# organized_michelin_html/Page_34 contains 20 files.
# organized_michelin_html/Page_35 contains 20 files.
# organized_michelin_html/Page_36 contains 20 files.
# organized_michelin_html/Page_37 contains 20 files.
# organized_michelin_html/Page_38 contains 20 files.
# organized_michelin_html/Page_39 contains 20 files.
# organized_michelin_html/Page_40 contains 20 files.
# organized_michelin_html/Page_41 contains 20 files.
# organized_michelin_html/Page_42 contains 20 files.
# organized_michelin_html/Page_43 contains 20 files.
# organized_michelin_html/Page_44 contains 20 files.
# organized_michelin_html/Page_45 contains 20 files.
# organized_michelin_html/Page_46 contains 20 files.
# organized_michelin_html/Page_47 contains 20 files.
# organized_michelin_html/Page_48 contains 20 files.
# organized_michelin_html/Page_49 contains 20 files.
# organized_michelin_html/Page_50 contains 20 files.
# organized_michelin_html/Page_51 contains 20 files.
# organized_michelin_html/Page_52 contains 20 files.
# organized_michelin_html/Page_53 contains 20 files.
# organized_michelin_html/Page_54 contains 20 files.
# organized_michelin_html/Page_55 contains 20 files.
# organized_michelin_html/Page_56 contains 20 files.
# organized_michelin_html/Page_57 contains 20 files.
# organized_michelin_html/Page_58 contains 20 files.
# organized_michelin_html/Page_59 contains 20 files.
# organized_michelin_html/Page_60 contains 20 files.
# organized_michelin_html/Page_61 contains 20 files.
# organized_michelin_html/Page_62 contains 20 files.
# organized_michelin_html/Page_63 contains 20 files.
# organized_michelin_html/Page_64 contains 20 files.
# organized_michelin_html/Page_65 contains 20 files.
# organized_michelin_html/Page_66 contains 20 files.
# organized_michelin_html/Page_67 contains 20 files.
# organized_michelin_html/Page_68 contains 20 files.
# organized_michelin_html/Page_69 contains 20 files.
# organized_michelin_html/Page_70 contains 20 files.
# organized_michelin_html/Page_71 contains 20 files.
# organized_michelin_html/Page_72 contains 20 files.
# organized_michelin_html/Page_73 contains 20 files.
# organized_michelin_html/Page_74 contains 20 files.
# organized_michelin_html/Page_75 contains 20 files.
# organized_michelin_html/Page_76 contains 20 files.
# organized_michelin_html/Page_77 contains 20 files.
# organized_michelin_html/Page_78 contains 20 files.
# organized_michelin_html/Page_79 contains 20 files.
# organized_michelin_html/Page_80 contains 20 files.
# organized_michelin_html/Page_81 contains 20 files.
# organized_michelin_html/Page_82 contains 20 files.
# organized_michelin_html/Page_83 contains 20 files.
# organized_michelin_html/Page_84 contains 20 files.
# organized_michelin_html/Page_85 contains 20 files.
# organized_michelin_html/Page_86 contains 20 files.
# organized_michelin_html/Page_87 contains 20 files.
# organized_michelin_html/Page_88 contains 20 files.
# organized_michelin_html/Page_89 contains 20 files.
# organized_michelin_html/Page_90 contains 20 files.
# organized_michelin_html/Page_91 contains 20 files.
# organized_michelin_html/Page_92 contains 20 files.
# organized_michelin_html/Page_93 contains 20 files.
# organized_michelin_html/Page_94 contains 20 files.
# organized_michelin_html/Page_95 contains 20 files.
# organized_michelin_html/Page_96 contains 20 files.
# organized_michelin_html/Page_97 contains 20 files.
# organized_michelin_html/Page_98 contains 20 files.
# organized_michelin_html/Page_99 contains 20 files.
# organized_michelin_html/Page_100 contains 1 files.

# %% [markdown]
# ## 1.3 Parse downloaded pages

# %%
def extract_restaurant_data(html_content, url):
    # Parse the HTML content
    soup = BeautifulSoup(html_content, "html.parser")

    # Extract restaurant's name (from the <h1> tag)
    name_tag = soup.find("h1")
    restaurant_name = name_tag.get_text(strip=True) if name_tag else ""

    # Extract restaurant's address (from the <div> class)
    address_tag = soup.find("div", class_="data-sheet__block--text")
    restaurant_address = address_tag.get_text(strip=True) if address_tag else ""

    # Split address into components
    address, city, postal_code, country = "", "", "", ""
    if restaurant_address:
        address_parts = [part.strip() for part in restaurant_address.split(",")]
        if len(address_parts) >= 4:
            # Extract address components if all four parts are present
            address = address_parts[0]
            city = ", ".join(address_parts[1:-2])
            postal_code = address_parts[-2].strip()
            country = address_parts[-1].strip()
        elif len(address_parts) == 3:
            # Case with three components (missing postal code)
            address = address_parts[0]
            city = address_parts[1].strip()
            postal_code = ""
            country = address_parts[2].strip()
        elif len(address_parts) == 2:
            # Case with only address and country
            address = address_parts[0]
            city = ""
            postal_code = ""
            country = address_parts[1].strip()

    # Extract restaurant's price range and restaurant's cuisine type (from the <div> class)
    price_range, cuisine_type = "", ""
    price_description_tags = soup.find_all("div", class_="data-sheet__block--text")
    if price_description_tags and len(price_description_tags) > 1:

        # Split content into price range and cuisine type
        content = price_description_tags[1].get_text().strip()
        content_parts = content.split('·')
        if len(content_parts) == 2:
            price_range = content_parts[0].strip()
            cuisine_type = content_parts[1].strip()
        elif len(content_parts) == 1:
            price_range = content_parts[0].strip()

    # Extract restaurant's description (from the <div> class)
    description_tag = soup.find("div", class_="data-sheet__description")
    restaurant_description = description_tag.get_text(strip=True) if description_tag else ""

    # Extract restaurant's services (from the <div> class)
    services = []
    services_container = soup.find("div", class_="restaurant-details__services")
    if services_container:
        services_tags = services_container.find_all("li")
        services = [tag.get_text(strip=True) for tag in services_tags] if services_tags else []

    # Extract credit card's information (from the <div> class)
    credit_cards = []
    credit_cards_container = soup.find("div", class_="list--card")
    if credit_cards_container:
        credit_card_tags = credit_cards_container.find_all("img")
        for tag in credit_card_tags:
            data_src = tag.get("data-src", "")
            if "amex" in data_src:
                credit_cards.append("Amex")
            elif "mastercard" in data_src:
                credit_cards.append("Mastercard")
            elif "visa" in data_src:
                credit_cards.append("Visa")

    # Extract restaurant's phone number (from the <div> class)
    phone_number = ""
    phone_container = soup.find("div", class_="collapse__block-item")
    if phone_container:
        phone_tag = phone_container.find("span", dir="ltr")
        phone_number = phone_tag.get_text(strip=True) if phone_tag else ""

    # Extract restaurant's website URL (from the <div> class)
    website = ""
    website_container = soup.find("div", class_="collapse__block-item link-item")
    if website_container:
        website_tag = website_container.find("a", href=True)
        website = website_tag["href"] if website_tag else ""

    # Return extracted data as a dictionary
    return {
        "restaurantName": restaurant_name or "",
        "address": restaurant_address or "",
        "city": city or "",
        "postalCode": postal_code or "",
        "country": country or "",
        "priceRange": price_range or "",
        "cuisineType": cuisine_type or "",
        "description": restaurant_description or "",
        "facilitiesServices": services if services else [],
        "creditCards": credit_cards if credit_cards else [],
        "phoneNumber": phone_number or "",
        "website": website or ""
    }

# %%
def parse_all_html_files(input_folder, output_file):

    # List to store data for all restaurants
    all_restaurants_data = []

    # Walk through all subfolders and files within the input folder
    for dirpath, _, filenames in os.walk(input_folder):
        for file in sorted(filenames):
            if file.endswith(".html"):

                # Open and read the content of each HTML file
                file_path = os.path.join(dirpath, file)
                with open(file_path, "r", encoding="utf-8") as f:
                    html_content = f.read()
                    url = f"http://example.com/{file}"
                    data = extract_restaurant_data(html_content, url)
                    all_restaurants_data.append(data)

    # Create a DataFrame
    df = pd.DataFrame(all_restaurants_data)

    # Save the DataFrame in a TSV file
    df.to_csv(output_file, sep="\t", index=False)
    print(f"Data saved to {output_file}")

# Define input and output paths
input_folder = "organized_michelin_html"  # Main directory containing all folders
output_file = "parsed_restaurants.tsv"
parse_all_html_files(input_folder, output_file)
# Out:
# Data saved to parsed_restaurants.tsv

# %% [markdown]
# # RQ2. Search Engine

# %% [markdown]
# ## Importing

# %%
df = pd.read_csv('cleaned_restaurants.csv')

df.head()
# Out:
#              restaurantName                    address            city  \
# 0            Castel Toblino  località Castel Toblino 1  Castel Toblino
# 1               Su Gologone       Località Su Gologone          Oliena
# 2           Bàcaro Il Gusto    via Provinciale Nord 30           Fossò
# 3  Osteria dello Strecciolo         via Indipendenza 2        Robbiate
# 4                    Trippa       via Giorgio Vasari 1           Milan
#
#    postalCode country priceRange                     cuisineType  \
# 0       38076   Italy         €€    Modern Cuisine, Contemporary
# 1        8025   Italy         €€  Sardinian, Traditional Cuisine
# 2       30030   Italy         €€                        Venetian
# 3       23899   Italy        €€€            Italian Contemporary
# 4       20135   Italy         €€       Italian, Seasonal Cuisine
#
#                                          description  \
# 0  Situated in a bucolic location in the Trentino...
# 1  It is difficult to choose between the three de...
# 2  A simple, modern restaurant where all the atte...
# 3  Situated in the centre of the village, this po...
# 4  Simple, informal and with a slightly retro fee...
#
#                                   facilitiesServices  \
# 0          ['Car park', 'Garden or park', 'Terrace']
# 1  ['Air conditioning', 'Car park', 'Garden or pa...
# 2          ['Air conditioning', 'Wheelchair access']
# 3                                                 []
# 4  ['Air conditioning', 'Terrace', 'Wheelchair ac...
#
#                       creditCards       phoneNumber  \
# 0  ['Amex', 'Mastercard', 'Visa']   +39 0461 864036
# 1  ['Amex', 'Mastercard', 'Visa']   +39 0784 287512
# 2  ['Amex', 'Mastercard', 'Visa']  +39 041 517 0035
# 3  ['Amex', 'Mastercard', 'Visa']  +39 039 928 1052
# 4  ['Amex', 'Mastercard', 'Visa']  +39 327 668 7908
#
#                                             website
# 0                    https://www.casteltoblino.com/
# 1  https://www.sugologone.it/ristorante-tipico.html
# 2            https://www.ristorantebacaroilgusto.it
# 3              http://www.osteriadellostrecciolo.it
# 4                      https://www.trippamilano.it/

# %% [markdown]
# ## 2.0 Preprocessing the text
#
# To build an effective search engine for restaurant descriptions, we need to preprocess the text data to ensure consistency and improve search accuracy. Here’s what each step of the preprocessing does and why it is essential:
#
# 1. **Lowercasing**: All text is converted to lowercase to make searches case-insensitive. This ensures that words like "Vegan" and "vegan" are treated the same, avoiding mismatches due to capitalization.
#
# 2. **Removing Punctuation**: Punctuation marks (like commas, periods, and exclamation points) are removed, as they often do not contribute meaningfully in search contexts. This helps focus on the words themselves without interference from symbols.
#
# 3. **Removing Stopwords**: Commonly used words (like "and," "the," "in") are removed, as they generally do not add value in distinguishing between search results. Removing these words reduces noise in the data, allowing us to focus on the meaningful content of each description.
#
# 4. **Stemming**: Words are reduced to their root forms, meaning that variations of a word (such as "cooking," "cooked," and "cook") are treated as the same term. This normalization makes the data more consistent and compact, improving the effectiveness of search queries that include variations of keywords.
#
# 5. **Reassembling Cleaned Text**: After processing, the cleaned words are reassembled into a single, preprocessed string, ready for use in the search engine. This cleaned text better represents the core content of each description, making searches more accurate and consistent.
#
# Through these steps, we make the text data cleaner and more uniform, which is essential for tasks like search or similarity matching by removing irrelevant elements and highlighting essential keywords.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string

# Download the stopwords data (only needed once per environment)
nltk.download('stopwords')

# Initialize the stemmer and stopwords
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

def preprocess_description(text):
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Tokenize, remove stopwords, and apply stemming
    tokens = [stemmer.stem(word) for word in text.split() if word not in stop_words]

    # Join the tokens back into a cleaned text
    cleaned_text = ' '.join(tokens)

    return cleaned_text

# Apply preprocessing to the 'description' column
df['processed_description'] = df['description'].apply(preprocess_description)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df.head()
# Out:
#              restaurantName                    address            city  \
# 0            Castel Toblino  località Castel Toblino 1  Castel Toblino
# 1               Su Gologone       Località Su Gologone          Oliena
# 2           Bàcaro Il Gusto    via Provinciale Nord 30           Fossò
# 3  Osteria dello Strecciolo         via Indipendenza 2        Robbiate
# 4                    Trippa       via Giorgio Vasari 1           Milan
#
#    postalCode country priceRange                     cuisineType  \
# 0       38076   Italy         €€    Modern Cuisine, Contemporary
# 1        8025   Italy         €€  Sardinian, Traditional Cuisine
# 2       30030   Italy         €€                        Venetian
# 3       23899   Italy        €€€            Italian Contemporary
# 4       20135   Italy         €€       Italian, Seasonal Cuisine
#
#                                          description  \
# 0  Situated in a bucolic location in the Trentino...
# 1  It is difficult to choose between the three de...
# 2  A simple, modern restaurant where all the atte...
# 3  Situated in the centre of the village, this po...
# 4  Simple, informal and with a slightly retro fee...
#
#                                   facilitiesServices  \
# 0          ['Car park', 'Garden or park', 'Terrace']
# 1  ['Air conditioning', 'Car park', 'Garden or pa...
# 2          ['Air conditioning', 'Wheelchair access']
# 3                                                 []
# 4  ['Air conditioning', 'Terrace', 'Wheelchair ac...
#
#                       creditCards       phoneNumber  \
# 0  ['Amex', 'Mastercard', 'Visa']   +39 0461 864036
# 1  ['Amex', 'Mastercard', 'Visa']   +39 0784 287512
# 2  ['Amex', 'Mastercard', 'Visa']  +39 041 517 0035
# 3  ['Amex', 'Mastercard', 'Visa']  +39 039 928 1052
# 4  ['Amex', 'Mastercard', 'Visa']  +39 327 668 7908
#
#                                             website  \
# 0                    https://www.casteltoblino.com/
# 1  https://www.sugologone.it/ristorante-tipico.html
# 2            https://www.ristorantebacaroilgusto.it
# 3              http://www.osteriadellostrecciolo.it
# 4                      https://www.trippamilano.it/
#
#                                processed_description
# 0  situat bucol locat trentino excel vino santo p...
# 1  difficult choos three delight room restaur one...
# 2  simpl modern restaur attent focus extraordinar...
# 3  situat centr villag popular profession run res...
# 4  simpl inform slightli retro feel restaur serv ...

# %% [markdown]
# ## 2.1 Conjuctive query
#
# A **conjunctive query** is a search query that requires all specified terms to be present in the documents it retrieves. In the context of a search engine, this is often called an "AND search" because it returns only documents that contain **all** of the query terms.
#
# For example, a conjunctive query for `"modern cuisine"` would only retrieve documents that contain both `"modern"` **and** `"cuisine"` in their content. This approach is useful when looking for highly specific results, but it can limit the number of results if one of the terms is uncommon or if the dataset contains few documents with all the terms.
#
# To build a conjunctive search engine for restaurant descriptions, we will:
# 1. **Preprocess the Text**: Clean and standardize each restaurant’s description by removing stopwords, punctuation, and stemming words to create a searchable field.
# 2. **Build the Vocabulary**: Create a vocabulary that maps each unique term in the descriptions to a unique integer `term_id`.
# 3. **Create an Inverted Index**: Build an inverted index where each `term_id` is associated with a list of document IDs (restaurants) that contain that term.
# 4. **Implement the Conjunctive Query Function**: Design a function that takes a user query, preprocesses it, retrieves term IDs from the vocabulary, and finds the intersection of document lists in the inverted index to return only documents containing all query terms.
# 5. **Test and Display Results**: Run sample queries and display the results to verify the functionality of the conjunctive search engine.
#
# This approach will help us retrieve highly relevant restaurants based on the specific combination of terms in a query.

# %% [markdown]
# ## Vocabulary and Inverted Index Building
#
# In this step, we’ll create the foundation for our search engine by building a **vocabulary** and an **inverted index** from the `processed_description` column of each restaurant.
#
# ### Vocabulary
# The vocabulary is a dictionary that maps each unique word in the restaurant descriptions to a unique integer ID, called `term_id`. This serves two main purposes:
# 1. **Uniqueness**: Each word has a single ID, allowing consistent identification across the dataset.
# 2. **Efficiency**: By using integer IDs instead of words, we reduce memory usage and speed up search operations.
#
# ### Inverted Index
# The inverted index is a data structure that maps each `term_id` to a list of document IDs (in this case, restaurant indices) that contain the term. This enables us to quickly look up documents containing specific words, which is essential for efficient searching.
#
# For each restaurant’s `processed_description`, we:
# 1. Split the text into individual terms.
# 2. Map each term to a `term_id` (using the vocabulary) and assign it a unique integer if it doesn’t already exist in the vocabulary.
# 3. Add the restaurant’s ID (or index) to the inverted index for each term it contains.
#
# By the end of this step, we’ll have a vocabulary that associates each unique word with a `term_id`, and an inverted index that lets us retrieve restaurants based on these terms.
#
# This setup is critical for enabling efficient **conjunctive queries** later on, as the inverted index lets us intersect document lists for each search term and retrieve only the relevant results.

# %%
from collections import defaultdict

# Initialize vocabulary and inverted index
vocabulary = {}  # maps each term to a unique term_id
inverted_index = defaultdict(list)  # maps each term_id to a list of document IDs (restaurant indices)

# Unique identifier for each term
current_term_id = 0

# Populate vocabulary and inverted index based on the preprocessed descriptions
for doc_id, description in enumerate(df['processed_description']):
    # Split description into terms
    terms = description.split()

    for term in terms:
        # Assign a unique term_id if term is not in vocabulary
        if term not in vocabulary:
            vocabulary[term] = current_term_id
            current_term_id += 1

        # Get the term_id for the current term
        term_id = vocabulary[term]

        # Add the document ID to the inverted index for this term_id
        if doc_id not in inverted_index[term_id]:
            inverted_index[term_id].append(doc_id)

# %% [markdown]
# After creating them we check a few conditions to see if they are well built.

# %%
# 1. Check for unique mappings by comparing the vocabulary size to the number of unique terms in processed descriptions.
unique_terms_in_descriptions = set(term for description in df['processed_description'] for term in description.split())
if len(vocabulary) == len(unique_terms_in_descriptions):
    print("Vocabulary integrity check 1: Passed. Each term has a unique mapping.")
else:
    print("Vocabulary integrity check 1: Failed. The vocabulary size does not match the number of unique terms.")

# 2. Check that each term has a unique term_id by verifying no duplicates in the IDs.
unique_ids = set(vocabulary.values())
if len(vocabulary) == len(unique_ids):
    print("Vocabulary integrity check 2: Passed. Each term_id is unique.")
else:
    print("Vocabulary integrity check 2: Failed. Some terms share the same term_id.")

# 3. Verify that each term in the vocabulary appears at least once in any processed description
terms_in_descriptions = {term for description in df['processed_description'] for term in description.split()}
missing_terms = set(vocabulary.keys()) - terms_in_descriptions

if not missing_terms:
    print("Vocabulary integrity check 3: Passed. All terms in the vocabulary are present in descriptions.")
else:
    print(f"Vocabulary integrity check 3: Failed. Terms missing in descriptions: {missing_terms}")
# Out:
# Vocabulary integrity check 1: Passed. Each term has a unique mapping.
# Vocabulary integrity check 2: Passed. Each term_id is unique.
# Vocabulary integrity check 3: Passed. All terms in the vocabulary are present in descriptions.

# %%
# 1. Check that each term in the vocabulary has an entry in the inverted index.
missing_terms = [term for term, term_id in vocabulary.items() if term_id not in inverted_index]
if not missing_terms:
    print("Inverted index validity check 1: Passed. All vocabulary terms have entries in the inverted index.")
else:
    print(f"Inverted index validity check 1: Failed. Missing terms in the inverted index: {missing_terms}")

# 2. Check that each document ID in the inverted index actually contains the term.
incorrect_mappings = []
for term, term_id in vocabulary.items():
    # Get all document IDs for this term from the inverted index
    doc_ids = inverted_index.get(term_id, [])
    for doc_id in doc_ids:
        # Check if the term is actually present in the document's processed description
        if term not in df['processed_description'].iloc[doc_id].split():
            incorrect_mappings.append((term, doc_id))

if not incorrect_mappings:
    print("Inverted index validity check 2: Passed. All document IDs in the inverted index contain the term.")
else:
    print(f"Inverted index validity check 2: Failed. Incorrect mappings found: {incorrect_mappings}")

# 3. Ensure each document list for a term_id has unique entries (no duplicate document IDs).
duplicate_doc_ids = {}
for term_id, doc_ids in inverted_index.items():
    unique_doc_ids = set(doc_ids)
    if len(unique_doc_ids) != len(doc_ids):
        duplicate_doc_ids[term_id] = [doc_id for doc_id in doc_ids if doc_ids.count(doc_id) > 1]

if not duplicate_doc_ids:
    print("Inverted index validity check 3: Passed. No duplicate document IDs found in any inverted index entry.")
else:
    print(f"Inverted index validity check 3: Failed. Duplicate document IDs found: {duplicate_doc_ids}")
# Out:
# Inverted index validity check 1: Passed. All vocabulary terms have entries in the inverted index.
# Inverted index validity check 2: Passed. All document IDs in the inverted index contain the term.
# Inverted index validity check 3: Passed. No duplicate document IDs found in any inverted index entry.

# %% [markdown]
# ## Executing the Conjunctive Query
#
# To execute a conjunctive search query, we’ll follow these steps, which allow the search engine to return only the restaurants that contain **all** specified query terms in their descriptions. This is also known as an “AND search.”
#
# #### Steps
#
# 1. **Process the Query**: We preprocess the user’s query using the same method as we used for the descriptions. This includes:
#    - Converting text to lowercase.
#    - Removing punctuation.
#    - Removing stopwords.
#    - Applying stemming to reduce words to their root forms.
#
# 2. **Retrieve Term IDs**: For each processed term in the query, we look up its unique integer identifier (`term_id`) in the vocabulary. This ID allows us to efficiently search in the inverted index.
#
# 3. **Find Matching Documents**: Using the inverted index, we retrieve lists of document IDs that contain each term.
#
# 4. **Intersect Document Lists**: Since this is a conjunctive query, we find the intersection of all document lists, ensuring that only documents (restaurants) containing **all** query terms are retained.
#
# 5. **Return Results**: For each document ID in the intersection, we retrieve the relevant restaurant details, including:
#    - `restaurantName`
#    - `address`
#    - `description`
#    - `website`
#
# ### Example
# If the user inputs the query `"traditional Italian terrace"`, the search engine will:
#    - Process each term.
#    - Retrieve and intersect the lists of documents that contain these terms.
#    - Output only those restaurants whose descriptions contain all the terms “traditional,” “Italian,” and “terrace.”
#
# This approach is useful for returning highly specific results by ensuring each restaurant in the result list matches the entire query. Run the code to test the query function!

# %%
def preprocess_query(query):
    """Preprocesses the user query."""
    # Apply the same preprocessing as used for the descriptions
    query = query.lower().translate(str.maketrans('', '', string.punctuation))
    tokens = [stemmer.stem(word) for word in query.split() if word not in stop_words]
    return tokens

def execute_conjunctive_query(query):
    """Executes a conjunctive query and returns matching restaurant details."""
    # Preprocess the query terms
    query_terms = preprocess_query(query)

    # Retrieve term IDs for each query term from the vocabulary
    term_ids = [vocabulary[term] for term in query_terms if term in vocabulary]

    # If any term is not in the vocabulary, return no results
    if len(term_ids) != len(query_terms):
        print("Some query terms are not in the vocabulary. No results found.")
        return pd.DataFrame(columns=["restaurantName", "address", "description", "website"])

    # Get the document lists for each term_id from the inverted index
    doc_lists = [inverted_index[term_id] for term_id in term_ids]

    # Find the intersection of all document lists
    matching_doc_ids = list(set(doc_lists[0]).intersection(*doc_lists[1:])) if doc_lists else []

    # Retrieve restaurant details for matching document IDs
    results = df.loc[matching_doc_ids, ["restaurantName", "address", "description", "website"]]
    return results

# %%
# Accept a query input from the user
query = input("RQ2 Conjunctive query: ")

# Run the conjunctive query function using the input query
results = execute_conjunctive_query(query)

results
# Out:
# RQ2 Conjunctive query: traditional Italian terrace
#                    restaurantName                    address  \
# 457   Il Ristorante - Niko Romito          via di Ripetta 73
# 1583        La Leggenda dei Frati      costa San Giorgio 6/a
# 1337          Osteria Il Cappello  piazzetta Bruno Lunelli 5
#
#                                             description  \
# 457   Situated on the fifth floor of the Hotel Bulga...
# 1583  After an uphill approach if you’re arriving he...
# 1337  The outdoor terrace at this restaurant overloo...
#
#                                                 website
# 457   https://www.bulgarihotels.com/it_IT/rome/dinin...
# 1583                     https://laleggendadeifrati.it/
# 1337                      https://osteriailcappello.it/

# %% [markdown]
# ### Conjunctive Query Implementation and Testing with Query Examples
#
# To validate the functionality of our conjunctive query search engine, we ran two queries with increasing specificity. This helped us confirm that the search engine correctly filtered restaurants based on multiple terms and adjusted the results accordingly.
#
# #### Example Queries and Reasoning
#
# 1. **General Query: "traditional Italian"**
#    - **Reason**: This broad query was chosen to test the search engine’s ability to retrieve a wide array of restaurants that feature traditional Italian cuisine. Since these terms are common, we expected the search to return a larger number of results.
#    - **Result**: The search engine returned a diverse list of restaurants emphasizing traditional Italian cuisine. This larger output confirmed that the search engine could locate all relevant descriptions containing both "traditional" and "Italian."
#
# 2. **Specific Query: "traditional Italian terrace"**
#    - **Reason**: By adding the term "terrace," this query became more specific, aiming to filter the results to restaurants that not only feature traditional Italian cuisine but also have a terrace. This helped us test the conjunctive functionality further by adding a distinguishing feature to the initial query.
#    - **Result**: The output list was significantly smaller, showing only restaurants that include "traditional," "Italian," and "terrace" in their descriptions. This confirmed that the search engine could accurately refine results as more specific terms are added.
#
# #### Summary
#
# These two queries demonstrated the conjunctive query functionality effectively:
# - Broader queries return a larger, more inclusive list of restaurants.
# - Adding specific terms narrows down the results to match only restaurants that meet all criteria, allowing for focused, relevant results.
#
# This approach ensures that users can adjust the specificity of their queries to receive either general or highly targeted search results.

# %% [markdown]
# ## 2.2 Ranked Search Engine with TF-IDF and Cosine Similarity
#
# ### Ranked Search Engine with TF-IDF and Cosine Similarity
#
# To build a ranked search engine, we will calculate **TF-IDF** scores for each term in each restaurant’s description and use **cosine similarity** to rank results based on their relevance to the query. Below are the main steps for implementation:
#
# #### Steps
#
# 1. **Calculate TF-IDF Scores**
#    - **TF (Term Frequency)**: For each term in a description, we calculate term frequency, which is the count of the term in that description divided by the total number of terms in the description.
#    - **IDF (Inverse Document Frequency)**: Calculate IDF for each term, which measures how unique the term is across all descriptions:
#      \begin{equation}
#      \text{IDF} = \log\left(\frac{N}{1 + \text{DF}}\right)
#      \end{equation}
#      where \( N \) is the total number of documents, and \( DF \) is the number of documents containing the term.
#    - **TF-IDF**: Multiply TF by IDF for each term in each description to get the final TF-IDF score.
#
# 2. **Create the Updated Inverted Index with TF-IDF Scores**
#    - Each term in the inverted index will map to a list of tuples. Each tuple will contain a document ID and the TF-IDF score for that term in that document.
#
# 3. **Execute the Ranked Query**
#    - **Process the Query**: Preprocess the query terms similarly to the descriptions and compute TF-IDF scores for the query terms.
#    - **Cosine Similarity**: Calculate cosine similarity between the TF-IDF vector of the query and the TF-IDF vector of each restaurant description.
#    - **Ranking**: Sort restaurants by cosine similarity scores and retrieve the top-k results.
#
# The code below will implement steps 1 and 2 by calculating TF-IDF scores for each term and creating the updated inverted index.

# %% [markdown]
# ## 2.2.1 Inverted Index with TF-IDF Scores

# %%
import numpy as np
from collections import defaultdict
import math

# Step 1: Calculate TF-IDF Scores
N = len(df)  # Total number of documents
term_document_frequency = defaultdict(int)  # DF: Document frequency for each term
tf_idf_index = defaultdict(list)  # Inverted index with TF-IDF scores

# Calculate term frequency (TF) and document frequency (DF) for each term
for doc_id, description in enumerate(df['processed_description']):
    term_counts = defaultdict(int)
    terms = description.split()
    total_terms = len(terms)

    for term in terms:
        term_counts[term] += 1

    for term, count in term_counts.items():
        # TF calculation
        tf = count / total_terms
        term_document_frequency[term] += 1
        # Store TF temporarily in the index for later TF-IDF computation
        tf_idf_index[term].append((doc_id, tf))  # Store TF instead of TF-IDF for now

# Calculate IDF and update the inverted index with TF-IDF scores
for term, doc_list in tf_idf_index.items():
    # IDF calculation
    idf = math.log(N / (1 + term_document_frequency[term]))

    # Update each document's TF with TF-IDF for this term
    tf_idf_index[term] = [(doc_id, tf * idf) for doc_id, tf in doc_list]

# Step 2: Inverted index now has TF-IDF scores

# %% [markdown]
# ## Sample Verification of the TF-IDF Index

# %%
# Display a few terms and their associated documents with TF-IDF scores
sample_terms = list(tf_idf_index.keys())[:5]  # Adjust the number of terms if needed
sample_tf_idf_index = {term: tf_idf_index[term] for term in sample_terms}

# Print sample
print("Sample of TF-IDF index:")
for term, doc_list in sample_tf_idf_index.items():
    print(f"Term: {term}")
    for doc_id, tf_idf_score in doc_list[:5]:  # Show a limited number of docs per term
        print(f"  Document ID: {doc_id}, TF-IDF Score: {tf_idf_score:.4f}")
    print("-" * 20)
# Out:
# Sample of TF-IDF index:
# Term: situat
#   Document ID: 0, TF-IDF Score: 0.0268
#   Document ID: 3, TF-IDF Score: 0.0479
#   Document ID: 7, TF-IDF Score: 0.0479
#   Document ID: 13, TF-IDF Score: 0.0263
#   Document ID: 32, TF-IDF Score: 0.0463
# --------------------
# Term: bucol
#   Document ID: 0, TF-IDF Score: 0.1129
#   Document ID: 521, TF-IDF Score: 0.0733
#   Document ID: 573, TF-IDF Score: 0.1344
#   Document ID: 708, TF-IDF Score: 0.2258
#   Document ID: 1354, TF-IDF Score: 0.0594
# --------------------
# Term: locat
#   Document ID: 0, TF-IDF Score: 0.0510
#   Document ID: 6, TF-IDF Score: 0.0340
#   Document ID: 10, TF-IDF Score: 0.0849
#   Document ID: 12, TF-IDF Score: 0.0214
#   Document ID: 14, TF-IDF Score: 0.0392
# --------------------
# Term: trentino
#   Document ID: 0, TF-IDF Score: 0.1079
#   Document ID: 219, TF-IDF Score: 0.1079
#   Document ID: 1280, TF-IDF Score: 0.1037
#   Document ID: 1337, TF-IDF Score: 0.1173
#   Document ID: 1541, TF-IDF Score: 0.1254
# --------------------
# Term: excel
#   Document ID: 0, TF-IDF Score: 0.0319
#   Document ID: 2, TF-IDF Score: 0.0410
#   Document ID: 6, TF-IDF Score: 0.0213
#   Document ID: 7, TF-IDF Score: 0.0570
#   Document ID: 10, TF-IDF Score: 0.0532
# --------------------

# %% [markdown]
# To ensure the accuracy and structure of our TF-IDF index, we extracted a sample of terms with their associated documents and TF-IDF scores. This verification step is important for confirming that:
#
# 1. **The Index Structure is Correct**: Each term in the index is linked to a list of document IDs where it appears. Each document ID is paired with the term’s TF-IDF score in that document. This structure allows efficient lookups during search operations.
#
# 2. **TF-IDF Scores Appear Reasonable**: TF-IDF scores are generally fractional values, often between 0 and 0.2, with higher values indicating a term that is highly relevant in a specific document. In our sample, values like `0.1129` for "bucol" in document 0 and `0.1079` for "trentino" in document 0 are within an expected range. Higher values for specific terms in select documents indicate that these terms are particularly important in those contexts.
#
# 3. **Document Coverage Matches Term Frequency Expectations**: For more common terms (e.g., "situat" and "locat"), we observe links to a broad range of documents, reflecting their general use across the corpus. In contrast, more specific terms (e.g., "bucol" and "trentino") appear in fewer documents, confirming that the index correctly distinguishes between frequent and rare terms.
#
# This sample verification provides confidence that the TF-IDF index has been correctly constructed, with meaningful TF-IDF scores ready to be used in ranking documents by relevance to a given search query.

# %% [markdown]
# ## 2.2.2 Execute the Ranked Query
#
# ### Ranked Query Execution with Cosine Similarity
#
# To implement the ranked query, we will use **cosine similarity** between the query’s TF-IDF vector and each restaurant description’s TF-IDF vector. Here’s the step-by-step breakdown:
#
# 1. **Process the Query**: We preprocess the query terms to match the format of our descriptions, applying lowercasing, stopword removal, and stemming.
#
# 2. **Construct the Query Vector (TF-IDF)**: We calculate TF-IDF scores for each term in the query:
#    - **TF (Term Frequency)**: For each query term, the term frequency is calculated as the term count divided by the total number of terms in the query.
#    - **IDF (Inverse Document Frequency)**: We retrieve the IDF values already computed for each term in the vocabulary to calculate the query's TF-IDF scores.
#
# 3. **Compute Cosine Similarity**:
#    - For each document that contains any of the query terms, we calculate the cosine similarity between the query vector and the document’s TF-IDF vector.
#    - Cosine similarity is calculated as the dot product of the two vectors divided by the product of their norms:
#
#      \begin{equation}
#      \text{Cosine Similarity} = \frac{\text{Dot Product (Query and Document TF-IDF vectors)}}{\text{Norm of Query Vector} \times \text{Norm of Document Vector}}
#      \end{equation}
#
#    - This score provides a measure of relevance between the query and each document, with values ranging from 0 (no similarity) to 1 (identical vectors).
#
# 4. **Sort and Return Top-k Results**:
#    - Sort the documents by cosine similarity score in descending order.
#    - Retrieve the top-k results, each with the restaurant's `name`, `address`, `description`, `website`, and similarity score.
#
# The code below implements these steps, retrieving and ranking restaurants based on the relevance of their descriptions to the query.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def execute_ranked_query(query, k=5):

    # Preprocess the query using the same preprocessing as the dataset
    preprocessed_query = preprocess_description(query)
    description_col = df['processed_description']

    # Vectorize the preprocessed query
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(description_col)
    query_vector = vectorizer.transform([preprocessed_query])

    # Compute cosine similarity between the query and all restaurant vectors
    cosine_similarities = cosine_similarity(query_vector, tfidf_matrix).flatten()

    # Get the top-k indices sorted by similarity score
    top_indices = np.argsort(cosine_similarities)[::-1][:k]

    # Filter results with non-zero similarity
    top_indices = [i for i in top_indices if cosine_similarities[i] > 0]

    # Prepare the output
    results = df.loc[top_indices, ['restaurantName', 'address', 'description', 'website']].copy()
    results['Similarity Score'] = cosine_similarities[top_indices]
    results = results.sort_values(by='Similarity Score', ascending=False)

    return results

# %%
# Accept a query input from the user
query = input("RQ2 Ranked query: ")

# Run the conjunctive query function using the input query
results = execute_ranked_query(query)

results
# Out:
# RQ2 Ranked query: traditional Italian terrace
#            restaurantName               address  \
# 1098                 ZELO          via Gesù 6/8
# 1866           La Veranda         via Regina 40
# 1833  Caffè Dante Bistrot  piazza dei Signori 2
# 924              Il Pozzo       viale Allegri 7
# 261    Zàghara Restaurant   Contrada Bigini snc
#
#                                             description  \
# 1098  The elegant ZELO restaurant enjoys a beautiful...
# 1866  As its name suggests, the dining room at this ...
# 1833  This restaurant boasts an outdoor terrace over...
# 924   This restaurant is housed in a historic palazz...
# 261   Housed in the elegant Relais Villa Flora, this...
#
#                                                 website  Similarity Score
# 1098  https://www.fourseasons.com/it/milan/dining/re...          0.237762
# 1866  https://www.villadeste.com/it/hotel-con-ristor...          0.219165
# 1833                         https://www.caffedante.it/          0.196841
# 924                                                 NaN          0.194572
# 261                      http://www.villaflorarelais.it          0.189553

# %% [markdown]
# ### Explanation of Results
#
# We followed the prescribed method, including:
#
# 1. **Preprocessing**:
#    - Applied consistent preprocessing to both the dataset and the query, including lemmatization, removal of punctuation, stopwords, and converting text to lowercase.
#    - Ensured uniformity to maximize the alignment between the query and the dataset.
#
# 2. **TF-IDF Vectorization**:
#    - Used a `TfidfVectorizer` with optimized parameters such as `ngram_range=(1,2)` to include bigrams, `max_df=0.85`, and `min_df=2`, to filter out overly common or rare terms.
#
# Despite these efforts, the cosine similarity values remain relatively small (below 0.2). This can be attributed to several factors:
#
# - **Dataset Specificity**: The dataset may not have detailed or highly descriptive text that directly aligns with the query. For example, if the descriptions do not frequently mention "modern" or "seasonal cuisine" explicitly, the cosine similarity values will naturally be lower.
#
# - **Query Specificity**: The query "modern seasonal cuisine" is quite specific, and if the dataset descriptions are generic, they might not capture the full context of the query.
#
# - **Limitations of TF-IDF**:
#    - TF-IDF relies on exact term matching and does not understand semantic relationships (e.g., "modern" and "contemporary" are semantically similar but treated as different terms).
#    - Even with bigrams, the matching depends on the exact occurrence of the phrase "modern cuisine" in the text.
#
# In conclusion, while the results are meaningful in ranking the dataset entries, the relatively low cosine similarity values are a known limitation of the TF-IDF approach when applied to datasets with sparse or generic textual descriptions.

# %% [markdown]
# # RQ3. Define a New Score!
#
# Now, we will define a custom ranking metric to prioritize restaurants based on user queries.
#
# Steps:
#
# 1. User Query: The user provides a text query. We’ll retrieve relevant documents using the search engine built in Step 2.1.
#
# 2. New Ranking Metric: After retrieving relevant documents, we’ll rank them using a new custom score. Instead of limiting the scoring to only the description field, we can include other attributes like `priceRange`, `facilitiesServices`, and `cuisineType`.
#
# 3. You will use a heap data structure (e.g., Python’s heapq library) to maintain the top-k restaurants.
#
# 4. Are the results you obtain better than with the previous scoring function? Explain and compare results.

# %% [markdown]
# #### STEP 1: User query
#
# User's input is preprocessed by using the `preprocessed_query()` function which does the following:
#    - Converts text to lowercase.
#    - Removes punctuation.
#    - Removes stopwords.
#    - Applies stemming to reduce words to their root forms.
#
# This preprocessing is important as it allows for correct comparision between the query and characteristics of each restaurant.
# In the next step, we will apply `execute_conjunctive_query()` function to the query in order to retrieve matching documents.
#    As we are interested in additional information that are not returned by the
# `execute_conjunctive_query()` function we can add this columns from the prepared subset_df by simple left-join merge.

# %%
import heapq

# Make subset with the relevant data for scoring function
subset_df = df[['restaurantName','priceRange', 'facilitiesServices', 'cuisineType', 'processed_description']]
print(subset_df.head())
# Out:
#              restaurantName priceRange  \
# 0            Castel Toblino         €€
# 1               Su Gologone         €€
# 2           Bàcaro Il Gusto         €€
# 3  Osteria dello Strecciolo        €€€
# 4                    Trippa         €€
#
#                                   facilitiesServices  \
# 0          ['Car park', 'Garden or park', 'Terrace']
# 1  ['Air conditioning', 'Car park', 'Garden or pa...
# 2          ['Air conditioning', 'Wheelchair access']
# 3                                                 []
# 4  ['Air conditioning', 'Terrace', 'Wheelchair ac...
#
#                       cuisineType  \
# 0    Modern Cuisine, Contemporary
# 1  Sardinian, Traditional Cuisine
# 2                        Venetian
# 3            Italian Contemporary
# 4       Italian, Seasonal Cuisine
#
#                                processed_description
# 0  situat bucol locat trentino excel vino santo p...
# 1  difficult choos three delight room restaur one...
# 2  simpl modern restaur attent focus extraordinar...
# 3  situat centr villag popular profession run res...
# 4  simpl inform slightli retro feel restaur serv ...

# %%
# Query input and preprocessing
query = input('RQ3 New score query:')
processed_query = preprocess_query(query)

# Convert the list into string for downstream tf-idf
processed_query_str = ' '.join(processed_query)

# Dataframe of the search results
# This function has buit into it the query preprocessing so we simply use the unprocessed query
search_results_df = execute_conjunctive_query(query)

# Print to visually inspect the matched documents preprocessed query
print('Preprocessed query:', processed_query_str)
print(search_results_df.head())
# Out:
# RQ3 New score query:traditional italian terrace
# Preprocessed query: tradit italian terrac
#                    restaurantName                    address  \
# 457   Il Ristorante - Niko Romito          via di Ripetta 73
# 1583        La Leggenda dei Frati      costa San Giorgio 6/a
# 1337          Osteria Il Cappello  piazzetta Bruno Lunelli 5
#
#                                             description  \
# 457   Situated on the fifth floor of the Hotel Bulga...
# 1583  After an uphill approach if you’re arriving he...
# 1337  The outdoor terrace at this restaurant overloo...
#
#                                                 website
# 457   https://www.bulgarihotels.com/it_IT/rome/dinin...
# 1583                     https://laleggendadeifrati.it/
# 1337                      https://osteriailcappello.it/

# %%
# Complete data frame composed of the search results merged with the scoring function-relevant columns
results_complete_df = pd.merge(search_results_df, subset_df, on='restaurantName', how='left')
print(results_complete_df.head())
# Out:
#                 restaurantName                    address  \
# 0  Il Ristorante - Niko Romito          via di Ripetta 73
# 1  Il Ristorante - Niko Romito          via di Ripetta 73
# 2        La Leggenda dei Frati      costa San Giorgio 6/a
# 3          Osteria Il Cappello  piazzetta Bruno Lunelli 5
#
#                                          description  \
# 0  Situated on the fifth floor of the Hotel Bulga...
# 1  Situated on the fifth floor of the Hotel Bulga...
# 2  After an uphill approach if you’re arriving he...
# 3  The outdoor terrace at this restaurant overloo...
#
#                                              website priceRange  \
# 0  https://www.bulgarihotels.com/it_IT/rome/dinin...       €€€€
# 1  https://www.bulgarihotels.com/it_IT/rome/dinin...       €€€€
# 2                     https://laleggendadeifrati.it/       €€€€
# 3                      https://osteriailcappello.it/         €€
#
#                                   facilitiesServices  \
# 0  ['Air conditioning', 'Interesting wine list', ...
# 1  ['Air conditioning', 'Garden or park', 'Terrac...
# 2  ['Car park', 'Restaurant offering vegetarian m...
# 3                    ['Air conditioning', 'Terrace']
#
#                 cuisineType                              processed_description
# 0      Italian Contemporary  situat fifth floor hotel bulgari view mausoleu...
# 1      Italian Contemporary  hous within bulgari hotel right heart milan op...
# 2                  Creative  uphil approach you’r arriv foot come villa bar...
# 3  Classic Cuisine, Italian  outdoor terrac restaur overlook pleasant pedes...

# %% [markdown]
# #### STEP 2: Define a scoring function that takes into account various attributes:
#
# **TF-IDF Computation**:
# TF_IDF is a metric that evaluates the importance of a word in a document with respect to the whole collection of documents. In this way it identifies the key terms of a particular document. We will use this metric by first running the vectorizer on the `processed_description` column so it learn the vocabulary and scores it and followingly on the query itself.
#
# **Cosine Similarity**:
# A metric used to evaluate the similarity of two vectors, by computing the cosine angle between them (1 for identical, 0 for orthogonal). Here we will apply it to the previously computed query vector and the document matrix. A result will be the score of how similar the query is to each of the retrieved restaurant descriptions.

# %%
# Compute the TF-IDF and add them as an additional column
description_col = results_complete_df['processed_description']
vectorizer = TfidfVectorizer()

# Fit and transform the processed_description column and processed query
tfidf_matrix = vectorizer.fit_transform(description_col)
tfidf_query = vectorizer.transform([processed_query_str])

# Compute cosine similarity between the query and the processed_description column
similarity_scores = cosine_similarity(tfidf_query, tfidf_matrix)
results_complete_df["cosineSimilarity"] = similarity_scores.flatten()

# Display the DataFrame
print(results_complete_df.to_string())
# Out:
#                 restaurantName                    address                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            description                                                                    website priceRange                                                      facilitiesServices               cuisineType                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          processed_description  cosineSimilarity
# 0  Il Ristorante - Niko Romito          via di Ripetta 73                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Situated on the fifth floor of the Hotel Bulgari with views of the Mausoleum of Augustus, Il Ristorante - Niko Romito boasts a spacious terrace and an elegant, welcoming dining room with mahogany walls adorned with works of art. The menu features traditional Italian cuisine reinterpreted with a light and imaginative touch as demonstrated by memorable dishes such as the chef’s own take on classic spaghetti in a tomato sauce.  https://www.bulgarihotels.com/it_IT/rome/dining/il-ristorante-niko-romito       €€€€                ['Air conditioning', 'Interesting wine list', 'Terrace']      Italian Contemporary                                                                                                                                                                                                                                                                                                         situat fifth floor hotel bulgari view mausoleum augustu il ristorant niko romito boast spaciou terrac eleg welcom dine room mahogani wall adorn work art menu featur tradit italian cuisin reinterpret light imagin touch demonstr memor dish chef’ take classic spaghetti tomato sauc          0.180576
# 1  Il Ristorante - Niko Romito          via di Ripetta 73                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Situated on the fifth floor of the Hotel Bulgari with views of the Mausoleum of Augustus, Il Ristorante - Niko Romito boasts a spacious terrace and an elegant, welcoming dining room with mahogany walls adorned with works of art. The menu features traditional Italian cuisine reinterpreted with a light and imaginative touch as demonstrated by memorable dishes such as the chef’s own take on classic spaghetti in a tomato sauce.  https://www.bulgarihotels.com/it_IT/rome/dining/il-ristorante-niko-romito       €€€€  ['Air conditioning', 'Garden or park', 'Terrace', 'Wheelchair access']      Italian Contemporary                                                                                                                                                                                                                                                                                                                                                                                                       hous within bulgari hotel right heart milan opposit exclus garden restaur run threemichelinstar chef niko romito abruzzi creat light italian dish contemporari feel trendi atmospher bar          0.056692
# 2        La Leggenda dei Frati      costa San Giorgio 6/a  After an uphill approach if you’re arriving here on foot, you come into the Villa Bardini museum complex and from there into this elegant and welcoming restaurant which provides the setting for delicious, creative and modern cuisine. Here, chef Filippo Saporito, never one to rest on his laurels, continues to experiment and perfect his cuisine, which focuses mainly on Italian culinary traditions and a scrupulous selection of top-quality ingredients, preferably from sustainable supply chains (various types of meat, bread and pasta), all showcased on different menus, including a vegetarian option. In summer, enjoy your meal on the romantic terrace surrounded by greenery and the scents of herbs, with a glimpse of Santa Croce church as a backdrop. Although the centre of Florence is not far away, it seems as though you’re already in the Tuscan hills, even with the occasional sound of cicadas in the background.                                             https://laleggendadeifrati.it/       €€€€         ['Car park', 'Restaurant offering vegetarian menus', 'Terrace']                  Creative  uphil approach you’r arriv foot come villa bardini museum complex eleg welcom restaur provid set delici creativ modern cuisin chef filippo saporito never one rest laurel continu experi perfect cuisin focus mainli italian culinari tradit scrupul select topqual ingredi prefer sustain suppli chain variou type meat bread pasta showcas differ menu includ vegetarian option summer enjoy meal romant terrac surround greeneri scent herb glimps santa croce church backdrop although centr florenc far away seem though you’r alreadi tuscan hill even occasion sound cicada background          0.116695
# 3          Osteria Il Cappello  piazzetta Bruno Lunelli 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                         The outdoor terrace at this restaurant overlooks a pleasant pedestrian piazza in the historic centre, while the welcoming dining rooms are decorated in a style typical of the Trentino. The cuisine – reliable, seasonal and full of flavour – is traditionally Italian, yet with a contemporary touch. The menu also features a few regional options as well as the occasional fish dish. The quail stuffed with acacia honey, pumpkin purée and stewed radicchio is superb.                                              https://osteriailcappello.it/         €€                                         ['Air conditioning', 'Terrace']  Classic Cuisine, Italian                                                                                                                                                                                                                                                                             outdoor terrac restaur overlook pleasant pedestrian piazza histor centr welcom dine room decor style typic trentino cuisin – reliabl season full flavour – tradit italian yet contemporari touch menu also featur region option well occasion fish dish quail stuf acacia honey pumpkin puré stew radicchio superb          0.173543

# %% [markdown]
# ##### New scoring function:
# - **Description Match**: Give weight based on the query similarity to the description (using TF-IDF scores).
# - **Cuisine Match**: Increase the score for matching cuisine types.
# - **Facilities and Services**: Give more points for matching facilities/services (e.g., “Terrace,” “Air conditioning”).
# - **Price Range**: Higher scores could be given to more affordable options based on the user’s choice.
#
# Considerations:
#
# - **Scoring**: As the "*restaur*" term appears quite often in the searches and so does in the `facilitiesServices` but does not aport any additional value, it will be excluded from the scoring.

# %%
# Total scoring function and helper match functions


# Function that scores query match with the cuisine type
def cuisine_match(query, row):
    score = 0
    for term in query:
        if term in preprocess_description(row['cuisineType']):
            score = 1
    return score

# Function that scores the query match with the facilities and services
def facility_match(query, row):
    score = 0
    for term in query:
        if term in preprocess_description(row['facilitiesServices']):
            if term != 'restaur':
                score += 1
    return score

# Function for price score
def price_match(row):
    prices = {'€€€€':0,'€€€':1,'€€':2,'€':3}
    score = prices.get(row['priceRange'])
    return score

# Function computing the overall score for every restaurant using the above defined match functions
def new_attribute_score(query, row, cuisine_weight=0.5, facility_weight=0.3, price_weight=0.2):
    cuisine_score = cuisine_match(query, row)
    facility_score = facility_match(query, row)
    price_score = price_match(row)
    similarity = row['cosineSimilarity']

    total_score = similarity*(cuisine_score*cuisine_weight + facility_score*facility_weight + price_score*price_weight +1)
    return(total_score)

# %% [markdown]
# #### STEP 3: Top k restaurants: You will use a heap data structure (e.g., Python’s heapq library) to maintain the top-k restaurants.
#
# The output should include:
# - restaurantName
# - address
# - description
# - website
# - the new similarity score based on the custom metric
#
#
# To create and maintain a heap of the top restaurants based on the `newScore` function, we use the `top_k_restaurants()` function that takes as input the search results, the query and a variable k, representing the number of top restaurants we want in the output.
#
# FUNCTION DESCRIPTION
#
#  The function creates an empty heap and then proceeds to iterate over the rows of the search results assigning a score to each restaurant considering the matches with `priceRange`, `facilitiesServices` and `cuisineType`. Based on the score it then adds it to the heap which if completely filled will push out the restaurant with lowest score.
#     Followingly, a simple dictionary of the top restaurant is created and used to filter out
# the relevant information for the output from the search result dataframe.
#     Lastly, data frame of the top k restaurants in descending order based on the newScore
# is returned.

# %%
# Top restaurants function using heap as data structure
def top_k_restaurants(df, query, k):

    if df.empty:
        return 'We found no result to your query.'
    else:
        heap = []
        # Assign a score to each restaurant by iterating over the data frame
        for index, row in df.iterrows():
            score = new_attribute_score(query,row)
            restaurant = row['restaurantName']

            if len(heap) < k:
                heapq.heappush(heap,(score, restaurant))
            else:
                heapq.heappushpop(heap, (score, restaurant))

        # Dictionary with the restaurant name and scores
        top_restaurants_dict = {name:score for score, name in heap}

        # Subset the dataframe with the top restaurants and get selcted columns
        top_restaurants_df = df[df['restaurantName'].isin(top_restaurants_dict.keys())][['restaurantName','address','cuisineType','priceRange','website', 'Latitude', 'Longitude', 'Region']]
        top_restaurants_df['newScore'] = top_restaurants_df['restaurantName'].map(top_restaurants_dict)

        # Sort the top restaurants in descending order based
        top_restaurants_df = top_restaurants_df.sort_values(by='newScore', ascending=False)

        return top_restaurants_df

# Function call to get k top restaurants based on the newScore
top_restaurants = top_k_restaurants(results_complete_df, processed_query, k=10)
print(top_restaurants)
# Out:
#                 restaurantName                    address  \
# 3          Osteria Il Cappello  piazzetta Bruno Lunelli 5
# 0  Il Ristorante - Niko Romito          via di Ripetta 73
# 1  Il Ristorante - Niko Romito          via di Ripetta 73
# 2        La Leggenda dei Frati      costa San Giorgio 6/a
#
#                 cuisineType priceRange  \
# 3  Classic Cuisine, Italian         €€
# 0      Italian Contemporary       €€€€
# 1      Italian Contemporary       €€€€
# 2                  Creative       €€€€
#
#                                              website  newScore
# 3                      https://osteriailcappello.it/  0.381795
# 0  https://www.bulgarihotels.com/it_IT/rome/dinin...  0.325036
# 1  https://www.bulgarihotels.com/it_IT/rome/dinin...  0.325036
# 2                     https://laleggendadeifrati.it/  0.151703

# %% [markdown]
# #### STEP 4: Compare the results
# The new scoring function is more sensitive as it takes into account other parameters than just the similarity between description and the query. Adding query-dependent facility score and cuisine score improves the results especially in cases when these might not be mentioned in the description. On the other hand, the price score fixed for each restaurant based on the `priceRange` ensures the preofrence will be added to the budget-friendlier restaurants. Finally, having the option of setting the weights for each of these parameters, the user can opt to exclude any of these from their search or taylor them to their needs.

# %% [markdown]
# # RQ4. Visualizing the Most Relevant Restaurants

# %% [markdown]
# We had to first compile distinct locations in the form of cities and regions in order to finish this step. Using OpenCage's API, we obtained the required data. We created a CSV file with the geographic data for every restaurant using its latitude, longitude and region.

# %%
# !pip install folium

# Use query and k for filtering
query_terms = ["italian", "cuisine"]  # Example query terms
k = 5  # Number of top restaurants

top_restaurants = top_k_restaurants(results_complete_df, processed_query, k)

import folium
from folium.plugins import MarkerCluster

# Initialize a map centered around the average latitude and longitude of the dataset
center_lat = top_restaurants['Latitude'].mean()
center_lon = top_restaurants['Longitude'].mean()

m = folium.Map(location=[center_lat, center_lon], zoom_start=6)

# Define price range colors
price_colors = {
    '€': 'green',
    '€€': 'blue',
    '€€€': 'orange',
    '€€€€': 'red'
}

# Add a marker cluster to group nearby restaurants
marker_cluster = MarkerCluster().add_to(m)

# Add restaurants to the map
for _, row in top_restaurants.iterrows():
    marker_color = price_colors.get(row['priceRange'], 'gray')  # Default to gray if price range not found
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=8,  # Fixed marker size for visibility
        color=marker_color,
        fill=True,
        fill_color=marker_color,
        fill_opacity=0.7,
        popup=(
            f"<b>Name:</b> {row['restaurantName']}<br>"
            f"<b>Region:</b> {row['Region']}<br>"
            f"<b>Price Range:</b> {row['priceRange']}<br>"
            f"<b>Address:</b> {row['address']}<br>"
            f"<b>Website:</b> <a href='{row['website']}' target='_blank'>{row['website']}</a>"
        )
    ).add_to(marker_cluster)

# Add a legend to the map
legend_html = '''
<div style="position: fixed;
            bottom: 50px; left: 50px; width: 200px; height: 150px;
            background-color: white; z-index:9999; font-size:14px;
            border:2px solid grey; padding: 10px;">
    <b>Price Range Legend</b><br>
    <i style="background:green; color:green; border-radius:50%; padding:5px;"></i> €<br>
    <i style="background:blue; color:blue; border-radius:50%; padding:5px;"></i> €€<br>
    <i style="background:orange; color:orange; border-radius:50%; padding:5px;"></i> €€€<br>
    <i style="background:red; color:red; border-radius:50%; padding:5px;"></i> €€€€<br>
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))

# Save the map to an HTML file and display top 5 restaurants as an instance
map_file = 'top_restaurants_map.html'
m.save(map_file)

map_file
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.8.30)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-8ef3af26f8dd> in <cell line: 13>()
#      11
#      12 # Initialize a map centered around the average latitude and longitude of the dataset
# ---> 13 center_lat = top_restaurants['Latitude'].mean()
#      14 center_lon = top_restaurants['Longitude'].mean()
#      15
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Latitude'

# %%
from IPython.core.display import HTML
HTML('<img src="top_restaurants_map.html" alt="Top restaurants map" width="400">')
# Out:
# <img src="top_restaurants_map.html" alt="Example Image" width="400">

# %%
from IPython.display import IFrame

# Display the uploaded HTML file
IFrame(src='top_5_restaurants_map.html', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="top_5_restaurants_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # RQ5. BONUS: Advanced Search Engine

# %%
# Function to create an inverted index for fast search on selected fields
def create_inverted_index(data):
    index = defaultdict(set)

    # Tokenize and index fields for search with separate handling for fields and words
    for i, row in data.iterrows():

        for field in ["restaurantName", "city", "cuisineType"]:
            field_value = row.get(field)            # Retrieve the value of the field for the current row
            if pd.notna(field_value):               # Check if the value is not NaN
                words = field_value.lower().split() # Tokenize the value into words

                for word in words:
                    if word not in index:
                        index[word] = set()         # Initialize a new set if the word is not in the index
                    index[word].add(i)              # Add the index of the row to the set for this word
    return index

# %%
# Function to search the restaurants
def restaurants_search(data, name=None, city=None, cuisine_type=None, min_price=None, max_price=None, regions=None, credit_cards=None, facilities=None):

    # Create a copy of data
    temporary_data = data.copy()

    # Create an inverted index to do efficient search
    index = create_inverted_index(temporary_data)

    matching_indices = set(temporary_data.index)

    # Name's search logic function
    if name:

        # Find all matches for name terms using the inverted index
        name_matches = set.union(*(index.get(term, set()) for term in name.lower().split()))
        matching_indices = matching_indices.intersection(name_matches)

    # City's search logic function
    if city:

        # Find all matches for city terms using the inverted index
        city_matches = set.union(*(index.get(term, set()) for term in city.lower().split()))
        matching_indices = matching_indices.intersection(city_matches)

    # Cuisine type's search logic function
    if cuisine_type:

        # Find all matches for cuisine type terms using the inverted index
        cuisine_matches = set.union(*(index.get(term, set()) for term in cuisine_type.lower().split()))
        matching_indices = matching_indices.intersection(cuisine_matches)

    # Price range's filter
    if min_price or max_price:

        # Map of price symbols to numerical values
        price_values = {"€": 1, "€€": 2, "€€€": 3, "€€€€": 4}
        min_price_value = price_values.get(min_price, 1)  # Default to 1
        max_price_value = price_values.get(max_price, 4)  # Default to 4

        # Filter indices based on price range
        price_matches = {idx for idx in temporary_data.index if price_values.get(temporary_data.at[idx, "priceRange"], 0) >= min_price_value and price_values.get(temporary_data.at[idx, "priceRange"], 0) <= max_price_value}
        matching_indices = matching_indices.intersection(price_matches)

    # Region's filter
    if regions:

        # Postal codes and their ranges (with the corresponding regions)
        postal_code_ranges = [
            (100, 199, "Lazio"), (1000, 1999, "Lazio"), (3000, 3999, "Lazio"),
            (7000, 9199, "Sardegna"), (10000, 12999, "Piemonte"),
            (13000, 13999, "Valle d'Aosta"), (15000, 19999, "Piemonte"),
            (20000, 20999, "Lombardia"), (21000, 23999, "Lombardia"),
            (25000, 28999, "Lombardia"), (30000, 34999, "Veneto"),
            (36000, 36999, "Veneto"), (37000, 39999, "Veneto"),
            (38000, 38999, "Trentino-Alto Adige"), (40000, 47999, "Emilia-Romagna"),
            (50000, 59100, "Toscana"), (60000, 63999, "Marche"),
            (64000, 64999, "Abruzzo"), (66000, 66999, "Abruzzo"),
            (67000, 67999, "Molise"), (70000, 71999, "Puglia"),
            (75000, 75999, "Basilicata"), (80000, 84999, "Campania"),
            (85000, 86999, "Basilicata"), (87000, 89999, "Calabria"),
            (90000, 91999, "Sicilia"), (95000, 98199, "Sicilia")
        ]

        # Function to determine the region dependent on the postal code
        def region_from_postal_code(postal_code):
            try:
                postal_code = int(postal_code)
                matched_region = next((region for start, end, region in postal_code_ranges if start <= postal_code <= end), "Unknown Region")
                return matched_region

            except (ValueError, TypeError):
                return "Unknown Region"

        # Add the region column to temporary_data
        temporary_data["region"] = temporary_data["postalCode"].apply(region_from_postal_code).str.lower()

        # Apply region filter
        region_list = {region.strip().lower() for region in regions.split(",")}
        region_matches = {idx for idx in temporary_data.index if temporary_data.at[idx, "region"] in region_list}
        matching_indices = matching_indices.intersection(region_matches)

    # Credit cards' filter
    if credit_cards:

        # Filter indices based on presence of specified credit cards
        credit_matches = {idx for idx in temporary_data.index if any(card in temporary_data.at[idx, "creditCards"] for card in credit_cards)}
        matching_indices = matching_indices.intersection(credit_matches)

    # Facilities' filter
    if facilities:

        # Filter indices based on presence of specified facilities
        facility_matches = {idx for idx in temporary_data.index if all(facility in temporary_data.at[idx, "facilitiesServices"] for facility in facilities)}
        matching_indices = matching_indices.intersection(facility_matches)

    # Filtered data
    result = temporary_data.loc[list(matching_indices), ["restaurantName", "address", "city", "cuisineType", "priceRange", "region", "website"]]

    return result

# %% [markdown]
# # Algorithmic Question (AQ)

# %% [markdown]
# 1. Write the pseudocode for an algorithm that solves this problem.

# %%
def solve():
    T = int(input()) # Number of test cases

    for t in range(T):
        n = int(input())  # Number of packages
        packages = []  # Package coordinates

        for i in range(n):
            x, y = list(map(int, input().split())) # x and y coordinates of a package
            packages.append((x, y))

        # Sort packages by (x, y) coordinates
        packages.sort()  # Sorts first by x, then by y (if x's are the same)

        # Check if a valid path exists
        possible = True
        for i in range(1, n):
            # Check if coordinates of the current package is less than coordinates of the previous package
            if packages[i][0] < packages[i - 1][0] or packages[i][1] < packages[i - 1][1]:
                possible = False
                break

        if not possible:
            print("NO")
            continue

        # Construct the path if possible
        current_x, current_y = 0, 0
        path = ""

        for x, y in packages:
            # Move right (R) to reach the target x-coordinate
            path += "R" * (x - current_x)
            # Move up (U) to reach the target y-coordinate
            path += "U" * (y - current_y)
            # Update current position
            current_x, current_y = x, y

        # Output the result
        print("YES")
        print(path)
solve()
# Out:
# 3
# 5
# 1 3
# 1 2
# 3 3
# 5 5
# 4 3
# YES
# RUUURRRRUU
# 2
# 1 0
# 0 1
# NO
# 1
# 4 3
# YES
# RRRRUUU

# %% [markdown]
# 2. Prove that your algorithm is correct.

# %% [markdown]
# It can be proved that the algorithm is correct by establishing an invariant — a condition that holds true at each step of the algorithm.
#
# #### Invariant 1: Sorted Order Implies Lexicographical Order
# **Claim**: Sorting the packages by `(x, y)` coordinates ensures that visiting them in this order produces the lexicographically smallest path.
#
# **Proof**: Sorting by `(x, y)` ensures that if two packages have the same `x` coordinate, the one with the smaller `y` coordinate appears first. This ordering respects the lexicographical priority of moving right (`R`) before moving up (`U`). As a result, if there’s a valid path that collects all packages in this order, it will be the lexicographically smallest.
#
# #### Invariant 2: Reachability Check Guarantees Feasibility
# **Claim**: If for every pair of consecutive packages `(xᵢ, yᵢ)` and `(xᵢ₊₁, yᵢ₊₁)` in the sorted list, `xᵢ ≤ xᵢ₊₁` and `yᵢ ≤ yᵢ₊₁`, then all packages are reachable using only right and up moves.
#
# **Proof**: If `xᵢ > xᵢ₊₁` or `yᵢ > yᵢ₊₁` for any two consecutive packages, it would mean moving left or down is required to reach the next package, which violates the movement restrictions. Therefore, the algorithm checks each pair of consecutive packages after sorting to ensure `x` and `y` coordinates are non-decreasing. If this holds for all pairs, then it is guaranteed that we can move from each package to the next using only right or up moves.
#
# #### Invariant 3: Constructed Path is Minimal
# **Claim**: The constructed path is the minimal (shortest) path to collect all packages in the lexicographically smallest order.
#
# **Proof**: After confirming that each package is reachable in the sorted order, the algorithm constructs the path by calculating the difference in `x` (right moves) and `y` (up moves) between the current position and each package. Since the algorithm adds all `R` moves before `U` moves for each step, this minimizes unnecessary movement and maintains lexicographical order. Thus, this approach yields the shortest path that respects the lexicographical requirement.

# %% [markdown]
# 3. Compute the time complexity of your algorithm in Big O notation. Break down the steps involved in the algorithm, and explain which parts contribute most to the overall time complexity.

# %% [markdown]
# 1) Reading Input for Each Test Case:

# %%
T = int(input()) # Number of test cases

for t in range(1, T + 1):
    n = int(input())  # Number of packages
    packages = []

    for i in range(n):
        x, y = list(map(int,input()))
        packages.append((x, y))

# %% [markdown]
# This part reads **T (the number of test cases)** and, for each test case, reads **n packages** with their coordinates.
#
# Time complexity:
# * Reading each integer takes O(1), so reading n packages per test case takes O(n)
# * For T test cases, the total time complexity for reading input is: O(T * n)

# %% [markdown]
# 2) Sorting the Packages

# %%
packages.sort()

# %% [markdown]
# The packages are sorted by coordinates (x, y), which helps in constructing the lexicographically smallest path.
#
# Time complexity:
# * Sorting n packages takes O(*n* log *n*). It requires about log *n* levels of division to fully sort the list, and at each level, comparing *n* elements requires O(n) time.
# * For T test cases, the time complexity for sorting is: O(T * *n* log *n*)

# %% [markdown]
# 3) Verifying Reachability

# %%
possible = True
for i in range(1, n):
    if packages[i][0] < packages[i - 1][0] or packages[i][1] < packages[i - 1][1]:
        possible = False
        break

# %% [markdown]
# This loop checks if all packages can be reached using only right (R) and up (U) moves. If any package cannot be reached in this way, it sets possible to False.

# %% [markdown]
# Time complexity:
# * This loop iterates through the sorted list of n packages. Across T test cases, the complexity for verifying reachability is: O(T * n)

# %% [markdown]
# 4) Constructing the Path

# %%
current_x, current_y = 0, 0
path = ""

for (x, y) in packages:
    path += "R" * (x - current_x)
    path += "U" * (y - current_y)
    current_x, current_y = x, y

# %% [markdown]
# If all packages are reachable, this step constructs the path by iterating through each package and calculating the required number of R and U moves.
#
# Time complexity:
# * Total moves per package are bounded by the grid size n. Across T test cases, the total complexity for path construction is: O(T * n)

# %% [markdown]
# The most computationally expensive step is sorting the packages, which has a time complexity of **O(T * *n* log *n*)**. Therefore, the overall time complexity of the algorithm is **O(T * *n* log *n*)**.

# %% [markdown]
# 4. Ask an LLM tool (such as ChatGPT, Claude AI, Gemini, Perplexity, etc.) to evaluate the time complexity of your code using Big O notation. Is the assessment accurate? If it differs from your previous analysis, which would be correct? Please explain your reasoning.

# %% [markdown]
# ### Time Complexity Analysis of `solve()` Function
#
# To analyze the time complexity of the code, we’ll examine each part of the function `solve()`.
#
# #### 1. Reading Input
# - `T = int(input())` takes constant time, $O(1)$, to read the number of test cases.
# - For each test case, `n = int(input())` reads the number of packages. Assuming each integer read takes constant time, $O(1)$, this step itself is $O(T)$.
#
# #### 2. Loop Through Test Cases
# - The main loop iterates $T$ times (once per test case), so anything inside this loop is performed $T$ times.
#
# #### 3. Reading and Storing Coordinates
# - For each test case, the loop `for i in range(n):` iterates $n$ times, where each iteration reads a coordinate pair `(x, y)` and appends it to the `packages` list.
# - The complexity of reading all coordinates for a test case is $O(n)$, assuming each read is $O(1)$.
#
# #### 4. Sorting the Packages
# - After reading all packages, the code sorts the list of packages by their `(x, y)` coordinates.
# - Sorting $n$ elements takes $O(n \log n)$ time. This is the most computationally expensive operation within a test case.
#
# #### 5. Checking Validity of Path
# - The next loop, `for i in range(1, n):`, checks if each package’s coordinates are non-decreasing. This loop runs $n-1$ times.
# - Each iteration involves a constant-time comparison, making the complexity of this loop $O(n)$.
#
# #### 6. Constructing the Path
# - If the path is valid, the final loop constructs the path by moving horizontally and vertically between package coordinates.
# - This loop iterates $n$ times, and each iteration appends characters to the `path` string.
# - In the worst case, if we have to move across a large distance (e.g., from `(0, 0)` to `(x, y)`), we would append $x + y$ characters to the string.
# - While the exact number of moves depends on the input coordinates, in the worst case, we can assume constructing the path would take $O(n)$ time for each test case.
#
# #### 7. Printing the Result
# - Printing the result is $O(1)$ for each test case, as it outputs constant-size strings.
#
# ### Total Time Complexity
# Combining all these steps, the overall time complexity for each test case is dominated by the sorting step, which is $O(n \log n)$. Thus, for $T$ test cases, the total time complexity of the function is:
#
# $$
# O(T \cdot (n \log n + n)) = O(T \cdot n \log n)
# $$
#
# ### Final Complexity
# The time complexity of the function `solve()` is:
#
# $$
# O(T \cdot n \log n)
# $$
#
# where:
# - $T$ is the number of test cases.
# - $n$ is the number of packages (coordinates) in each test case.

# %% [markdown]
# 5. Assume now that the robot can also move towards the left or downwards, and consider the greedy approach: from the current location go to the closest package. Notice that now we can always collect all packages. Prove that the greedy algorithm is optimal (i.e., it minimizes the total distance traveled), or provide a counterexample showing that it is not.

# %% [markdown]
# - Let the robot start at position $P_0$, and let there be $n$ packages located at positions $P_1, P_2, \dots, P_n $.
# - Let $d(A, B)$ denote the distance between points $A$ and $B$, calculated as the Manhattan distance:
#
#   $
#   d(A, B) = |x_A - x_B| + |y_A - y_B|
#   $
#
# ### Greedy Algorithm
#
# 1. At each step, from the robot’s current position $P_i$, the greedy algorithm moves to the nearest remaining package $P_{i+1}$ such that:
#
#    $
#    d(P_i, P_{i+1}) = \min_{P_k \in \text{Remaining Packages}} d(P_i, P_k)
#    $
#
# 2. The total distance $D_{\text{greedy}}$ traveled by the robot following the greedy algorithm is:
#
#    $
#    D_{\text{greedy}} = \sum_{i=0}^{n-1} d(P_i, P_{i+1})
#    $
#
#
#
# To prove that the greedy algorithm is optimal, we use the **triangle inequality**, which states that for any three points $A$, $B$, and $C$:
# $
# d(A, B) \leq d(A, C) + d(C, B)
# $
#
#
# ### Proof by Contradiction
#
# Assume, for contradiction, that there exists a different path, $D_{\text{alt}}$, that is shorter than the greedy path $D_{\text{greedy}}$:
# $
# D_{\text{alt}} < D_{\text{greedy}}
# $
# Let this alternative path visit packages in a non-greedy order.
#
# 1. **Alternative Path Analysis**:
#    - In $D_{\text{alt}}$, suppose the robot skips a closer package $P_j$ in favor of a farther package $P_k$ (where $d(P_i, P_j) < d(P_i, P_k)$), and then returns to visit $P_j$ later.
#    - By the triangle inequality:
#      $
#      d(P_i, P_j) \leq d(P_i, P_k) + d(P_k, P_j)
#      $
#    - Therefore, going directly from $P_i$ to $P_j$ is shorter than or equal to first going to $P_k$ and then to $P_j$.
#
# 2. **Contradiction**:
#    - By skipping the closest package $P_j$ and going to a farther one $P_k$, $D_{\text{alt}}$ must be longer than or equal to $D_{\text{greedy}}$.
#    - This contradicts our assumption that $D_{\text{alt}} < D_{\text{greedy}}$.
#
#
# Therefore, the greedy algorithm is optimal.
